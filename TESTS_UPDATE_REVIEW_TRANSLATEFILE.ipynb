# %% [markdown]
# REPLACE ONLY FINAL TRANSLATION SECTION

# %% [markdown]
# TESTA 18APR TRANSLATE VIDEO

# %% [markdown]
# 26 APR mety seg2

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up





def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides





def parse_review_file(review_file_path):
    """
    Lit le review file et retourne une liste de dicts, un par segment, avec :
      - start_s, end_s : début / fin du segment en secondes
      - original : texte original en anglais
      - final_translation : texte final en français
      - voice_speed : vitesse synthèse (e.g. "+0%")
      - pre_silence, post_silence : en millisecondes
      - inter_phrase_silences : liste de silences entre phrases (en ms)
      - phrases : liste de phrases françaises à synthétiser
    """
    text = open(review_file_path, encoding="utf-8").read()
    # split sur toute ligne de 3+ tirets
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header_re = re.compile(
        r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)", re.I
    )

    for blk in blocks:
        if blk.startswith("Translation Review File"):
            continue
        m = header_re.search(blk)
        if not m:
            continue

        start_s = float(m.group(1))
        end_s   = float(m.group(2))

        # valeurs par défaut
        orig    = None
        ft      = None
        vs      = "+0%"
        pre     = 0.0
        post    = 100.0
        inter   = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()
            elif line.startswith("**Final Translation:**"):
                ft   = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs   = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try:
                    pre = float(line.split("**Pre-Silence:**",1)[1].strip())
                except ValueError:
                    pass
            elif line.startswith("**Post-Silence:**"):
                try:
                    post = float(line.split("**Post-Silence:**",1)[1].strip())
                except ValueError:
                    pass
            elif line.startswith("**Inter-Phrase-Silence:**"):
                vals = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if vals:
                    try:
                        raw = [float(x) for x in vals.split(",")]
                        # clamp à [0, 5000] ms pour éviter les excès
                        inter = [max(0, min(v, 5000)) for v in raw]
                    except ValueError:
                        inter = []

        if orig is None:
            raise RuntimeError(f"Segment sans **Original** dans {review_file_path}")
        if ft is None:
            ft = orig  # fallback

        # découpe finale en phrases françaises (accents et majuscules prises en compte)
        phrases = re.split(r"(?<=[\.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", ft)
        phrases = [p.strip() for p in phrases if p.strip()]

        segments.append({
            "start_s":               start_s,
            "end_s":                 end_s,
            "original":              orig,
            "final_translation":     ft,
            "voice_speed":           vs,
            "pre_silence":           pre,
            "post_silence":          post,
            "inter_phrase_silences": inter,
            "phrases":               phrases
        })

    print(f"✅ Parsed {len(segments)} segments from review file.")
    return segments

def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%", max_retries: int = 10):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    Note: In Edge TTS v7.0.0 the 'session' parameter is not supported.
    """
    for attempt in range(max_retries):
        try:
            # Create a new session for each attempt.
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt+1}: Synthesizing phrase: '{phrase}'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.uniform(0, 1)
            print(f"[Error] Attempt {attempt+1}/{max_retries} failed for phrase: '{phrase}'. Exception: {e}")
            print(f"[Debug] Retrying in {wait_time:.2f} seconds...")
            await asyncio.sleep(wait_time)
    raise Exception(f"Failed to synthesize phrase after {max_retries} attempts: {phrase}")

async def synthesize_phrase(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%"):
    await robust_synthesize_phrase(phrase, output_path, voice, rate)

# For backward compatibility:
async def synthesize_phrase_edge_hybrid(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%"):
    await synthesize_phrase(phrase, output_path, voice, rate)

def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")




def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) Regroupe les sous-titres par phrases.
    2) Scinde les groupes trop longs.
    3) Écrit le fichier de review en indiquant :
       - pre / post silence
       - budget total pour inter-phrases
       - inter-phrase-silence par défaut (0 pour chaque intervalle)
    """
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regroupement par phrase
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, current = [], []
    for sub in subs:
        current.append(sub)
        if sentence_end.search(sub.text):
            groups.append(current)
            current = []
    if current:
        groups.append(current)

    # 2) Découpe si trop long & enforcement ponctuation
    from itertools import chain
    def split_long_groups(groups, max_s):
        new = []
        for g in groups:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end-start <= max_s:
                new.append(g)
            else:
                mid = len(g)//2
                new.extend([g[:mid], g[mid:]])
        return new
    groups = split_long_groups(groups, max_group_duration_secs)

    def enforce_punctuation_boundaries(groups):
        i = 0
        while i < len(groups):
            last = groups[i][-1].text.strip()
            if not re.search(r"[.!?,;:]$", last):
                if i+1 < len(groups):
                    groups[i] += groups.pop(i+1)
                else:
                    groups[i][-1].text += "."
            else:
                i += 1
        return groups
    groups = enforce_punctuation_boundaries(groups)

    # 3) Write review file
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Edit the **Final Translation** below. You can also adjust:\n")
        f.write("- **Voice Speed:** -10% to +10%\n")
        f.write("- **Pre-Silence/Post-Silence:** in milliseconds\n")
        f.write("- **Inter-Phrase-Silence:** comma-separated ms between phrases\n")
        f.write("  (must have one fewer value than phrases)\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal/1000
            end_s   = group[-1].end.ordinal/1000
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # découpe en phrases (Final Translation automatique)
            phrases = re.split(
                r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])",
                auto_tr
            )
            phrases = [p.strip() for p in phrases if p.strip()]

            # budget inter-phrases
            total_ms     = int((end_s - start_s)*1000)
            pre_ms, post_ms = 100, 100
            budget_inter = max(0, total_ms - pre_ms - post_ms)

            # silences par défaut = 0
            inter_default = ",".join("0" for _ in range(len(phrases)-1))

            # écriture
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s):\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** +0%\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Budget total Inter-Phrase-Silence (ms):** {budget_inter}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_default}\n")
            f.write("----------------------------------------------------------------\n\n")

    print(f"✅ Review file created at: {review_file_path}  ({len(groups)} segments)")
    input("Type 'Y' when ready to continue: ")
    return groups


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # ─── 1) Génération / mise à jour du review file ───
    # Cette fonction va demander à l'utilisateur de valider ou modifier le fichier.
    groups = generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )

    # ─── 2) Lecture du review file enrichi ───
    # parse_review_file récupère start_s, end_s, final_translation, voice_speed, pre/post et inter-phrase.
    segments = parse_review_file(review_file_path)

    # ─── 3) On s'assure d'avoir autant d'overrides que de groupes ───
    default_ov = {
        "final_translation":    None,
        "voice_speed":          "+0%",
        "pre_silence":          0.0,
        "post_silence":         100.0,
        "inter_phrase_silences": []
    }
    # segments contient déjà tous les champs dont on a besoin
    # Si vous voulez quand même un fallback, vous pouvez l'ajouter ici.

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        # on récupère tout directement depuis seg dict
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms= int((end_s - start_s)*1000)

        text       = seg.get("final_translation", seg.get("original", ""))
        rate       = seg.get("voice_speed", "+0%")
        pre_ms     = seg.get("pre_silence", 0.0)
        post_ms    = seg.get("post_silence", 100.0)
        inter_user = seg.get("inter_phrase_silences", [])
                # découpage en phrases + poids
        phrases   = split_french_phrases(text)
        weights   = calculate_phrase_weights(text, phrases)
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # synth + ajustements identiques à votre pipeline
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur      = content_ms * weights[i] / 1000.0
            tmp_path = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await synthesize_phrase_edge_hybrid(ph, tmp_path, voice="fr-FR-DeniseNeural", rate=rate)
            aud = AudioSegment.from_mp3(tmp_path); os.remove(tmp_path)
            aud = adjust_audio_duration(aud, dur)
            phrase_audios.append(aud)

        # # anti-dépassement TTS seul
        # sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)
        # if sum_tts > content_ms and sum_tts>0:
        #     factor = content_ms / sum_tts
        #     phrase_audios = [change_playback_speed(a, factor) for a in phrase_audios]
        #     sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)

        # # anti-dépassement silences users
        # available = content_ms - sum_tts
        # if available <= 0:
        #     inter_applied = [0]*len(inter_user)
        # elif sum(inter_user) <= available:
        #     inter_applied = inter_user.copy()
        # else:
        #     factor = available / sum(inter_user)
        #     inter_applied = [int(ms*factor) for ms in inter_user]
        
        # ─── ANTI-DÉPASSEMENT : PRIORITÉ AUX SILENCES UTILISATEUR ───
        sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)
        sum_int = sum(inter_user)

        # Si TTS + silences > budget, on réduit d'abord le TTS
        if sum_tts + sum_int > content_ms and sum_tts > 0:
            factor_tts = max(0.0, (content_ms - sum_int) / sum_tts)
            phrase_audios = [
                change_playback_speed(aud, factor_tts)
                for aud in phrase_audios
            ]

        # On applique exactement les silences demandés par l'utilisateur
        inter_applied = inter_user.copy()

        # rebuild + pre/post silence + strip internal + pad/trim identique...
        seq = []
        for i, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq: seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        non = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS-16)
        if non:
            seg_audio = seg_audio[non[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # mesures pour debug
        non2 = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS-16)
        start_audio_ms = non2[0][0] if non2 else pre_ms
        end_audio_ms   = non2[-1][1] if non2 else (total_ms-post_ms)
        abs_start_a = int(start_s*1000)+start_audio_ms
        abs_end_a   = int(start_s*1000)+end_audio_ms
        abs_start_v = int(start_s*1000)
        abs_end_v   = int(end_s*1000)
        decal_start = abs_start_a - abs_start_v
        decal_end   = abs_end_a   - abs_end_v

        # éventuel warp global
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s-start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s-start_s)/gen_dur)

        # mix sur timeline
        start_ms = int(start_s*1000)
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms-len(combined)))
        combined += seg_audio

        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"inter_user={inter_user} → inter_applied={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms, "
            f"phrases={phrases}\n"
        )

    # export
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")
    return output_audio_path

# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file created at: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250426_083624\translation_review.txt  (27 segments)
# ✅ Parsed 27 segments from review file.
# [Debug] Attempt 1: Synthesizing phrase: 'Nous allons voir les configurations de l'application EPM.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous verrons comment créer une règle métier ou une formule de membre.'
# [Error] Attempt 1/10 failed for phrase: 'Nous verrons comment créer une règle métier ou une formule de membre.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B0320> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.56 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous verrons comment créer une règle métier ou une formule de membre.'
# [Error] Attempt 2/10 failed for phrase: 'Nous verrons comment créer une règle métier ou une formule de membre.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B0440> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.73 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Nous verrons comment créer une règle métier ou une formule de membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous verrons comment la sécurité fonctionne dans l'application EPM et nous couvrirons comment créer et configurer des formulaires de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La sécurité dans  EPM comprendra la sécurité dimensionnelle, la sécurité des artefacts, la sécurité par tâches ou le flux de travail, la sécurité des règles métier et la sécurité des données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions.'
# [Error] Attempt 1/10 failed for phrase: 'À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1BE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.96 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Maintenant, dans cet écran, nous allons alors sélectionner le cube, et pour la dimension du compte correspondant, nous allons rechercher le membre pour lequel je souhaite mettre à jour la formule du membre.'
# [Error] Attempt 1/10 failed for phrase: 'Maintenant, dans cet écran, nous allons alors sélectionner le cube, et pour la dimension du compte correspondant, nous allons rechercher le membre pour lequel je souhaite mettre à jour la formule du membre.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B0440> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.99 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Maintenant, dans cet écran, nous allons alors sélectionner le cube, et pour la dimension du compte correspondant, nous allons rechercher le membre pour lequel je souhaite mettre à jour la formule du membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Une fois que le membre est mis en évidence, nous pouvons modifier les propriétés de formule de membres.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons sélectionner le cube pour voir la formule du membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La formule des membres est utilisée n'importe où dans l'application.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ici, le matériel OFS sera divisé par le volume OFS.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Une fois que nous avons la formule des membres, nous pouvons la valider et nous pouvons voir qu'elle est validée avec succès.'
# [Error] Attempt 1/10 failed for phrase: 'Une fois que nous avons la formule des membres, nous pouvons la valider et nous pouvons voir qu'elle est validée avec succès.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B15B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.40 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Une fois que nous avons la formule des membres, nous pouvons la valider et nous pouvons voir qu'elle est validée avec succès.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons enregistrer, réinitialiser ou annuler, et alors je vais annuler dans ce cas.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour obtenir un rôle commercial du Navigator, nous cliquerons sur l'icône Navigator et nous cliquerons sur les règles.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il ouvrira notre responsable de calcul de livres et il est également appelé des règles métier.'
# [Error] Attempt 1/10 failed for phrase: 'Il ouvrira notre responsable de calcul de livres et il est également appelé des règles métier.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1D00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.21 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Il ouvrira notre responsable de calcul de livres et il est également appelé des règles métier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vous pouvez voir que l'application EPM Cloud et l'expansion nous montrent l'EPBCS et actuellement nous allons créer la règle sous EPM FS.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Permettez-moi de sélectionner EPM FS et sous des actions, je peux soit créer une nouvelle règle, script, formule, je peux importer, je peux voir les propriétés.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans cette démo, je vais créer une règle.'
# [Error] Attempt 1/10 failed for phrase: 'Dans cette démo, je vais créer une règle.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1F40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.78 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Dans cette démo, je vais créer une règle.'
# [Error] Attempt 2/10 failed for phrase: 'Dans cette démo, je vais créer une règle.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B11C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.63 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Dans cette démo, je vais créer une règle.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Comme j'ai sélectionné la file d'attente et l'application, toutes ces informations sont présentées.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais sélectionner le rouge en créant une formule de membre avec ce nom et je vais cliquer sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il dira qu'il a créé, que nous voulons apporter des modifications.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais dire oui et une fois que nous avons créé, c'est la première page que nous allons voir et surtout les administrateurs commerciaux utilisent la vue de concepteur et il y a aussi une vue de script.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais sélectionner la vue du script.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous avons toutes les dimensions requises dont nous avons besoin ici et je vais actuellement copier les données de FY24 pour le scénario de plan fonctionnant à partir du décalage de l'allocation d'entité au compensation de l'allocation de l'entité de travail du plan FY23.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il s'agit d'une règle commerciale très fondamentale.'
# [Error] Attempt 1/10 failed for phrase: 'Il s'agit d'une règle commerciale très fondamentale.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1D90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.84 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Il s'agit d'une règle commerciale très fondamentale.'
# [Error] Attempt 2/10 failed for phrase: 'Il s'agit d'une règle commerciale très fondamentale.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B3020> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.26 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Il s'agit d'une règle commerciale très fondamentale.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons avoir des règles commerciales pour des scénarios complexes et toutes ces règles commerciales s'exécutent en quelques secondes.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais donc le valider et le sauver.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Une fois que je l'ai enregistré, je peux le déployer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Actuellement, je vais ouvrir un formulaire de données pour montrer comment fonctionne cette règle commerciale.'
# [Error] Attempt 1/10 failed for phrase: 'Actuellement, je vais ouvrir un formulaire de données pour montrer comment fonctionne cette règle commerciale.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B22A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.09 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Actuellement, je vais ouvrir un formulaire de données pour montrer comment fonctionne cette règle commerciale.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai déjà un formulaire ici et comme vous pouvez le voir, c'est FY23-24 et j'ai des données dans FY24 pour tous les quartiers et FY23.'
# [Error] Attempt 1/10 failed for phrase: 'J'ai déjà un formulaire ici et comme vous pouvez le voir, c'est FY23-24 et j'ai des données dans FY24 pour tous les quartiers et FY23.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2D50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.12 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'J'ai déjà un formulaire ici et comme vous pouvez le voir, c'est FY23-24 et j'ai des données dans FY24 pour tous les quartiers et FY23.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je n'ai pas de données pour cette intersection.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour copier des données, nous devons simplement exécuter la règle commerciale et il copiera les données de FY24 à 23 une fois que j'ai exécuté la règle.'
# [Error] Attempt 1/10 failed for phrase: 'Pour copier des données, nous devons simplement exécuter la règle commerciale et il copiera les données de FY24 à 23 une fois que j'ai exécuté la règle.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B0290> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.81 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Pour copier des données, nous devons simplement exécuter la règle commerciale et il copiera les données de FY24 à 23 une fois que j'ai exécuté la règle.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais aller à ma règle et cliquer sur ce bouton lance la règle commerciale.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais le lancer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons faire lancer cette règle commerciale à partir d'ici ou nous pouvons joindre cette règle commerciale à tout autre fait comme les formulaires de données des formulaires de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais cliquer sur Actualiser.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vous voyez comment les données sont copiées et elles sont remplies dans cette forme.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'L'exécuter à partir du gestionnaire CALC, je peux joindre la règle commerciale directement au formulaire et vérifier les options comme exécuter sur Enregistrer, exécuter sur le chargement.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Cela nous aide donc à exécuter les règles une fois que nous avons cliqué sur le bouton Enregistrer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également planifier la règle de l'entreprise dans nos automations et gérer dans le cadre des travaux quotidiens d'automatisation.'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également planifier la règle de l'entreprise dans nos automations et gérer dans le cadre des travaux quotidiens d'automatisation.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2A80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.76 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons également planifier la règle de l'entreprise dans nos automations et gérer dans le cadre des travaux quotidiens d'automatisation.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La sécurité peut être appliquée aux règles commerciales qui permettront de restreindre les utilisateurs et qui peuvent être effectuées en utilisant la sécurité des règles de l'entreprise.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais cliquer sur le formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour en savoir plus sur la sécurité, cliquez sur les outils et accédez au contrôle d'accès où nous pouvons créer des groupes pour gérer les utilisateurs au sein de ces groupes et nous avons des groupes définis gratuits qui définissent le mieux l'administrateur système, l'utilisateur de puissance, l'utilisateur et la visionneuse.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons voir la liste des utilisateurs ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons attribuer différents rôles à ces utilisateurs, ce qui les aidera à effectuer plus de tâches que nécessaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons attribuer des rôles supplémentaires aux groupes ou à l'utilisateur qui les aideront à créer ou à exécuter des intégrations, à gérer ou à approuver les gestionnaires de tâches à créer et à utiliser des formulaires ad hoc.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons exporter à partir de n'importe quelle instance et importer un format CSV avec la liste des utilisateurs et des groupes à partir de toute instance différente dans cette instance particulière.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais déplacer des détails sur la façon dont la sécurité joue un rôle majeur dans l'EPM.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vérifions la sécurité dimensionnelle.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour cette dimension particulière, nous avons des rôles de sécurité affectés à chaque niveau de membre qui ne permettra que des utilisateurs particuliers qui ont accès ou des groupes affectés à leur accéder.'
# [Error] Attempt 1/10 failed for phrase: 'Pour cette dimension particulière, nous avons des rôles de sécurité affectés à chaque niveau de membre qui ne permettra que des utilisateurs particuliers qui ont accès ou des groupes affectés à leur accéder.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2E70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.10 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Pour cette dimension particulière, nous avons des rôles de sécurité affectés à chaque niveau de membre qui ne permettra que des utilisateurs particuliers qui ont accès ou des groupes affectés à leur accéder.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons créer ou ajouter des utilisateurs et nous pouvons attribuer une lecture d'écriture et sans accès ainsi que des fonctions comme les enfants des enfants descendants du membre.'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons créer ou ajouter des utilisateurs et nous pouvons attribuer une lecture d'écriture et sans accès ainsi que des fonctions comme les enfants des enfants descendants du membre.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1F40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.93 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons créer ou ajouter des utilisateurs et nous pouvons attribuer une lecture d'écriture et sans accès ainsi que des fonctions comme les enfants des enfants descendants du membre.'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons créer ou ajouter des utilisateurs et nous pouvons attribuer une lecture d'écriture et sans accès ainsi que des fonctions comme les enfants des enfants descendants du membre.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B20F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.14 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Nous pouvons créer ou ajouter des utilisateurs et nous pouvons attribuer une lecture d'écriture et sans accès ainsi que des fonctions comme les enfants des enfants descendants du membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La sécurité attribue la sécurité des niveaux d'artefacts comme les formulaires de données, les rapports, les tableaux de bord, les tâches, les workflows.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Voyons comment nous pouvons attribuer la sécurité pour un formulaire de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais aller dans le dossier de démonstration et j'ai un formulaire et en cliquant sur cela, je vais ajouter un groupe et donc la conférence d'enregistrement du compte si je ajoute et leur donne les fonctions requises, ils pourront accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous allons maintenant examiner la sécurité au niveau des données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Les intersections de valeur peuvent vous aider à contrôler la saisie des données en définissant des combinaisons valides des membres de la dimension pour éviter les entrées de données non valides.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devons simplement définir les combinaisons et la sauver.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous avons également une sécurité au niveau cellulaire qui contrôle l'accès aux cellules individuelles en fonction des dimensions et des sélections de membres.'
# [Error] Attempt 1/10 failed for phrase: 'Nous avons également une sécurité au niveau cellulaire qui contrôle l'accès aux cellules individuelles en fonction des dimensions et des sélections de membres.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2F90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.32 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous avons également une sécurité au niveau cellulaire qui contrôle l'accès aux cellules individuelles en fonction des dimensions et des sélections de membres.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons créer une nouvelle ou une importation.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Comment créer et configurer un formulaire de données à partir de la page d'accueil Cliquez sur le plan de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Sous des actions, nous pouvons créer un ad hoc ou créer une forme.'
# [Error] Attempt 1/10 failed for phrase: 'Sous des actions, nous pouvons créer un ad hoc ou créer une forme.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B0440> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.35 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Sous des actions, nous pouvons créer un ad hoc ou créer une forme.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je cliquerai sur Créer un formulaire.'
# [Error] Attempt 1/10 failed for phrase: 'Je cliquerai sur Créer un formulaire.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1BE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.27 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Je cliquerai sur Créer un formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devons entrer le nom.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devrons sélectionner la file d'attente.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous aurons toutes les dimensions ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devons faire glisser et dessiner les dimensions sur les lignes et colonnes respectives.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également avoir des dimensions sur les pages.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devrons sélectionner les membres en conséquence.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_13.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Cliquer sur l'icône me donnera le sélecteur de membres et je peux ajouter le membre requis.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_14.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai la possibilité de personnaliser en fonction de la façon dont je veux voir les données si j'ai besoin de menus.'
# [Error] Attempt 1/10 failed for phrase: 'J'ai la possibilité de personnaliser en fonction de la façon dont je veux voir les données si j'ai besoin de menus.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1EB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.24 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'J'ai la possibilité de personnaliser en fonction de la façon dont je veux voir les données si j'ai besoin de menus.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_15.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Le sens nous aide à passer d'un formulaire à un autre juste en cliquant avec le bouton droit sur le formulaire de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'C'est là que nous pouvons ajouter une règle commerciale que nous avons créée pour cette application.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons dire comment nous voulons gérer cette règle commerciale.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans la disposition, nous pouvons voir différentes options si nous voulons supprimer les données, supprimer les lignes, supprimer les colonnes.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir des propriétés pour les dimensions si nous voulons voir le nom adieux au lieu de la hauteur du membre, description.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également définir les propriétés du segment qui est une propriété de ligne et la propriété de colonne et ce que nous voulons voir.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous avons également différentes options en termes de façon de voir les données sous cette forme particulière.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ont également des règles pour valider certaines conditions.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai créé le formulaire de données en conservant le produit des versions, le marché, la devise, le type d'usine dans le scénario de point de vue de la page.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans les colonnes, nous avons l'année, la période et le compte.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans les lignes, nous avons l'entité.'
# [Error] Attempt 1/10 failed for phrase: 'Dans les lignes, nous avons l'entité.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B10A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.48 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Dans les lignes, nous avons l'entité.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'
# [Error] Attempt 1/10 failed for phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B10A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.92 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'
# [Error] Attempt 2/10 failed for phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2960> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.40 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ainsi, en sélectionnant l'icône du sélecteur de membres, nous voyons les membres mais aussi nous voyons des variables.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir les variables qui nous aideront à préparer dynamiquement la forme.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai réglé une condition ici pour la ligne 3.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_14.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Donc, si la valeur de la devise est supérieure à 6000, le TEL doit être en rouge.'
# [Error] Attempt 1/10 failed for phrase: 'Donc, si la valeur de la devise est supérieure à 6000, le TEL doit être en rouge.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B1D00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.34 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Donc, si la valeur de la devise est supérieure à 6000, le TEL doit être en rouge.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons valider la condition et nous obtiendrons la boîte de dialogue.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous cliquerons sur OK.'
# [Error] Attempt 1/10 failed for phrase: 'Nous cliquerons sur OK.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2A80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.59 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous cliquerons sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous cliquerons à nouveau sur OK.'
# [Error] Attempt 1/10 failed for phrase: 'Nous cliquerons à nouveau sur OK.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B2E70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.60 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous cliquerons à nouveau sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais enregistrer ce formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je ferai ce formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ceci est la forme que nous avons modifiée.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais l'ouvrir et l'expansion.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je peux voir que lorsque j'en avais 6000, il a été mis en évidence selon la condition et je peux développer plus.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai également les options pour ajuster les cellules comme je peux dire que c'est 10%.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je peux donc avoir une valeur négative positive ou un pourcentage et cliquer sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La cellule est mise à jour et nous pouvons voir comment la valeur est modifiée pour l'année totale.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Chaque fois que la cellule est mise à jour en jaune lorsque nous les enregistrons, les données sont enregistrées immédiatement et nous pouvons voir comment les données sont reflétées.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Tout comme Excel, nous pouvons faire glisser des données et apporter des données à toutes ces lignes afin que toutes les données du trimestre soient mises à jour avec le total et que je vais les enregistrer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je veux également faire réfléchir ces données pour tous les autres chiffres et pour ceux-ci, je souhaite augmenter les données de 20%.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Et pour cela, je vais augmenter les données de 50%.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai également la possibilité de distribuer pour copier coller les données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données en termes de façon dont je souhaite l'ajuster.'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données en termes de façon dont je souhaite l'ajuster.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000187EB5B24E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.35 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données en termes de façon dont je souhaite l'ajuster.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Est-ce proportionnel ou est-il uniforme?'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Disons donc pour le trimestre du trimestre trois car j'ai des données pour juillet de septembre, je vais ajuster les données proportionnellement et elle est ajustée par 1000.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vous pouvez voir comment les données sont ajustées.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également ajouter des pièces jointes, ajouter des commentaires et joindre les détails de support de nos fichiers locaux et le publier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'L'utilisateur sera en mesure de voir le nom d'utilisateur, la date à laquelle le commentaire a été fait, l'heure et ce qui est le commentaire et cela peut aller.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ainsi, quand un utilisateur peut faire des commentaires qui ont accès au formulaire et à la cellule, quel est le commentaire?'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il est en bleu, ce qui signifie que nous avons une pièce jointe ou un commentaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également définir la préférence des outils.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir la langue et les zones.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir comment nous voulons voir les données,'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La précision, les suppressions.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous définirons les variables utilisateur à partir d'ici en sélectionnant le sélecteur de membre et en sélectionnant le membre respectif et en cliquant sur OK, puis en le enregistrant.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_1.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250426_083624\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250426_083624\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250426_083624\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250426_083624\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %% [markdown]
# 26 apr to solve poids par phrase

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up





def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 0.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides





def parse_review_file(review_file_path):
    """
    Lit le review file et retourne une liste de dicts, un par segment, avec :
      - start_s, end_s : début / fin du segment en secondes
      - original : texte original en anglais
      - final_translation : texte final en français
      - voice_speed : vitesse synthèse (e.g. "+0%")
      - pre_silence, post_silence : en millisecondes
      - inter_phrase_silences : liste de silences entre phrases (en ms)
      - phrases : liste de phrases françaises à synthétiser
    """
    text = open(review_file_path, encoding="utf-8").read()
    # split sur toute ligne de 3+ tirets
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header_re = re.compile(
        r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)", re.I
    )

    for blk in blocks:
        if blk.startswith("Translation Review File"):
            continue
        m = header_re.search(blk)
        if not m:
            continue

        start_s = float(m.group(1))
        end_s   = float(m.group(2))

        # valeurs par défaut
        orig    = None
        ft      = None
        vs      = "+0%"
        pre     = 0.0
        post    = 100.0
        inter   = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()
            elif line.startswith("**Final Translation:**"):
                ft   = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs   = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try:
                    pre = float(line.split("**Pre-Silence:**",1)[1].strip())
                except ValueError:
                    pass
            elif line.startswith("**Post-Silence:**"):
                try:
                    post = float(line.split("**Post-Silence:**",1)[1].strip())
                except ValueError:
                    pass
            elif line.startswith("**Inter-Phrase-Silence:**"):
                vals = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if vals:
                    try:
                        raw = [float(x) for x in vals.split(",")]
                        # clamp à [0, 5000] ms pour éviter les excès
                        inter = [max(0, min(v, 5000)) for v in raw]
                    except ValueError:
                        inter = []

        if orig is None:
            raise RuntimeError(f"Segment sans **Original** dans {review_file_path}")
        if ft is None:
            ft = orig  # fallback

        # découpe finale en phrases françaises (accents et majuscules prises en compte)
        phrases = re.split(r"(?<=[\.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", ft)
        phrases = [p.strip() for p in phrases if p.strip()]

        segments.append({
            "start_s":               start_s,
            "end_s":                 end_s,
            "original":              orig,
            "final_translation":     ft,
            "voice_speed":           vs,
            "pre_silence":           pre,
            "post_silence":          post,
            "inter_phrase_silences": inter,
            "phrases":               phrases
        })

    print(f"✅ Parsed {len(segments)} segments from review file.")
    return segments

def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%", max_retries: int = 10):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    Note: In Edge TTS v7.0.0 the 'session' parameter is not supported.
    """
    for attempt in range(max_retries):
        try:
            # Create a new session for each attempt.
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt+1}: Synthesizing phrase: '{phrase}'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.uniform(0, 1)
            print(f"[Error] Attempt {attempt+1}/{max_retries} failed for phrase: '{phrase}'. Exception: {e}")
            print(f"[Debug] Retrying in {wait_time:.2f} seconds...")
            await asyncio.sleep(wait_time)
    raise Exception(f"Failed to synthesize phrase after {max_retries} attempts: {phrase}")

async def synthesize_phrase(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%"):
    await robust_synthesize_phrase(phrase, output_path, voice, rate)

# For backward compatibility:
async def synthesize_phrase_edge_hybrid(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%"):
    await synthesize_phrase(phrase, output_path, voice, rate)

def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")


def merge_short_phrases(phrases: list[str],
                        weights: list[float],
                        min_chars: int = 30
                       ) -> tuple[list[str], list[float]]:
    """
    Parcourt la liste `phrases` et si une phrase fait moins de `min_chars`
    caractères, on la fusionne avec la phrase précédente, en ajustant les poids.
    Retourne (phrases_fusionnees, poids_normalises).
    """
    if not phrases:
        return [], []

    merged_phrases = [phrases[0]]
    merged_weights = [weights[0]]

    for ph, w in zip(phrases[1:], weights[1:]):
        if len(ph) < min_chars:
            # on fusionne dans l'élément courant
            merged_phrases[-1] += " " + ph
            merged_weights[-1] += w
        else:
            merged_phrases.append(ph)
            merged_weights.append(w)

    # renormalisation
    total = sum(merged_weights)
    if total > 0:
        merged_weights = [w/total for w in merged_weights]

    return merged_phrases, merged_weights



def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) Regroupe les sous-titres par phrases.
    2) Scinde les groupes trop longs.
    3) Écrit le fichier de review en indiquant :
       - pre / post silence
       - budget total pour inter-phrases
       - inter-phrase-silence par défaut (0 pour chaque intervalle)
    """
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regroupement par phrase
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, current = [], []
    for sub in subs:
        current.append(sub)
        if sentence_end.search(sub.text):
            groups.append(current)
            current = []
    if current:
        groups.append(current)

    # 2) Découpe si trop long & enforcement ponctuation
    from itertools import chain
    def split_long_groups(groups, max_s):
        new = []
        for g in groups:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end-start <= max_s:
                new.append(g)
            else:
                mid = len(g)//2
                new.extend([g[:mid], g[mid:]])
        return new
    groups = split_long_groups(groups, max_group_duration_secs)

    def enforce_punctuation_boundaries(groups):
        i = 0
        while i < len(groups):
            last = groups[i][-1].text.strip()
            if not re.search(r"[.!?,;:]$", last):
                if i+1 < len(groups):
                    groups[i] += groups.pop(i+1)
                else:
                    groups[i][-1].text += "."
            else:
                i += 1
        return groups
    groups = enforce_punctuation_boundaries(groups)

    # 3) Write review file
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Edit the **Final Translation** below. You can also adjust:\n")
        f.write("- **Voice Speed:** -10% to +10%\n")
        f.write("- **Pre-Silence/Post-Silence:** in milliseconds\n")
        f.write("- **Inter-Phrase-Silence:** comma-separated ms between phrases\n")
        f.write("  (must have one fewer value than phrases)\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal/1000
            end_s   = group[-1].end.ordinal/1000
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # découpe en phrases (Final Translation automatique)
            phrases = re.split(
                r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])",
                auto_tr
            )
            phrases = [p.strip() for p in phrases if p.strip()]

            # budget inter-phrases
            total_ms     = int((end_s - start_s)*1000)
            pre_ms, post_ms = 0, 0
            budget_inter = max(0, total_ms - pre_ms - post_ms)

            # silences par défaut = 0
            inter_default = ",".join("0" for _ in range(len(phrases)-1))

            # écriture
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s):\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** +0%\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Budget total Inter-Phrase-Silence (ms):** {budget_inter}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_default}\n")
            f.write("----------------------------------------------------------------\n\n")

    print(f"✅ Review file created at: {review_file_path}  ({len(groups)} segments)")
    input("Type 'Y' when ready to continue: ")
    return groups


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # ─── 1) Génération / mise à jour du review file ───
    # Cette fonction va demander à l'utilisateur de valider ou modifier le fichier.
    groups = generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )

    # ─── 2) Lecture du review file enrichi ───
    # parse_review_file récupère start_s, end_s, final_translation, voice_speed, pre/post et inter-phrase.
    segments = parse_review_file(review_file_path)

    # ─── 3) On s'assure d'avoir autant d'overrides que de groupes ───
    default_ov = {
        "final_translation":    None,
        "voice_speed":          "+0%",
        "pre_silence":          0.0,
        "post_silence":         100.0,
        "inter_phrase_silences": []
    }
    # segments contient déjà tous les champs dont on a besoin
    # Si vous voulez quand même un fallback, vous pouvez l'ajouter ici.

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        # on récupère tout directement depuis seg dict
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms= int((end_s - start_s)*1000)

        text       = seg.get("final_translation", seg.get("original", ""))
        rate       = seg.get("voice_speed", "+0%")
        pre_ms     = seg.get("pre_silence", 0.0)
        post_ms    = seg.get("post_silence", 100.0)
        inter_user = seg.get("inter_phrase_silences", [])
                # découpage en phrases + poids
        # phrases   = split_french_phrases(text)
        # weights   = calculate_phrase_weights(text, phrases)
        
        # — 3) split en phrases + calcul de poids initial
        phrases = split_french_phrases(text)
        weights = calculate_phrase_weights(text, phrases)

        # — 4) fusion itérative de TOUTES les phrases trop courtes
        #     min_chars = seuil en nombre de caractères pour considérer
        #     qu'une phrase est "trop petite" et doit fusionner
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=30)

        # — 5) recalcul de content_ms (inchangé)
        content_ms = max(0, total_ms - pre_ms - post_ms)
        

        # synth + ajustements identiques à votre pipeline
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur      = content_ms * weights[i] / 1000.0
            tmp_path = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await synthesize_phrase_edge_hybrid(ph, tmp_path, voice="fr-FR-DeniseNeural", rate=rate)
            aud = AudioSegment.from_mp3(tmp_path); os.remove(tmp_path)
            aud = adjust_audio_duration(aud, dur)
            phrase_audios.append(aud)

        # # anti-dépassement TTS seul
        # sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)
        # if sum_tts > content_ms and sum_tts>0:
        #     factor = content_ms / sum_tts
        #     phrase_audios = [change_playback_speed(a, factor) for a in phrase_audios]
        #     sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)

        # # anti-dépassement silences users
        # available = content_ms - sum_tts
        # if available <= 0:
        #     inter_applied = [0]*len(inter_user)
        # elif sum(inter_user) <= available:
        #     inter_applied = inter_user.copy()
        # else:
        #     factor = available / sum(inter_user)
        #     inter_applied = [int(ms*factor) for ms in inter_user]
        
        # ─── ANTI-DÉPASSEMENT : PRIORITÉ AUX SILENCES UTILISATEUR ───
        sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)
        sum_int = sum(inter_user)

        # Si TTS + silences > budget, on réduit d'abord le TTS
        if sum_tts + sum_int > content_ms and sum_tts > 0:
            factor_tts = max(0.0, (content_ms - sum_int) / sum_tts)
            phrase_audios = [
                change_playback_speed(aud, factor_tts)
                for aud in phrase_audios
            ]

        # On applique exactement les silences demandés par l'utilisateur
        inter_applied = inter_user.copy()

        # rebuild + pre/post silence + strip internal + pad/trim identique...
        seq = []
        for i, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq: seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        non = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS-16)
        if non:
            seg_audio = seg_audio[non[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # mesures pour debug
        non2 = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS-16)
        start_audio_ms = non2[0][0] if non2 else pre_ms
        end_audio_ms   = non2[-1][1] if non2 else (total_ms-post_ms)
        abs_start_a = int(start_s*1000)+start_audio_ms
        abs_end_a   = int(start_s*1000)+end_audio_ms
        abs_start_v = int(start_s*1000)
        abs_end_v   = int(end_s*1000)
        decal_start = abs_start_a - abs_start_v
        decal_end   = abs_end_a   - abs_end_v

        # éventuel warp global
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s-start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s-start_s)/gen_dur)

        # mix sur timeline
        start_ms = int(start_s*1000)
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms-len(combined)))
        combined += seg_audio

        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"inter_user={inter_user} → inter_applied={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms, "
            f"phrases={phrases}\n"
        )

    # export
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")
    return output_audio_path

# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file created at: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250427_131337\translation_review.txt  (27 segments)
# ✅ Parsed 27 segments from review file.
# [Debug] Attempt 1: Synthesizing phrase: 'Nous allons voir les configurations de l'application EPM.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous verrons comment créer une règle métier ou une formule de membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous verrons comment la sécurité fonctionne dans l'application EPM et nous couvrirons comment créer et configurer des formulaires de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La sécurité au niveau de EPM comprendra la sécurité dimensionnelle, la sécurité des artefacts, la sécurité par tâches ou le flux de travail, la sécurité des règles métier et la sécurité des données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Maintenant, je vais sélectionner le cube, et pour la dimension du compte, je vais rechercher le membre pour lequel je souhaite mettre à jour la formule du membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Une fois que le membre est mis en évidence, nous pouvons modifier les propriétés de formule de membres.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons sélectionner le cube pour voir la formule du membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La formule des membres est utilisée n'importe où dans l'application.'
# [Error] Attempt 1/10 failed for phrase: 'La formule des membres est utilisée n'importe où dans l'application.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932CE60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.32 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'La formule des membres est utilisée n'importe où dans l'application.'
# [Error] Attempt 2/10 failed for phrase: 'La formule des membres est utilisée n'importe où dans l'application.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932D0A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.18 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'La formule des membres est utilisée n'importe où dans l'application.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ici, le matériel OFS sera divisé par le volume OFS.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Une fois que nous avons la formule des membres, nous pouvons la valider et nous pouvons voir qu'elle est validée avec succès.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons enregistrer, réinitialiser ou annuler. Je vais annuler dans ce cas.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour voir une règle métier, cliquer sur l'icône Navigateur et cliquer sur Règles.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Calculation Manager, qui est également appelé règles métier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vous pouvez voir l'application EPM Cloud.'
# [Error] Attempt 1/10 failed for phrase: 'Vous pouvez voir l'application EPM Cloud.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E060> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.85 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Vous pouvez voir l'application EPM Cloud.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'L'expansion nous montrera EPBCS, et nous allons créer la règle sous OEP FS.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Permettez-moi de sélectionner OEP FS et sous actions, je peux soit créer une nouvelle règle, un script ou une formule.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je peux importer et je peux voir les propriétés.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans cette démo, je vais créer une règle.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Comme j'ai sélectionné le cube et l'application, toutes ces informations sont prépopulées.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais sélectionner Règles comme type d'objet, je vais indiquer un nom à la règle et je vais cliquer sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Le système indiquera que la règle a été créé et qu'on peut y apporter des modifications. Je vais cliquer sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ceci est la première page que nous allons voir lors de la création d'une règle.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Les administrateurs utilisent surtout la vue de concepteur.'
# [Error] Attempt 1/10 failed for phrase: 'Les administrateurs utilisent surtout la vue de concepteur.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932D1C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.59 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Les administrateurs utilisent surtout la vue de concepteur.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il y a aussi une vue de script.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais sélectionner la vue de script.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous avons toutes les dimensions requises dont nous avons besoin ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_14.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La règle va copier les données de FY24 pour le scénario plan, working, de la contrepartie de l'allocation d'entité, au plan FY23, working, contrepartie de l'allocation d'entité.'
# [Error] Attempt 1/10 failed for phrase: 'La règle va copier les données de FY24 pour le scénario plan, working, de la contrepartie de l'allocation d'entité, au plan FY23, working, contrepartie de l'allocation d'entité.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E960> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.80 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'La règle va copier les données de FY24 pour le scénario plan, working, de la contrepartie de l'allocation d'entité, au plan FY23, working, contrepartie de l'allocation d'entité.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_15.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il s'agit d'une règle métier de base.'
# [Error] Attempt 1/10 failed for phrase: 'Il s'agit d'une règle métier de base.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932EDE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.05 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Il s'agit d'une règle métier de base.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_16.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons avoir des règles métier pour des scénarios complexes et toutes ces règles métiers s'exécutent en quelques secondes.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_17.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais donc le valider et l'enregistrer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_18.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Une fois que je l'ai enregistré, je peux la déployer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Maintenant, je vais ouvrir un formulaire de données pour montrer comment fonctionne cette règle métier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai déjà un formulaire ici et comme vous pouvez le voir, c'est FY23-24 et j'ai des données dans FY24 pour tous les trimestres.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour FY23, je n'ai pas de données pour cette intersection.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour copier des données, nous devons simplement exécuter la règle métier et il copiera les données de FY24 à FY23.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais aller à ma règle et cliquer sur ce bouton pour lancer la règle métier. Je vais la lancer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons faire lancer cette règle métier à partir d'ici, ou nous pouvons joindre cette règle métier à tout autre artéfact, comme les formulaires de données ou tableau de bord.'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons faire lancer cette règle métier à partir d'ici, ou nous pouvons joindre cette règle métier à tout autre artéfact, comme les formulaires de données ou tableau de bord.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F020> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.58 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons faire lancer cette règle métier à partir d'ici, ou nous pouvons joindre cette règle métier à tout autre artéfact, comme les formulaires de données ou tableau de bord.'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons faire lancer cette règle métier à partir d'ici, ou nous pouvons joindre cette règle métier à tout autre artéfact, comme les formulaires de données ou tableau de bord.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932EBA0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.17 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Nous pouvons faire lancer cette règle métier à partir d'ici, ou nous pouvons joindre cette règle métier à tout autre artéfact, comme les formulaires de données ou tableau de bord.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais cliquer sur Actualiser.'
# [Error] Attempt 1/10 failed for phrase: 'Je vais cliquer sur Actualiser.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932DEB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.66 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Je vais cliquer sur Actualiser.'
# [Error] Attempt 2/10 failed for phrase: 'Je vais cliquer sur Actualiser.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932ECC0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.82 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Je vais cliquer sur Actualiser.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vous voyez comment les données sont copiées et elles sont remplies dans ce formulaire.'
# [Error] Attempt 1/10 failed for phrase: 'Vous voyez comment les données sont copiées et elles sont remplies dans ce formulaire.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E960> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.07 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Vous voyez comment les données sont copiées et elles sont remplies dans ce formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je peux l'exécuter à partir du calculation Manager, je peux joindre la règle métier directement au formulaire et vérifier les options comme, exécuter à l'enregistrement ou exécuter au chargement.'
# [Error] Attempt 1/10 failed for phrase: 'Je peux l'exécuter à partir du calculation Manager, je peux joindre la règle métier directement au formulaire et vérifier les options comme, exécuter à l'enregistrement ou exécuter au chargement.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932D1C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.78 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Je peux l'exécuter à partir du calculation Manager, je peux joindre la règle métier directement au formulaire et vérifier les options comme, exécuter à l'enregistrement ou exécuter au chargement.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Cela nous aide donc à exécuter les règles une fois que nous avons cliqué sur le bouton Enregistrer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également céduler la règle métier dans nos automations et gérer dans le cadre des travaux quotidiens d'automatisation.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La sécurité peut être appliquée aux règles métiers qui permettront de restreindre les utilisateurs.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'
# [Error] Attempt 1/10 failed for phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E210> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.76 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'
# [Error] Attempt 2/10 failed for phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E2A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.44 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'
# [Error] Attempt 3/10 failed for phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932D010> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.85 seconds...
# [Debug] Attempt 4: Synthesizing phrase: 'Ceci peut être fait en utilisant la sécurité des règles métier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour en savoir plus sur la sécurité, cliquez sur Outils et accédez au contrôle d'accès où nous pouvons créer des groupes pour gérer les utilisateurs.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il y a aussi des groupes définis par défaut pour les administrateurs système, les super utilisateurs, les utilisateurs et les utilisateurs en lecture seule.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons voir la liste des utilisateurs ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons attribuer différents rôles à ces utilisateurs, ce qui les aideront à effectuer plusieurs tâches.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons attribuer des rôles supplémentaires aux groupes ou à l'utilisateur qui les aideront à créer ou à exécuter des intégrations, à gérer ou à approuver les gestionnaires de tâches, à créer et à utiliser des formulaires ad hoc.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons exporter à partir de n'importe quelle instance et importer un format CSV avec la liste des utilisateurs et des groupes, à partir de toute instance différente dans cette instance particulière.'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons exporter à partir de n'importe quelle instance et importer un format CSV avec la liste des utilisateurs et des groupes, à partir de toute instance différente dans cette instance particulière.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932CB90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.55 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons exporter à partir de n'importe quelle instance et importer un format CSV avec la liste des utilisateurs et des groupes, à partir de toute instance différente dans cette instance particulière.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais montrer plus de détails sur la façon dont la sécurité joue un rôle majeur dans EPM.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Regardons la sécurité dimensionnelle.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour cette dimension particulière, nous avons des rôles de sécurité affectés à chaque niveau de membre, ce qui donnera accès seulement à des utilisateurs particuliers ou à des groupes assignés.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons créer ou ajouter des utilisateurs et nous pouvons attribuer des accès en lecture, écriture ou sans accès, ainsi que des fonctions comme les membres, les enfants du membre, ou les descendants du membre.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La sécurité attribue la sécurité des niveaux d'artefacts comme les formulaires de données, les rapports, les tableaux de bord, les tâches et les flux.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Voyons comment nous pouvons attribuer la sécurité pour un formulaire de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais aller dans le dossier Démo et j'ai un formulaire et en cliquant sur ceci, je vais ajouter un groupe.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Si j'ajoute le groupe Account Recon, lecture, et leur donne les fonctions requises, ils pourront accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.'
# [Error] Attempt 1/10 failed for phrase: 'Si j'ajoute le groupe Account Recon, lecture, et leur donne les fonctions requises, ils pourront accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E600> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.59 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Si j'ajoute le groupe Account Recon, lecture, et leur donne les fonctions requises, ils pourront accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.'
# [Error] Attempt 2/10 failed for phrase: 'Si j'ajoute le groupe Account Recon, lecture, et leur donne les fonctions requises, ils pourront accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.94 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Si j'ajoute le groupe Account Recon, lecture, et leur donne les fonctions requises, ils pourront accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous allons maintenant regarder la sécurité au niveau des données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Les intersections valides peuvent vous aider à contrôler la saisie des données en définissant des combinaisons valides des membres de la dimension, pour éviter les entrées de données non valides.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devons simplement définir les combinaisons et l'enregistrer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous avons également une sécurité au niveau des cellules, qui contrôle l'accès aux cellules individuelles en fonction des dimensions et des sélections de membres.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons créer une nouvelle sécurité ou faire une importation.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Voyons comment créer et configurer un formulaire de données. À partir de la page d'accueil cliquez sur la carte Données.'
# [Error] Attempt 1/10 failed for phrase: 'Voyons comment créer et configurer un formulaire de données. À partir de la page d'accueil cliquez sur la carte Données.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932CE60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.58 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Voyons comment créer et configurer un formulaire de données. À partir de la page d'accueil cliquez sur la carte Données.'
# [Error] Attempt 2/10 failed for phrase: 'Voyons comment créer et configurer un formulaire de données. À partir de la page d'accueil cliquez sur la carte Données.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E2A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.11 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Voyons comment créer et configurer un formulaire de données. À partir de la page d'accueil cliquez sur la carte Données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Sous actions, nous pouvons créer un ad hoc ou créer un formulaire.'
# [Error] Attempt 1/10 failed for phrase: 'Sous actions, nous pouvons créer un ad hoc ou créer un formulaire.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932ED50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.95 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Sous actions, nous pouvons créer un ad hoc ou créer un formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais cliquer sur Créer un formulaire. Nous devons entrer le nom.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devrons sélectionner le cube.'
# [Error] Attempt 1/10 failed for phrase: 'Nous devrons sélectionner le cube.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F140> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.25 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous devrons sélectionner le cube.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous aurons toutes les dimensions ici.'
# [Error] Attempt 1/10 failed for phrase: 'Nous aurons toutes les dimensions ici.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F2F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.74 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous aurons toutes les dimensions ici.'
# [Error] Attempt 2/10 failed for phrase: 'Nous aurons toutes les dimensions ici.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E960> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.65 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Nous aurons toutes les dimensions ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devons faire glisser les dimensions sur les lignes et colonnes respectives.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également avoir des dimensions sur les pages.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous devrons sélectionner les membres en conséquence.'
# [Error] Attempt 1/10 failed for phrase: 'Nous devrons sélectionner les membres en conséquence.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E7B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.73 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous devrons sélectionner les membres en conséquence.'
# [Error] Attempt 2/10 failed for phrase: 'Nous devrons sélectionner les membres en conséquence.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932D1C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.55 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Nous devrons sélectionner les membres en conséquence.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Cliquer sur l'icône me donnera le sélecteur de membres et je peux ajouter le membre requis.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_13.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai la possibilité de personnaliser en fonction de la façon dont je veux voir les données si j'ai besoin de menus.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_14.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Les menus nous aident à passer d'un formulaire à un autre juste en cliquant avec le bouton droit sur le formulaire de données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'C'est là que nous pouvons ajouter une règle métier que nous avons créée pour cette application.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons dire comment nous voulons gérer cette règle métier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans la disposition, nous pouvons voir différentes options si nous voulons supprimer les données, supprimer les lignes, supprimer les colonnes.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir des propriétés pour les dimensions si nous voulons voir l'alias du membre au lieu du nom du membre, masquer le membre, voir la description.'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir des propriétés pour les dimensions si nous voulons voir l'alias du membre au lieu du nom du membre, masquer le membre, voir la description.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E4E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.23 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons définir des propriétés pour les dimensions si nous voulons voir l'alias du membre au lieu du nom du membre, masquer le membre, voir la description.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également définir les propriétés de segment qui est une propriété de ligne et la propriété de colonne et ce que nous voulons voir.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous avons également différentes options en termes de façon de voir les données sous ce formulaire particulier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Il y a également des règles pour valider certaines conditions.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai créé le formulaire de données en conservant la version, le produit, le marché, la devise et le type d'usine dans le point de vue et le scénario dans la page.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans les colonnes, nous avons l'année, la période et le compte.'
# [Error] Attempt 1/10 failed for phrase: 'Dans les colonnes, nous avons l'année, la période et le compte.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F530> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.86 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Dans les colonnes, nous avons l'année, la période et le compte.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Dans les lignes, nous avons l'entité.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'
# [Error] Attempt 1/10 failed for phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E7B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.11 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'
# [Error] Attempt 2/10 failed for phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932CF80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.18 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'J'ai utilisé une variable de substitution ou une variable utilisateur ici.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ainsi, en sélectionnant l'icône du sélecteur de membres, nous voyons les membres mais aussi nous voyons des variables.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir les variables qui nous aideront à préparer dynamiquement le formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai mis une condition ici pour la ligne 3.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_14.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Donc, si la valeur de la devise est supérieure à 6000, la cellule doit être en rouge.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons valider la condition et nous obtiendrons la boîte de dialogue. Nous cliquerons sur OK.'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons valider la condition et nous obtiendrons la boîte de dialogue. Nous cliquerons sur OK.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F530> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.61 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons valider la condition et nous obtiendrons la boîte de dialogue. Nous cliquerons sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous cliquerons à nouveau sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je vais enregistrer ce formulaire. Je vais fermer ce formulaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ceci est le formulaire que nous avons modifiée. Je vais l'ouvrir.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'En développant l'année, je peux voir que le montant de 6000 a été mis en évidence selon la condition et je peux développer plus.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai également l'option d'ajuster les cellules comme je peux dire que c'est un ajustement de 10%.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je peux donc avoir une valeur négative, positive ou un pourcentage. Je vais cliquer sur OK.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La cellule est mise à jour et nous pouvons voir comment la valeur est modifiée pour l'année totale.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Chaque fois que la cellule est mise à jour en jaune, lorsque nous enregistrons, les données sont enregistrées immédiatement et nous pouvons voir comment les données sont reflétées.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Tout comme Excel, nous pouvons faire glisser des données sur toutes ces lignes ou colonnes afin que toutes les données du premier trimestre et le total de l'année soient mis à jour. Je vais les enregistrer.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Je veux également refléter ces données pour tous les autres chiffres.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Pour celles-ci, je vais augmenter les données de 20%.'
# [Error] Attempt 1/10 failed for phrase: 'Pour celles-ci, je vais augmenter les données de 20%.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E060> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.85 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Pour celles-ci, je vais augmenter les données de 20%.'
# [Error] Attempt 2/10 failed for phrase: 'Pour celles-ci, je vais augmenter les données de 20%.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932CEF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.76 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'Pour celles-ci, je vais augmenter les données de 20%.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Et pour cela, je vais augmenter les données de 50%.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai également la possibilité de copier et coller les données.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données de la façon dont je souhaite l'ajuster.'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données de la façon dont je souhaite l'ajuster.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E180> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.72 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données de la façon dont je souhaite l'ajuster.'
# [Error] Attempt 2/10 failed for phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données de la façon dont je souhaite l'ajuster.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E0F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.55 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'J'ai également la possibilité d'ajuster le niveau de la grille de données de la façon dont je souhaite l'ajuster.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Est-ce un ajustement proportionnel ou un ajustement uniforme?'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Disons donc pour le troisième trimestre où j'ai des données pour juillet, août et septembre, je vais ajuster les données proportionnellement et faire un ajustement de 1000.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Vous pouvez voir comment les données sont ajustées.'
# [Error] Attempt 1/10 failed for phrase: 'Vous pouvez voir comment les données sont ajustées.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F0B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.45 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Vous pouvez voir comment les données sont ajustées.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également ajouter des pièces jointes, ajouter des commentaires et joindre les détails de support de nos fichiers locaux et le publier.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'L'utilisateur sera en mesure de voir le nom d'utilisateur, la date à laquelle le commentaire a été fait, l'heure et le commentaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Ainsi, un utilisateur peut faire des commentaires s'il a accès au formulaire et à la cellule.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Lorsqu'un icône bleu est visible sur la cellule, ceci signifie que nous avons une pièce jointe ou un commentaire.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons également définir les préférences à partir des outils.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir la langue et les zones.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous pouvons définir la façon dont nous voulons voir les données,'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir la façon dont nous voulons voir les données,'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F0B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.80 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous pouvons définir la façon dont nous voulons voir les données,'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'La précision, les suppressions.'
# [Error] Attempt 1/10 failed for phrase: 'La précision, les suppressions.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932E7B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.02 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'La précision, les suppressions.'
# [Error] Attempt 2/10 failed for phrase: 'La précision, les suppressions.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932F5C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.70 seconds...
# [Debug] Attempt 3: Synthesizing phrase: 'La précision, les suppressions.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# [Debug] Attempt 1: Synthesizing phrase: 'Nous définirons les variables utilisateur à partir d'ici en sélectionnant le sélecteur de membre et en sélectionnant le membre respectif et en cliquant sur OK, puis en l'enregistrant.'
# [Error] Attempt 1/10 failed for phrase: 'Nous définirons les variables utilisateur à partir d'ici en sélectionnant le sélecteur de membre et en sélectionnant le membre respectif et en cliquant sur OK, puis en l'enregistrant.'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CC0932DE20> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 1.24 seconds...
# [Debug] Attempt 2: Synthesizing phrase: 'Nous définirons les variables utilisateur à partir d'ici en sélectionnant le sélecteur de membre et en sélectionnant le membre respectif et en cliquant sur OK, puis en l'enregistrant.'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_1.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250427_131337\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250427_131337\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250427_131337\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250427_131337\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %% [markdown]
# 28 APR 15h30

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.2_Flux de navigation_Avr_08_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up



def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")



def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) On regroupe et on split/merge les sous-titres exactement
       comme le fera l'audio.
    2) On écrit un review file où l'on affiche :
       - phrase par phrase (la liste exacte)
       - pre / post silence
       - voice speed
    Pas d’Inter-Phrase-Silence à remplir par l’utilisateur.
    """
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) regrouper par phrase
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text):
            groups.append(cur); cur = []
    if cur: groups.append(cur)

    # 2) split long + enforce punctuation
    def split_long(gs, max_s):
        out = []
        for g in gs:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end - start <= max_s:
                out.append(g)
            else:
                mid = len(g)//2
                out.extend([g[:mid], g[mid:]])
        return out
    groups = split_long(groups, max_group_duration_secs)

    i = 0
    while i < len(groups):
        if not re.search(r"[.!?,;:]$", groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 3) écrire le fichier de review
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, **Start-Offset:**, **End-Offset:** \n")
        f.write("mais **ne touchez pas** à la liste des phrases.\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal/1000
            end_s   = group[-1].end.ordinal/1000
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # découpe en phrases & merge_short_phrases
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]
            # appliquer merge_short_phrases avec vos seuils
            weights = calculate_phrase_weights(auto_tr, phrases)
            phrases, weights = merge_short_phrases(phrases, weights, min_chars=30, max_chars=90)

            total_ms = int((end_s - start_s)*1000)
            pre_ms, post_ms = 0, 100
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** +0%\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            # champs d’offset manuels, initialisés à 0
            f.write(f"**Start-Offset:** 0\n")
            f.write(f"**End-Offset:** 0\n")
            # f.write("**Phrases:**\n")
            # for ph in phrases:
            #     f.write(f"- {ph}\n")
            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Review file créé : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")
    return  # on n’a plus besoin de renvoyer les groupes bruts


def parse_review_file(review_file_path):
    """
    Lit le review file écrit ci-dessus et
    renvoie une liste de dicts avec :
      - start_s, end_s, final_translation, voice_speed
      - pre_silence, post_silence, phrases (list)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        ft, vs, pre, post = None, "+0%", 0.0, 100.0
        orig = None
        start_offset = 0 
        phrases = []
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                 # offset en millisecondes à ajouter au start
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])                
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
            elif line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()

        segments.append({
            "start_s":           start_s,
            "end_s":             end_s,
            "original":          orig,
            "final_translation": ft or orig,
            "voice_speed":       vs,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "phrases":           phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # ─── 1) Génération / mise à jour du review file ───
    groups = generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )

    # ─── 2) Lecture du review file enrichi ───
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        # ─── 3) Récupérations de base ───
        start_s  = seg["start_s"]
        end_s    = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        text   = seg["final_translation"]
        rate   = seg["voice_speed"]
        pre_ms = seg["pre_silence"]
        post_ms= seg["post_silence"]

        # ─── 4) Découpage en phrases + poids ───
        #phrases = split_french_phrases(text)
        #weights = calculate_phrase_weights(text, phrases)

        # ─── 5) Fusion des mini-phrases trop courtes ───
        #phrases, weights = merge_short_phrases(phrases, weights, min_chars=30)
        #phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)
        
        phrases = split_french_phrases(text)
        #phrases = split_long_phrases(phrases, max_chars=80)
        weights = calculate_phrase_weights(text, phrases)
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40, max_chars=None)

        # ─── 6) Budget TTS versus silences pré/post ───
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # ─── 7) Synthèse phrase par phrase avec retry ───
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s   = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")

            await robust_synthesize_phrase(
                ph, tmp_mp3,
                voice="fr-FR-DeniseNeural",
                rate=rate
            )
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)

            # On ajuste strictement à la durée allouée
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # ─── 8) Anti-dépassement TTS seul ───
        sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)
        if sum_tts > content_ms and sum_tts > 0:
            factor = content_ms / sum_tts
            phrase_audios = [
                change_playback_speed(a, factor)
                for a in phrase_audios
            ]
            sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)

        # ─── 9) Calcul AUTOMATIQUE des silences internes ───
        n_inter   = max(0, len(phrases) - 1)
        available = content_ms - sum_tts

        if n_inter > 0 and available > 0:
            sil_ms = available // n_inter
            inter_applied = [sil_ms] * n_inter
        else:
            inter_applied = [0] * n_inter

        # ─── 10) Reconstruction du segment ───
        seq = []
        for i, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq:
            seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        # ─── 11) Strip des silences internes TTS indésirables ───
        nons = detect_nonsilent(seg_audio, min_silence_len=1,
                                silence_thresh=seg_audio.dBFS - 16)
        if nons:
            seg_audio = seg_audio[nons[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        # ─── 12) Pad ou trim strict au total_ms ───
        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # ─── 13) Debug timings ───
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000)
        abs_e_v = int(end_s   * 1000)
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # ─── 14) Warp global si nécessaire ───
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s - start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s - start_s) / gen_dur)

        # ─── 15) Mix sur la timeline avec Start-Offset et End-Offset ───
        base_ms    = int(start_s * 1000)
        soff       = seg.get("start_offset_ms", 0)
        eoff       = seg.get("end_offset_ms",   0)

        # 1) Appliquer l’offset de fin sur seg_audio
        if eoff > 0:
            seg_audio = seg_audio + AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]  # tronque les |eoff| derniers ms

        # 2) Calculer le placement en tenant compte du start_offset
        start_ms = base_ms + soff

        # 3) Coller sur la timeline
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined += seg_audio

        # ─── 16) Log debug ───
        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"silences_internal={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms, "
            f"phrases={phrases}\n"
        )


    # ─── 17) Export debug & wav ───
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path






# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file créé : 4.2.2_Flux de navigation_Avr_08_Latest_run_20250430_085112\translation_review.txt (48 segments)
# ✅ Parsed 48 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, nous explorer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le flux de navigation améliore…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il permet une transition fluid…'
# [Error] Attempt 1/10 failed for phrase: 'Il permet une transition fluid…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFD640> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Il permet une transition fluid…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur s'est connecté à…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur l'icône du sél…'
# [Error] Attempt 1/10 failed for phrase: 'En cliquant sur l'icône du sél…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFD880> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'En cliquant sur l'icône du sél…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'application EPM est conçu av…'
# [Error] Attempt 1/10 failed for phrase: 'L'application EPM est conçu av…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE8D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'L'application EPM est conçu av…'
# [Error] Attempt 2/10 failed for phrase: 'L'application EPM est conçu av…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE840> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.8s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'L'application EPM est conçu av…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et vous pouvez basculer vers u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur le flux de navigat…'
# [Error] Attempt 1/10 failed for phrase: 'Cliquez sur le flux de navigat…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE690> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cliquez sur le flux de navigat…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir toutes les ca…'
# [Error] Attempt 1/10 failed for phrase: 'Vous pouvez voir toutes les ca…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE8D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Vous pouvez voir toutes les ca…'
# [Error] Attempt 2/10 failed for phrase: 'Vous pouvez voir toutes les ca…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFDC70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Vous pouvez voir toutes les ca…'
# [Error] Attempt 3/10 failed for phrase: 'Vous pouvez voir toutes les ca…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFD130> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.5s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'Vous pouvez voir toutes les ca…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Revenons maintenant à Flux SM.…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant voir le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur l'icône de navigat…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur la carte Données e…'
# [Error] Attempt 1/10 failed for phrase: 'Cliquez sur la carte Données e…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFEC30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cliquez sur la carte Données e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais développer l'année tot…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'On avait 9000 et on a saisi un…'
# [Error] Attempt 1/10 failed for phrase: 'On avait 9000 et on a saisi un…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE4E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'On avait 9000 et on a saisi un…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur la page d'…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais cliquer sur la page d'…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFD640> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais cliquer sur la page d'…'
# [Error] Attempt 2/10 failed for phrase: 'Je vais cliquer sur la page d'…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFD880> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Je vais cliquer sur la page d'…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais rechercher un rapport.…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais fermer ce rapport et j…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux également cliquer sur …'
# [Error] Attempt 1/10 failed for phrase: 'Je peux également cliquer sur …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE7B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux également cliquer sur …'
# [Error] Attempt 2/10 failed for phrase: 'Je peux également cliquer sur …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFEB10> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.3s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Je peux également cliquer sur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est pour vous montrer com…'
# [Error] Attempt 1/10 failed for phrase: 'Ceci est pour vous montrer com…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFEE70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ceci est pour vous montrer com…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons reprendre la sess…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette page de destination…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons désactiver la modé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour configurer le flux de nav…'
# [Error] Attempt 1/10 failed for phrase: 'Pour configurer le flux de nav…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE840> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour configurer le flux de nav…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez maintenant sur la grap…'
# [Error] Attempt 1/10 failed for phrase: 'Cliquez maintenant sur la grap…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE570> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cliquez maintenant sur la grap…'
# [Error] Attempt 2/10 failed for phrase: 'Cliquez maintenant sur la grap…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE840> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Cliquez maintenant sur la grap…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, vous pouvez voir plusieur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Certains d'entre eux sont acti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez sélectionner un fl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez copier, supprimer …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Avant de modifier un flux de n…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur le lien Actif du f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur le nom du flux de …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_27_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque élément est attribué à …'
# [Error] Attempt 1/10 failed for phrase: 'Chaque élément est attribué à …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE960> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Chaque élément est attribué à …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_28_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une option pour réorganiser et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_29_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette démo, nous allons a…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_30_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la grappe Données financi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_31_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également les options sui…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_32_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également l'option d'attr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_33_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et je vais enregistrer et ferm…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_34_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et je devrai cliquer sur le bo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_35_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur la page d'accu…'
# [Error] Attempt 1/10 failed for phrase: 'En cliquant sur la page d'accu…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE570> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'En cliquant sur la page d'accu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_36_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour actualiser le flux de nav…'
# [Error] Attempt 1/10 failed for phrase: 'Pour actualiser le flux de nav…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFDFD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour actualiser le flux de nav…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_37_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La page recharge avec la grapp…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_38_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur la grappe Données …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_39_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur la carte de revenu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_40_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, il s'agit de données de t…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_41_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En survolant sur les icônes, i…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_42_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons obtenir plus de d…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons obtenir plus de d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFF260> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons obtenir plus de d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_43_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également navigue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_44_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également des ongle…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_45_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir toutes les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_46_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, nous avons ex…'
# [Error] Attempt 1/10 failed for phrase: 'Dans cette démo, nous avons ex…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFF020> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans cette démo, nous avons ex…'
# [Error] Attempt 2/10 failed for phrase: 'Dans cette démo, nous avons ex…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002364ABFE330> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Dans cette démo, nous avons ex…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_47_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.2_Flux de navigation_Avr_08_Latest_run_20250430_085112\4.2.2_Flux de navigation_Avr_08_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.2_Flux de navigation_Avr_08_Latest_run_20250430_085112\4.2.2_Flux de navigation_Avr_08_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.2_Flux de navigation_Avr_08_Latest_run_20250430_085112\4.2.2_Flux de navigation_Avr_08_Latest-french.mp4
# Process completed! Output video: 4.2.2_Flux de navigation_Avr_08_Latest_run_20250430_085112\4.2.2_Flux de navigation_Avr_08_Latest-french.mp4

# %% [markdown]
# 30 APR

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent
import spacy


nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up



def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")




def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    Version robuste : génère un fichier de revue pour la traduction vocale.
    - Gère les erreurs, le découpage, la traduction, les cas limites.
    """
    print(f"🔍 Chargement des sous-titres depuis : {source_path}")
    try:
        subs = pysrt.open(source_path, encoding='utf-8')
    except UnicodeDecodeError:
        subs = pysrt.open(source_path, encoding='latin-1')
    except Exception as e:
        print(f"❌ Erreur lors de l'ouverture du fichier : {e}")
        return

    translator = GoogleTranslator(source=from_lang, target=to_lang)
    nlp = spacy.load("fr_core_news_sm")

    # 1. Regrouper en phrases
    print("🧠 Regroupement initial par ponctuation finale")
    sentence_end = re.compile(r"[.!?][\"')\]]?\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text.strip()):
            groups.append(cur)
            cur = []
    if cur:
        groups.append(cur)

    # 2. Split les groupes trop longs
    def split_long(gs, max_s):
        def split_group(g):
            start = g[0].start.ordinal / 1000
            end = g[-1].end.ordinal / 1000
            duration = end - start

            if duration <= max_s or len(g) == 1:
                return [g]

            for i in range(len(g) - 1, 0, -1):
                if re.search(r"[.?!,;:]$", g[i].text.strip()):
                    left, right = g[:i + 1], g[i + 1:]
                    if len(left) == 0 or len(right) == 0:
                        break
                    return split_group(left) + split_group(right)

            mid = len(g) // 2
            if mid == 0 or mid == len(g):
                return [g]
            return split_group(g[:mid]) + split_group(g[mid:])

        out = []
        for g in gs:
            out.extend(split_group(g))
        return out

    print("✂️ Découpage des groupes trop longs…")
    groups = split_long(groups, max_group_duration_secs)

    # 3. Merge finaux si fin de phrase manquante
    i = 0
    while i < len(groups):
        if not re.search(r"[.!?,;:]$", groups[i][-1].text.strip()):
            if i + 1 < len(groups):
                print(f"⚠️ Merge groupe {i} et {i+1} car fin de phrase absente")
                groups[i] += groups.pop(i + 1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4. Génération du fichier de revue
    print(f"✏️ Écriture du fichier de revue : {review_file_path}")
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, **Inter-Phrase-Silence:**, **Start-Offset**, **End-Offset**\n")
        f.write("Mais **ne touchez pas** à la liste des phrases.\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal / 1000
            end_s = group[-1].end.ordinal / 1000
            original = " ".join(s.text.strip() for s in group)

            try:
                auto_tr = translator.translate(text=original)
            except Exception as e:
                print(f"❌ Erreur traduction segment {idx} : {e}")
                auto_tr = "[ERREUR DE TRADUCTION]"

            # Segmentation avec spaCy
            doc = nlp(auto_tr)
            phrases = [sent.text.strip() for sent in doc.sents if sent.text.strip()]
            inter_ms = [0 for _ in range(max(0, len(phrases)-1))]
            total_ms = int((end_s - start_s) * 1000)
            pre_ms, post_ms = 0, 100
           

            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write("**Phrases (ne modifiez pas) :**\n")
            for ph in phrases:
                f.write(f"- {ph}\\n")
            f.write(f"**Voice Speed:** +0%\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Inter-Phrase-Silence:** {','.join(str(ms) for ms in inter_ms)}\n")
            f.write(f"**Start-Offset:** 0\n")
            f.write(f"**End-Offset:** 0\n")
            f.write(f"**Budget (ms)** : {total_ms}\n")
            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Fichier de revue généré : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")




def parse_review_file(review_file_path):
    """
    Lit le review file écrit ci-dessus et
    renvoie une liste de dicts avec :
      - start_s, end_s, final_translation, voice_speed
      - pre_silence, post_silence, start_offset_ms, end_offset_ms, inter_phrase_silences, phrases (list)
    """
    text = open(review_file_path, encoding="utf-8").read()
    # Séparation des blocs par lignes de ---
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        # ignorer l'en-tête global
        if blk.startswith("Translation Review File"): continue
        m = header.search(blk)
        if not m: continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft = None
        vs = "+0%"
        pre, post = 0.0, 0.0
        start_offset = 0
        end_offset = 0
        inter_ms = []
        phrases = []
        orig = None

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()
            elif line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                vals = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                inter_ms = [float(x) for x in vals.split(",") if x.strip()]
            elif line.startswith("**Start-Offset:**"):
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("- "):
                phrases.append(line[2:].strip())

        segments.append({
            "start_s":           start_s,
            "end_s":             end_s,
            "original":          orig,
            "final_translation": ft or orig,
            "voice_speed":       vs,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "inter_phrase_silences": inter_ms,
            "phrases":           phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # ─── 1) Génération / mise à jour du review file ───
    groups = generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )

    # ─── 2) Lecture du review file enrichi ───
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        # ─── 3) Récupérations de base ───
        start_s  = seg["start_s"]
        end_s    = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        text   = seg["final_translation"]
        rate   = seg["voice_speed"]
        pre_ms = seg["pre_silence"]
        post_ms= seg["post_silence"]

        # ─── 4) Utilisation des phrases définies dans le review file ───
        # si l'utilisateur a listé ses phrases, on les prend ; sinon fallback automatique
        # if seg.get("phrases"):
        #     phrases = seg["phrases"]
        # else:
        phrases = split_french_phrases(text)
        # calcul des poids sur texte final
        weights = calculate_phrase_weights(text, phrases)
        # fusion éventuelle de mini-phrases trop courtes
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40, max_chars=None)

        # ─── 6) Budget TTS versus silences pré/post ───
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # ─── 7) Synthèse phrase par phrase avec retry ───
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s   = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")

            await robust_synthesize_phrase(
                ph, tmp_mp3,
                voice="fr-FR-DeniseNeural",
                rate=rate
            )
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)

            # On ajuste strictement à la durée allouée
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # ─── 8) Anti-dépassement TTS seul ───
        sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)
        if sum_tts > content_ms and sum_tts > 0:
            factor = content_ms / sum_tts
            phrase_audios = [
                change_playback_speed(a, factor)
                for a in phrase_audios
            ]
            sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)

        # ─── 9) Silences internes (manuels ou automatiques) ───
        n_inter   = max(0, len(phrases) - 1)
        # si l'utilisateur a rempli inter_phrase_silences dans le review file, on l'utilise
        manual_inters = seg.get("inter_phrase_silences", [])
        if manual_inters and len(manual_inters) == n_inter:
            inter_applied = manual_inters
        else:
            # budget restant en ms pour inter-phrases
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter
                
                

        # ─── 10) Reconstruction du segment ───
        seq = []
        for i, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq:
            seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        # ─── 11) Strip des silences internes TTS indésirables ───
        nons = detect_nonsilent(seg_audio, min_silence_len=1,
                                silence_thresh=seg_audio.dBFS - 16)
        if nons:
            seg_audio = seg_audio[nons[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        # ─── 12) Pad ou trim strict au total_ms ───
        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # ─── 13) Debug timings ───
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000)
        abs_e_v = int(end_s   * 1000)
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # ─── 14) Warp global si nécessaire ───
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s - start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s - start_s) / gen_dur)

        # ─── 15) Mix sur la timeline avec positionnement absolu ───
        base_ms   = int(start_s * 1000)
        soff      = seg.get("start_offset_ms", 0)
        eoff      = seg.get("end_offset_ms",   0)

        # 1) Appliquer l’offset de fin sur seg_audio
        if eoff > 0:
            seg_audio = seg_audio + AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]  # tronque les |eoff| derniers ms

        # 2) Calculer le point de départ absolu
        start_ms = base_ms + soff

        # 3) Forcer combined à exactement start_ms
        if len(combined) < start_ms:
            # la timeline est trop courte → on padde jusqu’à start_ms
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms:
            # un précédent segment a débordé → on tronque pour revenir à start_ms
            combined = combined[:start_ms]

        # 4) Coller le segment audio
        combined += seg_audio


        # ─── 16) Log debug ───
        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"silences_internal={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms, "
            f"phrases={phrases}\n"
        )


    # ─── 17) Export debug & wav ───
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path



# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# 🔍 Chargement des sous-titres depuis : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\4.2.4_Configuration de la solution_Avr_10_Latest-english.srt
# 🧠 Regroupement initial par ponctuation finale
# ✂️ Découpage des groupes trop longs…
# ⚠️ Merge groupe 0 et 1 car fin de phrase absente
# ⚠️ Merge groupe 0 et 1 car fin de phrase absente
# ⚠️ Merge groupe 1 et 2 car fin de phrase absente
# ⚠️ Merge groupe 1 et 2 car fin de phrase absente
# ⚠️ Merge groupe 1 et 2 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 2 et 3 car fin de phrase absente
# ⚠️ Merge groupe 5 et 6 car fin de phrase absente
# ⚠️ Merge groupe 6 et 7 car fin de phrase absente
# ⚠️ Merge groupe 6 et 7 car fin de phrase absente
# ⚠️ Merge groupe 6 et 7 car fin de phrase absente
# ⚠️ Merge groupe 6 et 7 car fin de phrase absente
# ⚠️ Merge groupe 7 et 8 car fin de phrase absente
# ⚠️ Merge groupe 7 et 8 car fin de phrase absente
# ⚠️ Merge groupe 7 et 8 car fin de phrase absente
# ⚠️ Merge groupe 7 et 8 car fin de phrase absente
# ⚠️ Merge groupe 8 et 9 car fin de phrase absente
# ⚠️ Merge groupe 8 et 9 car fin de phrase absente
# ⚠️ Merge groupe 8 et 9 car fin de phrase absente
# ⚠️ Merge groupe 8 et 9 car fin de phrase absente
# ⚠️ Merge groupe 8 et 9 car fin de phrase absente
# ⚠️ Merge groupe 8 et 9 car fin de phrase absente
# ⚠️ Merge groupe 9 et 10 car fin de phrase absente
# ⚠️ Merge groupe 9 et 10 car fin de phrase absente
# ⚠️ Merge groupe 9 et 10 car fin de phrase absente
# ⚠️ Merge groupe 9 et 10 car fin de phrase absente
# ⚠️ Merge groupe 9 et 10 car fin de phrase absente
# ⚠️ Merge groupe 9 et 10 car fin de phrase absente
# ⚠️ Merge groupe 10 et 11 car fin de phrase absente
# ⚠️ Merge groupe 11 et 12 car fin de phrase absente
# ⚠️ Merge groupe 11 et 12 car fin de phrase absente
# ⚠️ Merge groupe 11 et 12 car fin de phrase absente
# ⚠️ Merge groupe 11 et 12 car fin de phrase absente
# ⚠️ Merge groupe 13 et 14 car fin de phrase absente
# ⚠️ Merge groupe 16 et 17 car fin de phrase absente
# ⚠️ Merge groupe 21 et 22 car fin de phrase absente
# ✏️ Écriture du fichier de revue : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\translation_review.txt
# ✅ Fichier de revue généré : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\translation_review.txt (28 segments)
# ✅ Parsed 28 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir les configura…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Error] Attempt 1/10 failed for phrase: 'Nous verrons comment créer une…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00560> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité dans EPM comprendr…'
# [Error] Attempt 1/10 failed for phrase: 'La sécurité dans EPM comprendr…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C5F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La sécurité dans EPM comprendr…'
# [Error] Attempt 2/10 failed for phrase: 'La sécurité dans EPM comprendr…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C830> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.6s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'La sécurité dans EPM comprendr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Error] Attempt 1/10 failed for phrase: 'Une fois que le membre est mis…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F010A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Error] Attempt 1/10 failed for phrase: 'Une fois que nous avons la for…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C9E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Error] Attempt 1/10 failed for phrase: 'Pour voir une règle métier, cl…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8E4FEC0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Error] Attempt 2/10 failed for phrase: 'Pour voir une règle métier, cl…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F01130> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir l'application…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'expansion nous montrera EPBC…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Error] Attempt 1/10 failed for phrase: 'Permettez-moi de sélectionner …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux importer et je peux vo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai sélectionné le cube…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner Règles co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le système indiquera que la rè…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Error] Attempt 1/10 failed for phrase: 'Ceci est la première page que …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00560> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les administrateurs utilisent …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La règle va copier les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons avoir des règles …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50CCB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais donc le valider et l'e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais ouvrir un …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour FY23, je n'ai pas de donn…'
# [Error] Attempt 1/10 failed for phrase: 'Pour FY23, je n'ai pas de donn…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50CA70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour FY23, je n'ai pas de donn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais aller à ma règle et cl…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00B90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également céduler…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons également céduler…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50D370> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Error] Attempt 3/10 failed for phrase: 'Nous pouvons également céduler…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00A70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.2s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Error] Attempt 1/10 failed for phrase: 'Ceci peut être fait en utilisa…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CE88F20B90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a aussi des groupes défin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons exporter à partir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50CEF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons créer ou ajouter …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité attribue la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Error] Attempt 1/10 failed for phrase: 'Voyons comment nous pouvons at…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50D370> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Error] Attempt 1/10 failed for phrase: 'Je vais aller dans le dossier …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C950> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si j'ajoute le groupe Account …'
# [Error] Attempt 1/10 failed for phrase: 'Si j'ajoute le groupe Account …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F01400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Si j'ajoute le groupe Account …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant regarde…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections valides peuv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons simplement définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer une nouvell…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment créer et config…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous actions, nous pouvons cré…'
# [Error] Attempt 1/10 failed for phrase: 'Sous actions, nous pouvons cré…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C710> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Sous actions, nous pouvons cré…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur Créer un f…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais cliquer sur Créer un f…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00560> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais cliquer sur Créer un f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons faire glisser les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également avoir d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Error] Attempt 1/10 failed for phrase: 'Nous devrons sélectionner les …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50CE60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai la possibilité de personn…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C9E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons dire comment nous…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F03920> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'supprimer les colonnes. Nous p…'
# [Error] Attempt 1/10 failed for phrase: 'supprimer les colonnes. Nous p…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F012E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'supprimer les colonnes. Nous p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également différent…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a également des règles po…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé le formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Error] Attempt 1/10 failed for phrase: 'Dans les colonnes, nous avons …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, en sélectionnant l'icôn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir les varia…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons définir les varia…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CE88F20B90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Error] Attempt 3/10 failed for phrase: 'Nous pouvons définir les varia…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00560> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.2s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai mis une condition ici pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et ceci est le formulaire que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En développant l'année, je peu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également l'option d'ajus…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme sur Excel, nous pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également refléter ces…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour celles-ci, je vais augmen…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C710> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce un ajustement proportio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Disons donc pour le troisième …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Error] Attempt 1/10 failed for phrase: 'L'utilisateur sera en mesure d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F00A70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Error] Attempt 2/10 failed for phrase: 'L'utilisateur sera en mesure d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CEE8F01400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.0s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, un utilisateur peut fai…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Lorsqu'un icône bleu est visib…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la langue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Error] Attempt 1/10 failed for phrase: 'la précision, les suppressions…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001CF1D50C9E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_27_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250430_175831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %% [markdown]
# 24apr perplexity

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")


# ============== Helper Functions ==============

def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path


# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                if last_safe_idx is not None:
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end
                last_safe_idx = None

        if temp:
            new_groups.append(temp)

    return new_groups

def validate_audio_duration(original_segment, translated_audio):
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return translated_audio + AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        return audio[:target_ms]
    elif curr_ms < target_ms:
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio

def split_french_phrases(text):
    # Improved splitting on punctuation followed by uppercase or accented uppercase letters
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

async def robust_synthesize_phrase(phrase: str, output_path: str, voice: str = "fr-FR-DeniseNeural", rate: str = "+0%", max_retries: int = 5):
    for attempt in range(max_retries):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt+1}: Synthesizing phrase: '{phrase}'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.uniform(0, 1)
            print(f"[Warning] Synthesis failed on attempt {attempt+1} for phrase '{phrase}': {e}. Retrying in {wait_time:.1f}s...")
            await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase}")

def change_playback_speed(sound: AudioSegment, speed=1.0):
    # Change playback speed without altering pitch drastically
    # Using pydub speedup with small chunk size and crossfade
    if speed == 1.0:
        return sound
    return sound.speedup(playback_speed=speed, chunk_size=150, crossfade=25)

# ============== Main Function with Improved Inter-Phrase Silence Handling ==============

async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # Step 1: Generate or update review file (user validation/modification)
    groups = generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        from_lang="en", to_lang="fr",
        max_group_duration_secs=25.0
    )
    
   
    print(f"Generated {len(groups)} groups for review.")
    # Step 2: Parse enriched review file
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms= int((end_s - start_s)*1000)

        text       = seg.get("final_translation", seg.get("original", ""))
        rate       = seg.get("voice_speed", "+0%")
        pre_ms     = seg.get("pre_silence", 0.0)
        post_ms    = seg.get("post_silence", 100.0)
        inter_user = seg.get("inter_phrase_silences", [])

        phrases   = split_french_phrases(text)
        if not phrases:
            print(f"[Warning] No phrases found for segment {idx+1}. Skipping.")
            debug.append(f"Segment {idx+1}: No phrases found. Skipping.\n")
            continue

        weights   = calculate_phrase_weights(text, phrases)
        content_ms = max(0, total_ms - pre_ms - post_ms)

        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur      = content_ms * weights[i] / 1000.0
            tmp_path = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_path, voice="fr-FR-DeniseNeural", rate=rate)
            aud = AudioSegment.from_mp3(tmp_path)
            os.remove(tmp_path)
            aud = adjust_audio_duration(aud, dur)
            phrase_audios.append(aud)

        # Prevent TTS audio from exceeding content duration
        sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)
        if sum_tts > content_ms and sum_tts > 0:
            factor = content_ms / sum_tts
            phrase_audios = [change_playback_speed(a, factor) for a in phrase_audios]
            sum_tts = sum(a.duration_seconds*1000 for a in phrase_audios)

        # Adjust inter-phrase silences to fit within available time
        available = content_ms - sum_tts
        if available <= 0:
            inter_applied = [0]*len(inter_user)
        elif sum(inter_user) <= available:
            inter_applied = inter_user.copy()
        else:
            factor = available / sum(inter_user)
            inter_applied = [int(ms*factor) for ms in inter_user]

        # Rebuild audio sequence with applied silences
        seq = []
        for i, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq:
            seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Trim leading silence to first non-silent audio
        non = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS-16)
        if non:
            seg_audio = seg_audio[non[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        # Pad or trim to exact segment duration
        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # Debug timing info
        non2 = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS-16)
        start_audio_ms = non2[0][0] if non2 else pre_ms
        end_audio_ms   = non2[-1][1] if non2 else (total_ms-post_ms)
        abs_start_a = int(start_s*1000)+start_audio_ms
        abs_end_a   = int(start_s*1000)+end_audio_ms
        abs_start_v = int(start_s*1000)
        abs_end_v   = int(end_s*1000)
        decal_start = abs_start_a - abs_start_v
        decal_end   = abs_end_a   - abs_end_v

        # Global speed warp if needed
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s-start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s-start_s)/gen_dur)

        # Mix on timeline
        start_ms = int(start_s*1000)
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms-len(combined)))
        combined += seg_audio

        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"inter_user={inter_user} → inter_applied={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms, "
            f"phrases={phrases}\n"
        )

    # Export debug log and final audio
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")
    return output_audio_path


# ============== Review File Parsing ==============

def parse_review_file(review_file_path):
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header_re = re.compile(
        r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)", re.I
    )

    for blk in blocks:
        if blk.startswith("Translation Review File"):
            continue
        m = header_re.search(blk)
        if not m:
            continue

        start_s = float(m.group(1))
        end_s   = float(m.group(2))

        orig    = None
        ft      = None
        vs      = "+0%"
        pre     = 0.0
        post    = 100.0
        inter   = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()
            elif line.startswith("**Final Translation:**"):
                ft   = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs   = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try:
                    pre = float(line.split("**Pre-Silence:**",1)[1].strip())
                except ValueError:
                    pass
            elif line.startswith("**Post-Silence:**"):
                try:
                    post = float(line.split("**Post-Silence:**",1)[1].strip())
                except ValueError:
                    pass
            elif line.startswith("**Inter-Phrase-Silence:**"):
                vals = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if vals:
                    try:
                        raw = [float(x) for x in vals.split(",")]
                        inter = [max(0, min(v, 5000)) for v in raw]
                    except ValueError:
                        inter = []

        if orig is None:
            raise RuntimeError(f"Segment sans **Original** dans {review_file_path}")
        if ft is None:
            ft = orig

        # Improved phrase splitting
        phrases = split_french_phrases(ft)

        segments.append({
            "start_s":               start_s,
            "end_s":                 end_s,
            "original":              orig,
            "final_translation":     ft,
            "voice_speed":           vs,
            "pre_silence":           pre,
            "post_silence":          post,
            "inter_phrase_silences": inter,
            "phrases":               phrases
        })

    print(f"✅ Parsed {len(segments)} segments from review file.")
    return segments


# ============== Placeholder for generate_translation_review_file (must be implemented) ==============


def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) Regroupe les sous-titres par phrases.
    2) Scinde les groupes trop longs.
    3) Écrit le fichier de review en indiquant :
       - pre / post silence
       - budget total pour inter-phrases
       - inter-phrase-silence par défaut (0 pour chaque intervalle)
    """
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regroupement par phrase
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, current = [], []
    for sub in subs:
        current.append(sub)
        if sentence_end.search(sub.text):
            groups.append(current)
            current = []
    if current:
        groups.append(current)

    # 2) Découpe si trop long & enforcement ponctuation
    from itertools import chain
    def split_long_groups(groups, max_s):
        new = []
        for g in groups:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end-start <= max_s:
                new.append(g)
            else:
                # simple découpe au milieu
                mid = len(g)//2
                new.extend([g[:mid], g[mid:]])
        return new
    groups = split_long_groups(groups, max_group_duration_secs)

    def enforce_punctuation_boundaries(groups):
        i = 0
        while i < len(groups):
            last = groups[i][-1].text.strip()
            if not re.search(r"[.!?,;:]$", last):
                if i+1 < len(groups):
                    groups[i] += groups.pop(i+1)
                else:
                    groups[i][-1].text += "."
            else:
                i += 1
        return groups
    groups = enforce_punctuation_boundaries(groups)

    # 3) Write review file
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Edit the **Final Translation** below. You can also adjust:\n")
        f.write("- **Voice Speed:** -10% to +10%\n")
        f.write("- **Pre-Silence/Post-Silence:** in milliseconds\n")
        f.write("- **Inter-Phrase-Silence:** comma-separated ms between phrases\n")
        f.write("  (must have one fewer value than phrases)\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal/1000
            end_s   = group[-1].end.ordinal/1000
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # découpe en phrases
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]

            # budget inter-phrases
            total_ms      = int((end_s - start_s)*1000)
            pre_ms, post_ms = 100, 100
            budget_inter  = max(0, total_ms - pre_ms - post_ms)

            # silences par défaut = 0
            inter_default = ",".join("0" for _ in range(len(phrases)-1))

            # on écrit
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s):\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** +0%\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Budget total Inter-Phrase-Silence (ms):** {budget_inter}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_default}\n")
            f.write("----------------------------------------------------------------\n\n")

    print(f"✅ Review file created at: {review_file_path}  ({len(groups)} segments)")
    input("Type 'Y' when ready to continue: ")
    return groups


def adjust_review_file_based_on_debug_log(
    review_path: str,
    debug_log_path: str,
    output_review_path: str,
    threshold_ms: int = 50
):
    """
    Pour chaque segment i :
      - si decal_end < -threshold_ms → audio trop court → on ajoute |decal_end|ms en post-silence
      - si decal_start >  threshold_ms → audio trop tôt  → on ajoute decal_start ms en pre-silence
    Réécrit un nouveau review_file.
    """
    # 1) on lit tout
    review_txt = open(review_path, encoding="utf-8").read()
    debug_txt  = open(debug_log_path, encoding="utf-8").read()

    # 2) on récupère les décalages par segment
    #    ex: "Segment 3 (…): … décalage_end=-1686ms"
    decal_ends = [int(m) for m in re.findall(r"Segment\s+(\d+).*?décalage_end=([\-0-9]+)ms", debug_txt)]
    decal_starts = [int(m) for m in re.findall(r"Segment\s+(\d+).*?décalage_start=([\-0-9]+)ms", debug_txt)]
    # on met dans dict {seg_index: (start,end)}
    shifts = {}
    for (i,end), (_,start) in zip(decal_ends, decal_starts):
        shifts[i] = {"start": start, "end": end}

    # 3) on rebuild le review file en insérant les ajustements
    out_lines = []
    current_seg = 0
    for line in review_txt.splitlines(keepends=True):
        m = re.match(r"Segment\s+(\d+)\s+\(start:", line)
        if m:
            # nouveau segment
            current_seg = int(m.group(1))
            end = shifts.get(current_seg,{}).get("end", 0)
            start = shifts.get(current_seg,{}).get("start", 0)
            out_lines.append(line)
            continue

        # si on est sur la ligne **Pre-Silence:**
        if line.startswith("**Pre-Silence:**") and current_seg in shifts:
            start, end = shifts[current_seg]["start"], shifts[current_seg]["end"]
            add = start if start>threshold_ms else 0
            # on lit l'ancienne valeur
            old = float(re.search(r"\*\*Pre-Silence:\*\*\s*([\d.]+)", line).group(1))
            new = old + add
            line = re.sub(r"\*\*Pre-Silence:\*\*\s*[\d.]+", f"**Pre-Silence:** {new}", line)
            out_lines.append(line)
            continue

        # si on est sur la ligne **Post-Silence:**
        if line.startswith("**Post-Silence:**") and current_seg in shifts:
            start, end = shifts[current_seg]["start"], shifts[current_seg]["end"]
            add = abs(end) if end< -threshold_ms else 0
            old = float(re.search(r"\*\*Post-Silence:\*\*\s*([\d.]+)", line).group(1))
            new = old + add
            line = re.sub(r"\*\*Post-Silence:\*\*\s*[\d.]+", f"**Post-Silence:** {new}", line)
            out_lines.append(line)
            continue

        out_lines.append(line)

    # 4) on écrit le nouveau review file
    with open(output_review_path, "w", encoding="utf-8") as f:
        f.write("".join(out_lines))

    print(f"✅ Adjusted review written to {output_review_path}")


# ============== Main Entry Point ==============

async def main():
    print("Extracting audio...")
    extract_audio()

    print("Transcribing audio...")
    language, segments = transcribe(extracted_audio)

    print("Generating subtitle file...")
    generate_subtitle_file(segments, subtitle_file_en)

    print("Generating translated audio with sync...")
    await async_generate_translated_audio_with_sync_using_review(
        subtitle_file_en,
        translated_audio,
        debug_log_file,
        review_file
    )

    print("Done!")

if __name__ == "__main__":
    asyncio.run(main())

# %%
import time
from pydub import AudioSegment
from gtts import gTTS
import tempfile
import os

# Segment 3 metadata
segment_id = 3
start_sec = 41.80
end_sec = 101.72
video_duration = end_sec - start_sec  # ~59.92 seconds

final_translation = (
    "À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions. "
    "Maintenant, je vais sélectionner le cube, et pour la dimension du compte, je vais rechercher "
    "le membre pour lequel je souhaite mettre à jour la formule du membre. Une fois que le membre est mis en évidence, "
    "nous pouvons modifier les propriétés de formule de membres. Nous pouvons sélectionner le cube pour voir la formule du membre. "
    "La formule des membres est utilisée n'importe où dans l'application. Ici, le matériel OFS sera divisé par le volume OFS. "
    "Une fois que nous avons la formule des membres, nous pouvons la valider et nous pouvons voir qu'elle est validée avec succès. "
    "Nous pouvons enregistrer, réinitialiser ou annuler. Je vais annuler dans ce cas."
)

inter_phrase_silences = [1000, 1000, 1000, 500, 500, 300, 250, 150]  # in ms
pre_silence_ms = 0
post_silence_ms = 100
voice_speed = "-5%"  # speed not yet handled in gTTS, but can be slowed using audio stretch if needed
expected_offset_ms = 100  # declared "Décalage"

# Step 1: Split text into phrases (by periods)
phrases = [phrase.strip() for phrase in final_translation.split('.') if phrase.strip()]

# Step 2: Generate and stitch audio
tts_segments = []

for idx, phrase in enumerate(phrases):
    print(f"[TTS] Synthesizing phrase {idx+1}/{len(phrases)}: {phrase}")
    tts = gTTS(text=phrase, lang='fr')
    
    with tempfile.NamedTemporaryFile(delete=False, suffix=".mp3") as tf:
        tmp_path = tf.name
        tts.save(tmp_path)

    # Load it after closing
    audio = AudioSegment.from_file(tmp_path, format="mp3")
    os.unlink(tmp_path)


    tts_segments.append(audio)

    # Add inter-phrase silence if not the last segment
    if idx < len(phrases) - 1:
        silence = AudioSegment.silent(duration=inter_phrase_silences[idx] if idx < len(inter_phrase_silences) else 0)
        tts_segments.append(silence)

# Step 3: Add pre- and post-silence
final_audio = AudioSegment.silent(duration=pre_silence_ms)
for seg in tts_segments:
    final_audio += seg
final_audio += AudioSegment.silent(duration=post_silence_ms)

# Step 4: Export and analyze duration
output_path = f"segment_{segment_id}_test_audio.mp3"
final_audio.export(output_path, format="mp3")

# Duration in seconds
audio_duration_sec = len(final_audio) / 1000.0
decalage_sec = audio_duration_sec - video_duration

print("\n🔍 Sync Analysis for Segment 3")
print(f"🕘 Video segment duration   : {video_duration:.2f} seconds")
print(f"🔊 Generated audio duration : {audio_duration_sec:.2f} seconds")
print(f"🧭 Décalage (audio - video) : {decalage_sec:+.2f} seconds")
print(f"📁 Output audio saved at    : {output_path}")
# Out:
# [TTS] Synthesizing phrase 1/9: À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions
# [TTS] Synthesizing phrase 2/9: Maintenant, je vais sélectionner le cube, et pour la dimension du compte, je vais rechercher le membre pour lequel je souhaite mettre à jour la formule du membre
# [TTS] Synthesizing phrase 3/9: Une fois que le membre est mis en évidence, nous pouvons modifier les propriétés de formule de membres
# [TTS] Synthesizing phrase 4/9: Nous pouvons sélectionner le cube pour voir la formule du membre
# [TTS] Synthesizing phrase 5/9: La formule des membres est utilisée n'importe où dans l'application
# [TTS] Synthesizing phrase 6/9: Ici, le matériel OFS sera divisé par le volume OFS
# [TTS] Synthesizing phrase 7/9: Une fois que nous avons la formule des membres, nous pouvons la valider et nous pouvons voir qu'elle est validée avec succès
# [TTS] Synthesizing phrase 8/9: Nous pouvons enregistrer, réinitialiser ou annuler
# [TTS] Synthesizing phrase 9/9: Je vais annuler dans ce cas
#
# 🔍 Sync Analysis for Segment 3
# 🕘 Video segment duration   : 59.92 seconds
# 🔊 Generated audio duration : 59.78 seconds
# 🧭 Décalage (audio - video) : -0.14 seconds
# 📁 Output audio saved at    : segment_3_test_audio.mp3

# %%
import asyncio
from pydub import AudioSegment
from pydub.silence import detect_nonsilent
import edge_tts
import tempfile
import os

# Configuration - matches your review file example
SEGMENTS = [
    {   # Segment 1
        "text": "Nous allons voir les configurations de l'application EPM. Nous verrons comment créer un rôle commercial ou une formule membre. Nous verrons comment la sécurité fonctionne dans l'application EPM et nous couvrirons comment créer et configurer des formulaires de données. La sécurité dans l'EPM comprendra la sécurité dimensionnelle, la sécurité des artefacts,",
        "pre_silence": 0,
        "post_silence": 0,
        "speed": "+0%"
    },
    {   # Segment 2
        "text": "Sécurité par tâches ou flux de travail, sécurité pour les rôles commerciaux et sécurité pour les données.",
        "pre_silence": 0,
        "post_silence": 100,
        "speed": "+0%"
    }
]

async def generate_segment(text: str, speed: str) -> AudioSegment:
    """Generate TTS audio with aggressive silence trimming"""
    with tempfile.NamedTemporaryFile(delete=False, suffix=".mp3") as tmp:
        communicate = edge_tts.Communicate(
            text=text,
            voice="fr-FR-DeniseNeural",
            rate=speed
        )
        await communicate.save(tmp.name)
        audio = AudioSegment.from_mp3(tmp.name)
        os.unlink(tmp.name)
        
        # Trim both edges aggressively
        non_silent = detect_nonsilent(audio, silence_thresh=-40, min_silence_len=50)
        if non_silent:
            start = non_silent[0][0]
            end = non_silent[-1][1]
            return audio[start:end]
        return audio

async def main():
    # Generate and process segments
    processed = []
    for idx, seg in enumerate(SEGMENTS):
        # Create silence pads
        pre = AudioSegment.silent(duration=seg["pre_silence"])
        post = AudioSegment.silent(duration=seg["post_silence"])
        
        # Generate TTS audio
        speech = await generate_segment(seg["text"], seg["speed"])
        
        # Combine elements
        full = pre + speech + post
        full.export(f"segment_{idx+1}.wav", format="wav")
        processed.append(full)
        print(f"Generated Segment {idx+1} ({len(full)}ms)")

    # Combine segments and analyze transition
    combined = processed[0] + processed[1]
    combined.export("combined_output.wav", format="wav")
    
    # Detect transition point
    transition_point = len(processed[0])
    samples = combined[transition_point-500:transition_point+500]  # 1s window
    
    # Find first speech after transition
    non_silent = detect_nonsilent(samples, silence_thresh=-40, min_silence_len=20)
    if non_silent:
        gap = non_silent[0][0] - 500  # Adjust for window offset
        print(f"\nTransition analysis:")
        print(f"Segment 1 ends at: {transition_point}ms")
        print(f"First speech in Segment 2 starts at: {transition_point + gap}ms")
        print(f"Actual gap between segments: {abs(gap)}ms")
    else:
        print("\nNo gap detected between segments")

if __name__ == "__main__":
    try:
        # Standard execution
        asyncio.run(main())
    except RuntimeError:
        # For Jupyter/notebook environments
        import nest_asyncio
        nest_asyncio.apply()
        asyncio.get_event_loop().run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 83
#      81 try:
#      82     # Standard execution
# ---> 83     asyncio.run(main())
#      84 except RuntimeError:
#      85     # For Jupyter/notebook environments
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\runners.py:186, in run(main, debug)
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 88
#      86 import nest_asyncio
#      87 nest_asyncio.apply()
# ---> 88 asyncio.get_event_loop().run_until_complete(main())
#
# File c:\AI PROJECTS\video_transcript\myenv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# Cell In[1], line 53, in main()
#      50 post = AudioSegment.silent(duration=seg["post_silence"])
#      52 # Generate TTS audio
# ---> 53 speech = await generate_segment(seg["text"], seg["speed"])
#      55 # Combine elements
#      56 full = pre + speech + post
#
# Cell In[1], line 34, in generate_segment(text, speed)
#      32 await communicate.save(tmp.name)
#      33 audio = AudioSegment.from_mp3(tmp.name)
# ---> 34 os.unlink(tmp.name)
#      36 # Trim both edges aggressively
#      37 non_silent = detect_nonsilent(audio, silence_thresh=-40, min_silence_len=50)
#
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\061181~1\\AppData\\Local\\Temp\\tmptkseujan.mp3'

# %%
import edge_tts

ssml_text = '''<speak version="1.0" xmlns="http://www.w3.org/2001/10/synthesis" xml:lang="fr-FR">
    <prosody rate="120%">Bonjour, comment allez-vous?</prosody>
    <break time="300ms"/>
    <prosody rate="100%">Je suis ravi de vous voir.</prosody>
    </speak>'''

# Use the synchronous version
edge_tts.Communicate(ssml_text, voice="fr-FR-DeniseNeural").save_sync("output.mp3")
print("✅ Done!")
# Out:
# ✅ Done!

# %%
# First install if needed (remove if already installed)
# !pip install edge-tts --upgrade

# Then run this cell:
import edge_tts

# PROPERLY FORMATTED SSML (no extra whitespace between tags)
ssml_text = (
    '<speak version="1.0" xmlns="http://www.w3.org/2001/10/synthesis" xml:lang="fr-FR">'
    '<prosody rate="120%">Bonjour, comment allez-vous?</prosody>'
    '<break time="300ms"/>'
    '<prosody rate="100%">Je suis ravi de vous voir.</prosody>'
    '</speak>'
)

# For Jupyter Notebooks - use the synchronous version
edge_tts.Communicate(ssml_text, voice="fr-FR-DeniseNeural").save_sync("output.mp3")

print("✅ Synthesis complete! Playing result...")

# Play the audio directly in notebook
from IPython.display import Audio
Audio("output.mp3")
# Out:
# Requirement already satisfied: edge-tts in c:\ai projects\video_transcript\myenv\lib\site-packages (7.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from edge-tts) (3.11.16)
# Requirement already satisfied: certifi>=2023.11.17 in c:\ai projects\video_transcript\myenv\lib\site-packages (from edge-tts) (2025.1.31)
# Requirement already satisfied: srt<4.0.0,>=3.4.1 in c:\ai projects\video_transcript\myenv\lib\site-packages (from edge-tts) (3.5.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.4.4 in c:\ai projects\video_transcript\myenv\lib\site-packages (from edge-tts) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from edge-tts) (4.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.18.3)
# Requirement already satisfied: idna>=2.0 in c:\ai projects\video_transcript\myenv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.0->edge-tts) (3.10)
# ✅ Synthesis complete! Playing result...
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import re

def parse_segments(content):
    """
    Parse the content into segments using a regular expression that captures each segment.
    Returns a dictionary with segment numbers (as integers) as keys and the full segment text as values.
    """
    segments = {}
    # This pattern finds segments that start with "Segment <number>" and goes until the next segment or end of file.
    pattern = r"(Segment\s+(\d+).*?)(?=^Segment\s+\d+|\Z)"
    matches = re.findall(pattern, content, re.DOTALL | re.MULTILINE)
    for full_seg, seg_no in matches:
        segments[int(seg_no)] = full_seg
    return segments

def get_final_translation(segment_text):
    """
    Extracts the final translation text from a segment.
    It looks for the pattern **Final Translation:** followed by any text.
    """
    match = re.search(r"\*\*Final Translation:\*\*\s*(.*)", segment_text)
    if match:
        return match.group(1).strip()
    return None

def update_translation_review(review_content, updated_segments):
    """
    For each segment in the review file's content, replaces the **Final Translation:** text
    with the one from the updated segments.
    """
    # Parse the review content into segments using the same parser
    review_segments = {}
    pattern = r"(Segment\s+(\d+).*?)(?=^Segment\s+\d+|\Z)"
    matches = re.findall(pattern, review_content, re.DOTALL | re.MULTILINE)
    
    updated_content = review_content  # Work on a copy of the content

    for full_seg, seg_no in matches:
        seg_no_int = int(seg_no)
        if seg_no_int in updated_segments:
            updated_final = get_final_translation(updated_segments[seg_no_int])
            if updated_final is not None:
                # Replace the **Final Translation:** line in this segment with the new translation.
                # This regex pattern matches the '**Final Translation:**' line and captures the prefix.
                new_seg = re.sub(
                    r"(\*\*Final Translation:\*\*\s*).*",  # match the line starting with **Final Translation:**
                    r"\1" + updated_final,  # replace with the captured prefix plus the updated text
                    full_seg
                )
                # Replace the old segment in the content with the updated segment.
                updated_content = updated_content.replace(full_seg, new_seg)

    return updated_content

def main():
    # Define file paths (make sure these paths are correct)
    updated_file_path = "to translate/translation_review_latest_seg11_33_speed_moins10%.txt"
    review_file_path = "to translate/translation_review.txt"
    
    # Read updated file content
    with open(updated_file_path, encoding='utf-8') as f:
        updated_content = f.read()
    
    # Read review file content
    with open(review_file_path, encoding='utf-8') as f:
        review_content = f.read()
    
    # Parse segments from the updated content
    updated_segments = parse_segments(updated_content)
    
    # Replace the **Final Translation:** values in the review content
    new_review_content = update_translation_review(review_content, updated_segments)
    
    # Write the updated content to a new file (or overwrite the original file if desired)
    output_file_path = "to translate/translation_review_updated.txt"
    with open(output_file_path, "w", encoding='utf-8') as f:
        f.write(new_review_content)
    
    print(f"Updated translation review file has been saved as {output_file_path}")

if __name__ == "__main__":
    main()
# Out:
# Updated translation review file has been saved as to translate/translation_review_updated.txt

# %% [markdown]
# REPLACE ALL SECTIONS

# %%
import re

def parse_segments(content):
    """
    Parse the content into segments based on the segment header.
    Returns a dictionary with segment numbers (as integers) as keys and the full segment text as values.
    """
    segments = {}
    # The pattern finds segments that start with "Segment <number>" until the next segment or end of file.
    pattern = r"(Segment\s+(\d+).*?)(?=^Segment\s+\d+|\Z)"
    matches = re.findall(pattern, content, re.DOTALL | re.MULTILINE)
    for full_seg, seg_no in matches:
        segments[int(seg_no)] = full_seg
    return segments

def get_field_text(segment_text, field_name):
    """
    Extract the text following a given field marker (e.g., **Original:**, **Auto Translated:**, **Final Translation:**)
    from the segment text. Returns the text stripped of leading/trailing spaces.
    """
    # Using a regex pattern that stops at the end of the line.
    pattern = r"\*\*" + re.escape(field_name) + r":\*\*\s*(.*)"
    match = re.search(pattern, segment_text)
    if match:
        return match.group(1).strip()
    return None

def update_segment_fields(review_segment, updated_segment, fields):
    """
    Replace the specified fields in the review_segment with the ones extracted
    from the updated_segment.
    
    fields should be a list of field names such as ["Original", "Auto Translated", "Final Translation"].
    """
    updated_seg = review_segment
    for field in fields:
        new_text = get_field_text(updated_segment, field)
        if new_text is not None:
            # Replace the entire line for the field in the review segment.
            # The regex captures the marker and then replaces what follows.
            pattern = r"(\*\*" + re.escape(field) + r":\*\*\s*).*$"
            replacement = r"\1" + new_text
            updated_seg = re.sub(pattern, replacement, updated_seg, flags=re.MULTILINE)
    return updated_seg

def update_translation_review(review_content, updated_segments, fields):
    """
    For each segment in review_content, replace the specified fields with those from the updated segments.
    """
    # Find the segments in review content using the same segmentation parser.
    pattern = r"(Segment\s+(\d+).*?)(?=^Segment\s+\d+|\Z)"
    matches = re.findall(pattern, review_content, re.DOTALL | re.MULTILINE)

    updated_content = review_content  # Work on a copy to allow replacements.

    for full_seg, seg_no in matches:
        seg_no_int = int(seg_no)
        if seg_no_int in updated_segments:
            # Replace the fields (Original, Auto Translated, Final Translation) based on updated segments.
            new_seg = update_segment_fields(full_seg, updated_segments[seg_no_int],
                                            fields)
            # Replace the old segment in the overall content with the updated segment.
            updated_content = updated_content.replace(full_seg, new_seg)
    return updated_content

def main():
    # Define the file paths (adjust these paths as needed)
    updated_file_path = "to translate/translation_review_version-5%speed.txt"
    review_file_path = "to translate/translation_review.txt"
    
    # Read the updated file content
    with open(updated_file_path, encoding='utf-8') as f:
        updated_content = f.read()
    
    # Read the review file content
    with open(review_file_path, encoding='utf-8') as f:
        review_content = f.read()
    
    # Parse segments from the updated file content
    updated_segments = parse_segments(updated_content)
    
    # Define the list of fields to update.
    fields_to_update = ["Original", "Auto Translated", "Final Translation"]
    
    # Replace the fields in the review content using the updated segments
    new_review_content = update_translation_review(review_content, updated_segments,
                                                   fields_to_update)
    
    # Write the updated content to a new file (or overwrite the original file if desired)
    output_file_path = "to translate/translation_review_updated.txt"
    with open(output_file_path, "w", encoding='utf-8') as f:
        f.write(new_review_content)
    
    print(f"Updated translation review file has been saved as {output_file_path}")

if __name__ == "__main__":
    main()
# Out:
# Updated translation review file has been saved as to translate/translation_review_updated.txt

# %%
import whisper
from transformers import pipeline
from TTS.api import TTS
import moviepy.editor as mp
from pydub import AudioSegment
import numpy as np

def translate_video(input_path, output_path):
    # 1. Extract audio
    video = mp.VideoFileClip(input_path)
    audio_path = "temp_audio.wav"
    video.audio.write_audiofile(audio_path)

    # 2. Transcribe with Whisper (large model for accuracy)
    model = whisper.load_model("large-v3")
    result = model.transcribe(audio_path, language="en")
    segments = result["segments"]

    # 3. Translate with NLLB (state-of-the-art translation)
    translator = pipeline("translation", 
                        model="facebook/nllb-200-3.3B",
                        src_lang="eng_Latn", 
                        tgt_lang="fra_Latn")
    
    # Context-aware translation with sentence grouping
    translated_text = []
    current_group = ""
    for seg in segments:
        if len(current_group) + len(seg['text']) < 500:
            current_group += " " + seg['text']
        else:
            translated_group = translator(current_group)[0]['translation_text']
            translated_text.append(translated_group)
            current_group = seg['text']
    if current_group:
        translated_text.append(translator(current_group)[0]['translation_text'])

    # 4. Generate French speech with natural flow
    tts = TTS(model_name="tts_models/multilingual/multi-dataset/xtts_v2",
             progress_bar=False, gpu=True)
    
    # Split translation into natural speech chunks
    full_audio = AudioSegment.silent(duration=0)
    for i, text in enumerate(translated_text):
        tts.tts_to_file(text=text, 
                       speaker_wav="fr_speaker_ref.wav",  # Provide reference audio
                       language="fr",
                       file_path=f"temp_{i}.wav")
        
        chunk = AudioSegment.from_wav(f"temp_{i}.wav")
        full_audio += chunk

    # 5. Synchronize with video
    new_audio = mp.AudioFileClip("final_audio.wav")
    final_video = video.set_audio(new_audio.set_duration(video.duration))
    final_video.write_videofile(output_path, codec="libx264", audio_codec="aac")

# Usage
translate_video("4.2.4_Configuration de la solution_Avr_10_Latest.mp4", "4.2.4_Configuration de la solution_Avr_10_Latest_fr.mp4")

# %%
import subprocess
import os

def translate_video_subdub(input_path, output_path, speaker_ref):
    """
    Full translation pipeline using Subdub (OSS)
    Requires Subdub installation and WhisperX/XTTS setup
    """
    # Clone Subdub repo if not exists
    if not os.path.exists("Subdub"):
        subprocess.run(["git", "clone", "https://github.com/lukaszliniewicz/Subdub.git"])
    
    # Install requirements (first time only)
    if not os.path.exists("Subdub/venv"):
        subprocess.run(["python", "-m", "venv", "Subdub/venv"])
        pip_cmd = "Subdub/venv/Scripts/pip" if os.name == "nt" else "Subdub/venv/bin/pip"
        subprocess.run([pip_cmd, "install", "-r", "Subdub/requirements.txt"])

    # Build Subdub command
    python_cmd = "Subdub/venv/Scripts/python" if os.name == "nt" else "Subdub/venv/bin/python"
    cmd = [
        python_cmd, "Subdub/Subdub.py",
        "-i", input_path,
        "-sl", "en", "-tl", "fr",
        "-task", "full",
        "-tts_voice", speaker_ref,
        "-whisper_model", "large-v3"
    ]
    
    # Run translation pipeline
    subprocess.run(cmd)
    
    # Move output file
    base_name = os.path.splitext(input_path)[0]
    subdub_output = f"{base_name}_dubbed.mp4"
    os.replace(subdub_output, output_path)

# Usage
translate_video_subdub(
    "4.2.4_Configuration de la solution_Avr_10_Latest.mp4",
    "4.2.4_Configuration de la solution_Avr_10_Latest_fr.mp4",
    "fr_speaker_ref.wav"
)

# %%
# -*- coding: utf-8 -*-
import os, re
import time
import math
import ffmpeg
from faster_whisper import WhisperModel
import pysrt
from translate import Translator
from gtts import gTTS
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
import whisper
from shutil import which

# --- Configuration ---
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

# Configuration
input_video = "4.2.4_Configuration de la solution_Avr_10_Latest.mp4"  # Path to your input video
output_dir = "output"       # Output directory
model_size = "small"        # Whisper model size (tiny, base, small, medium, large)

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Derived paths
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
subtitle_file_fr = os.path.join(output_dir, f"{input_video_name}-french.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")

def extract_audio():
    """Extract audio from video using ffmpeg"""
    try:
        (
            ffmpeg
            .input(input_video)
            .output(extracted_audio, ac=1, ar=16000)  # Convert to mono 16kHz
            .overwrite_output()
            .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print('STDOUT:', e.stdout.decode('utf8'))
        print('STDERR:', e.stderr.decode('utf8'))
        raise
def transcribe(audio_path):
    """Transcribe audio using faster-whisper."""
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)

    # Access the language attribute directly from the TranscriptionInfo object
    language = info.language
    print(f"Detected language: {language}")

    # Process the segments into a list
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })

    return language, transcript_segments

def generate_subtitle_file(segments, output_path):
    """Generate subtitle file from segments."""
    subs = pysrt.SubRipFile()
    
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),  # Access dictionary keys
            end=time_to_subrip(segment["end"]),      # Access dictionary keys
            text=segment["text"].strip()             # Access dictionary keys
        )
        subs.append(sub)
    
    subs.save(output_path, encoding='utf-8')
    return output_path

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    """Convert seconds to SubRipTime format"""
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(
        hours=hours,
        minutes=minutes,
        seconds=int(seconds),
        milliseconds=milliseconds
    )

def translate_subtitlesOLD(source_path, target_path, from_lang="en", to_lang="fr"):
    """Translate subtitles using translate library"""
    translator = Translator(to_lang=to_lang, from_lang=from_lang)
    subs = pysrt.open(source_path)
    
    for sub in subs:
        try:
            translated = translator.translate(sub.text)
            sub.text = translated
        except Exception as e:
            print(f"Translation error: {str(e)}")
            continue
    
    subs.save(target_path, encoding='utf-8')
    return target_path



from deep_translator import GoogleTranslator
import pysrt
# --- Configuration ---
update_existing = True  # Set to True to allow user updates of the transcript/translation

def translate_subtitles(source_path, target_path, from_lang="en", to_lang="fr"):
    """Translate subtitles using GoogleTranslator from deep_translator."""
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)
    
    for sub in subs:
        try:
            # Translate using deep_translator's GoogleTranslator
            translated = translator.translate(text=sub.text)
            
            # Allow user to update translation manually if desired.
            if update_existing:
                print(f"\nSegment {sub.index}:")
                print(f"**Original:** {sub.text}")
                print(f"**Auto Translated:** {translated}")
                user_input = input("Press ENTER to accept or type your corrected translation: ").strip()
                if user_input:
                    translated = user_input
            
            sub.text = translated
        except Exception as e:
            print(f"Translation error in segment {sub.index}: {str(e)}")
            continue
    
    subs.save(target_path, encoding='utf-8')
    return target_path





def generate_translated_audio(subtitle_path, output_audio_path):
    """Generate translated audio track with timing"""
    subs = pysrt.open(subtitle_path)
    combined = AudioSegment.silent(duration=0)

    for sub in subs:
        start_time = sub.start.ordinal / 1000  # Convert to seconds
        text = sub.text

        # Generate TTS
        tts = gTTS(text, lang='fr')
        temp_path = os.path.join(output_dir, "temp.mp3")
        tts.save(temp_path)

        # Load and process audio
        audio = AudioSegment.from_mp3(temp_path)
        current_duration = len(combined)
        required_start = start_time * 1000  # Convert to milliseconds

        if required_start > current_duration:
            silence = AudioSegment.silent(duration=required_start - current_duration)
            combined += silence

        combined += audio
        os.remove(temp_path)  # Clean up temporary file

    combined.export(output_audio_path, format="wav")
    return output_audio_path



def merge_audio_video():
    """Merge translated audio with original video."""
    try:
        print("Merging audio with video...")
        video = VideoFileClip(input_video)
        audio = AudioSegment.from_file(translated_audio)  # Use pydub to load the audio

        # Set audio duration to match video duration
        video_duration_ms = int(video.duration * 1000)  # Convert video duration to milliseconds
        audio_duration_ms = len(audio)  # Get audio duration in milliseconds

        if audio_duration_ms < video_duration_ms:
            # Add silence to match the video duration
            silence = AudioSegment.silent(duration=(video_duration_ms - audio_duration_ms))
            audio += silence

        # Export the adjusted audio to a temporary file
        adjusted_audio_path = "adjusted_audio.wav"
        audio.export(adjusted_audio_path, format="wav")

        # Replace the video's audio with the adjusted audio
        adjusted_audio = AudioFileClip(adjusted_audio_path)
        video = video.set_audio(adjusted_audio)

        # Write the final video file
        video.write_videofile(
            output_video,
            codec="libx264",
            audio_codec="aac",
            temp_audiofile="temp-audio.m4a",
            remove_temp=True,
            threads=4
        )

        # Clean up temporary audio file
        os.remove(adjusted_audio_path)

        print(f"Process completed! Output video: {output_video}")
        return output_video

    except Exception as e:
        print(f"Failed to merge audio with video: {e}")
        raise


def group_subtitles_by_sentence(subs):
    """
    Group subtitles so that consecutive segments without sentence ending punctuation
    are combined. This returns a list of groups, each group is a list of subtitles.
    """
    groups = []
    current_group = []

    # A simple pattern to check for sentence-ending punctuation.
    sentence_end_pattern = re.compile(r'[.!?]\s*$')

    for sub in subs:
        current_group.append(sub)
        # If text ends with punctuation, consider the group complete.
        if sentence_end_pattern.search(sub.text):
            groups.append(current_group)
            current_group = []
    # Add any remaining subtitles as a group.
    if current_group:
        groups.append(current_group)
    return groups

def generate_translated_audio_grouped(subtitle_path, output_audio_path):
    """Generate a translated audio track by grouping subtitles by sentence."""
    subs = pysrt.open(subtitle_path)
    grouped_subs = group_subtitles_by_sentence(subs)
    combined_audio = AudioSegment.silent(duration=0)

    for group in grouped_subs:
        # Determine the start time based on the first subtitle in the group.
        group_start_time = group[0].start.ordinal / 1000  # in seconds
        # Merge texts from all subtitles in the group.
        group_text = " ".join([sub.text for sub in group])
        
        # Generate TTS for the grouped text
        tts = gTTS(group_text, lang='fr')
        temp_path = os.path.join(output_dir, "temp.mp3")
        tts.save(temp_path)
        audio = AudioSegment.from_mp3(temp_path)
        os.remove(temp_path)  # Cleanup temporary file

        # Calculate required start time (in milliseconds)
        required_start = int(group_start_time * 1000)
        current_duration = len(combined_audio)
        
        # Insert silence if the current combined audio is shorter than the required start time.
        if required_start > current_duration:
            silence = AudioSegment.silent(duration=required_start - current_duration)
            combined_audio += silence
        
        # Append the generated audio
        combined_audio += audio

    combined_audio.export(output_audio_path, format="wav")
    return output_audio_path













if __name__ == "__main__":
    # Step 1: Extract audio
    print("Extracting audio...")
    audio_path = extract_audio()
    
    # Step 2: Transcribe audio
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    
    # Step 3: Generate English subtitles
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    
    # Step 4: Translate to French
    print("Translating subtitles...")
    translate_subtitles(subtitle_file_en, subtitle_file_fr)
    
   
        # Step 5: Generate French audio with improved grouping
    print("Generating French audio (grouped by sentences)...")
    generate_translated_audio_grouped(subtitle_file_fr, translated_audio)
    
    # Step 6: Merge audio and video
    print("Merging audio and video...")
    merge_audio_video()
    
    print(f"Process completed! Output video: {output_video}")
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Translating subtitles...
#
# Segment 1:
# **Original:** will take a look at the configurations in EPM application. We will see how to
# **Auto Translated:** Je vais jeter un œil aux configurations de l'application EPM. Nous verrons comment
#
# Segment 2:
# **Original:** create a business role or a member formula. We will see how the security
# **Auto Translated:** créer un rôle commercial ou une formule membre. Nous verrons comment la sécurité
#
# Segment 3:
# **Original:** works in the EPM application and we will cover how to create and configure
# **Auto Translated:** Fonctionne dans l'application EPM et nous couvrirons comment créer et configurer
#
# Segment 4:
# **Original:** data forms. Security in EPM will include dimensional security, artifact security,
# **Auto Translated:** formulaires de données. La sécurité dans l'EPM comprendra la sécurité dimensionnelle, la sécurité des artefacts,
#
# Segment 5:
# **Original:** security by tasks or workflow, security for business roles and security for data.
# **Auto Translated:** Sécurité par tâches ou flux de travail, sécurité pour les rôles commerciaux et sécurité pour les données.
#
# Segment 6:
# **Original:** From the home page, click on the navigator and navigate to dimensions. Now
# **Auto Translated:** À partir de la page d'accueil, cliquez sur le navigateur et accédez aux dimensions. Maintenant
#
# Segment 7:
# **Original:** I'm going to select the queue and for the account dimension, I will search the
# **Auto Translated:** Je vais sélectionner la file d'attente et pour la dimension du compte, je vais rechercher le
#
# Segment 8:
# **Original:** member for which I want to update the member formula. Once the member is
# **Auto Translated:** membre pour lequel je souhaite mettre à jour la formule des membres. Une fois le membre
#
# Segment 9:
# **Original:** highlighted we can edit and member formula properties and we can select the queue
# **Auto Translated:** mis en évidence, nous pouvons modifier les propriétés de formule des membres et nous pouvons sélectionner la file d'attente
#
# Segment 10:
# **Original:** to see the member formula. Member formula is used anywhere in the application then
# **Auto Translated:** pour voir la formule des membres. La formule des membres est utilisée partout dans l'application
#
# Segment 11:
# **Original:** OFS material will be divided by the OFS volume. Once we have the member formula
# **Auto Translated:** Le matériel OFS sera divisé par le volume OFS. Une fois que nous avons la formule des membres
#
# Segment 12:
# **Original:** we can validate the member formula and we can see that it is validated
# **Auto Translated:** Nous pouvons valider la formule du membre et nous pouvons voir qu'il est validé
#
# Segment 13:
# **Original:** successfully. We can save or reset and cancel. I'm going to cancel in this case.
# **Auto Translated:** avec succès. Nous pouvons enregistrer ou réinitialiser et annuler. Je vais annuler dans ce cas.
#
# Segment 14:
# **Original:** To get a business role from the navigator we will click on the navigator icon and
# **Auto Translated:** Pour obtenir un rôle commercial du Navigator, nous cliquerons sur l'icône Navigator et
#
# Segment 15:
# **Original:** we will click on rules. It will open up our book calculation manager and it is
# **Auto Translated:** Nous cliquerons sur les règles. Il ouvrira notre responsable de calcul de livre et il est
#
# Segment 16:
# **Original:** also called as business rules. You can see the EPM cloud application and
# **Auto Translated:** Également appelé règles commerciales. Vous pouvez voir l'application EPM Cloud et
#
# Segment 17:
# **Original:** expanding will show us the EPBCS and currently we are going to create the
# **Auto Translated:** L'expansion nous montrera l'EPBCS et actuellement nous allons créer
#
# Segment 18:
# **Original:** rule under EPM FS. Let me select EPM FS and under actions I can either create a new
# **Auto Translated:** Règle sous EPM FS. Permettez-moi de sélectionner EPM FS et sous des actions, je peux soit créer un nouveau
#
# Segment 19:
# **Original:** rule, script, formula, I can import, I can see the properties. In this demo I'm
# **Auto Translated:** Règle, script, formule, je peux importer, je peux voir les propriétés. Dans cette démo, je suis
#
# Segment 20:
# **Original:** going to create a rule. As I have selected the queue and the application
# **Auto Translated:** va créer une règle. Comme j'ai sélectionné la file d'attente et l'application
#
# Segment 21:
# **Original:** all these information is prepopulated. I'm going to select red creating a member
# **Auto Translated:** Toutes ces informations sont présentées. Je vais sélectionner le rouge en créant un membre
#
# Segment 22:
# **Original:** formula with this name and I'm going to click on OK. It will say that it has
# **Auto Translated:** Formule avec ce nom et je vais cliquer sur OK. Il dira qu'il a
#
# Segment 23:
# **Original:** created do we want to make changes. I'm going to say yes and once we have
# **Auto Translated:** créé, nous voulons apporter des modifications. Je vais dire oui et une fois que nous aurons
#
# Segment 24:
# **Original:** created this is the first page we are going to see and mostly the business
# **Auto Translated:** créé c'est la première page que nous allons voir et surtout l'entreprise
#
# Segment 25:
# **Original:** admins use the designer view and also there is a script view. I'm going to
# **Auto Translated:** Les administrateurs utilisent la vue de concepteur et il existe également une vue de script. Je vais
#
# Segment 26:
# **Original:** select the script view. We have all the required dimensions we need here and I'm
# **Auto Translated:** Sélectionnez la vue du script. Nous avons toutes les dimensions requises dont nous avons besoin ici et je suis
#
# Segment 27:
# **Original:** currently going to copy data from FY24 for plan scenario working from entity
# **Auto Translated:** Je vais actuellement copier les données de FY24 pour le scénario de plan fonctionnant à partir de l'entité
#
# Segment 28:
# **Original:** allocation offset to FY23 plan working entity allocation offset. This is a very
# **Auto Translated:** Offset d'allocation à l'exercice de l'allocation de travail du plan FY23 Offset d'allocation. C'est un très
#
# Segment 29:
# **Original:** basic business rule. We can have business rules for complex scenarios and all
# **Auto Translated:** règle commerciale de base. Nous pouvons avoir des règles commerciales pour des scénarios complexes et tous
#
# Segment 30:
# **Original:** these business rules run within seconds. So I'm going to validate and save it.
# **Auto Translated:** Ces règles commerciales fonctionnent en quelques secondes. Je vais donc le valider et le sauver.
#
# Segment 31:
# **Original:** Once I have saved it, I can deploy it.
# **Auto Translated:** Une fois que je l'ai enregistré, je peux le déployer.
#
# Segment 32:
# **Original:** Currently I'm going to open a data form to show how this business rule works.
# **Auto Translated:** Actuellement, je vais ouvrir un formulaire de données pour montrer comment fonctionne cette règle commerciale.
#
# Segment 33:
# **Original:** I have a form here already and as you can see it's FY23-24 and I have data in FY24
# **Auto Translated:** J'ai déjà un formulaire ici et comme vous pouvez le voir, c'est FY23-24 et j'ai des données dans FY24
#
# Segment 34:
# **Original:** for all the quarters and FY23. I don't have data for this intersection.
# **Auto Translated:** pour tous les quartiers et FY23. Je n'ai pas de données pour cette intersection.
#
# Segment 35:
# **Original:** To copy data we just have to run the business rule and it will copy the data from FY24 to
# **Auto Translated:** Pour copier des données, nous devons simplement exécuter la règle commerciale et il copiera les données de l'exercice 24 à
#
# Segment 36:
# **Original:** 23 once I run the rule. I'm going to go to my rule and clicking on this button
# **Auto Translated:** 23 Une fois que j'ai exécuté la règle. Je vais aller à ma règle et cliquer sur ce bouton
#
# Segment 37:
# **Original:** launches the business rule. I'm going to launch it. We can have this business
# **Auto Translated:** lance la règle commerciale. Je vais le lancer. Nous pouvons avoir cette entreprise
#
# Segment 38:
# **Original:** rule launched from here or we can attach this business rule to any other facts
# **Auto Translated:** Règle lancée à partir d'ici ou nous pouvons joindre cette règle commerciale à tout autre fait
#
# Segment 39:
# **Original:** like data forms dashboards. I'm going to click on refresh. You see how the data
# **Auto Translated:** Comme des formulaires de données tableaux de bord. Je vais cliquer sur Actualiser. Vous voyez comment les données
#
# Segment 40:
# **Original:** is copied and it's populated in this form. Running it from the calc manager I
# **Auto Translated:** est copié et il est peuplé dans cette forme. L'exécuter à partir du gestionnaire calc I
#
# Segment 41:
# **Original:** can attach the business rule directly to the form and check options like run
# **Auto Translated:** peut attacher la règle commerciale directement au formulaire et vérifier les options comme l'exécution
#
# Segment 42:
# **Original:** on save, run on load. So it helps us in executing the rules once we click on the
# **Auto Translated:** Sur Enregistrer, exécutez le chargement. Cela nous aide donc à exécuter les règles une fois que nous avons cliqué sur le
#
# Segment 43:
# **Original:** save button. We can also schedule the business rule in our automations and
# **Auto Translated:** Bouton Enregistrer. Nous pouvons également planifier la règle d'entreprise dans nos automatismes et
#
# Segment 44:
# **Original:** run as part of the daily automation jobs. Security can be applied to the
# **Auto Translated:** Exécutez dans le cadre des travaux quotidiens d'automatisation. La sécurité peut être appliquée à la
#
# Segment 45:
# **Original:** business rules which will allow to restrict users and that can be done
# **Auto Translated:** Règles commerciales qui permettra de restreindre les utilisateurs et qui peuvent être effectués
#
# Segment 46:
# **Original:** using the business rule security.
# **Auto Translated:** en utilisant la sécurité des règles commerciales.
#
# Segment 47:
# **Original:** I'm going to click on the form. To learn more about security let's click on tools
# **Auto Translated:** Je vais cliquer sur le formulaire. Pour en savoir plus sur la sécurité, cliquez sur les outils
#
# Segment 48:
# **Original:** and navigate to access control where we can create groups to manage users
# **Auto Translated:** et accéder au contrôle d'accès où nous pouvons créer des groupes pour gérer les utilisateurs
#
# Segment 49:
# **Original:** within these groups and we have free defined groups which best set system
# **Auto Translated:** au sein de ces groupes et nous avons des groupes définis gratuits qui définissent le mieux
#
# Segment 50:
# **Original:** administrator, power user, user and viewer. We can see the list of users here. We
# **Auto Translated:** Administrateur, utilisateur de puissance, utilisateur et visionneuse. Nous pouvons voir la liste des utilisateurs ici. Nous
#
# Segment 51:
# **Original:** can assign different roles to these users which will help them to do more
# **Auto Translated:** peut attribuer différents rôles à ces utilisateurs, ce qui les aidera à faire plus
#
# Segment 52:
# **Original:** tasks than required. We can assign additional roles to the groups or user
# **Auto Translated:** tâches que nécessaire. Nous pouvons attribuer des rôles supplémentaires aux groupes ou à l'utilisateur
#
# Segment 53:
# **Original:** which will help them in creating or executing integrations, managing or
# **Auto Translated:** ce qui les aidera à créer ou à exécuter des intégrations, à gérer ou
#
# Segment 54:
# **Original:** approving task managers creating and using ad hoc forms. We can export from
# **Auto Translated:** Approuvant les gestionnaires de tâches créant et utilisez des formulaires ad hoc. Nous pouvons exporter de
#
# Segment 55:
# **Original:** any instance and import a CSV format with the list of users and groups from
# **Auto Translated:** Toute instance et importe un format CSV avec la liste des utilisateurs et des groupes de
#
# Segment 56:
# **Original:** any different instance into this particular instance.
# **Auto Translated:** toute instance différente dans cette instance particulière.
#
# Segment 57:
# **Original:** I'm going to move details on how security plays a major role in EPM. Let's check
# **Auto Translated:** Je vais déplacer des détails sur la façon dont la sécurité joue un rôle majeur dans l'EPM. Vérifions
#
# Segment 58:
# **Original:** dimensional security. For this particular dimension we have security roles
# **Auto Translated:** Sécurité dimensionnelle. Pour cette dimension particulière, nous avons des rôles de sécurité
#
# Segment 59:
# **Original:** assigned at each member level which will allow only particular users who have
# **Auto Translated:** attribué à chaque niveau de membre qui ne permettra que des utilisateurs particuliers
#
# Segment 60:
# **Original:** access or groups assigned to access them. We can create or add users and we can
# **Auto Translated:** accès ou groupes affectés pour y accéder. Nous pouvons créer ou ajouter des utilisateurs et nous pouvons
#
# Segment 61:
# **Original:** assign read write and no access along with functions like member children
# **Auto Translated:** Attribuez une lecture d'écriture et sans accès avec des fonctions comme les enfants membres
#
# Segment 62:
# **Original:** descendants of the member. Security is assigning security of artifact levels
# **Auto Translated:** Descendants du membre. La sécurité attribue la sécurité des niveaux d'artefacts
#
# Segment 63:
# **Original:** like data forms, reports, dashboards, tasks, workflows. Let's see how we can
# **Auto Translated:** Comme les formulaires de données, les rapports, les tableaux de bord, les tâches, les workflows. Voyons comment nous pouvons
#
# Segment 64:
# **Original:** assign security for a data form. I'm going to go to the demo folder and I have a form
# **Auto Translated:** attribuer la sécurité pour un formulaire de données. Je vais aller dans le dossier de démonstration et j'ai un formulaire
#
# Segment 65:
# **Original:** and clicking on this I'm going to add a group and so the account record
# **Auto Translated:** Et en cliquant dessus, je vais ajouter un groupe et donc l'enregistrement du compte
#
# Segment 66:
# **Original:** lecture if I add and give them the required functions they will be able
# **Auto Translated:** Conférence si je ajoute et leur donne les fonctions requises, ils pourront
#
# Segment 67:
# **Original:** to access this particular data form and it will be restricted for the other users.
# **Auto Translated:** Pour accéder à ce formulaire de données particulier et il sera limité pour les autres utilisateurs.
#
# Segment 68:
# **Original:** Now we are going to look at the security at data level. Value intersections can
# **Auto Translated:** Nous allons maintenant examiner la sécurité au niveau des données. Les intersections de valeur peuvent
#
# Segment 69:
# **Original:** help you control the data entry by defining valid combinations of
# **Auto Translated:** vous aider à contrôler la saisie des données en définissant des combinaisons valides de
#
# Segment 70:
# **Original:** dimension members to prevent invalid data inputs. We just have to define the
# **Auto Translated:** membres de la dimension pour éviter les entrées de données non valides. Nous devons juste définir le
#
# Segment 71:
# **Original:** combinations and save it. We also have cell level security that controls access
# **Auto Translated:** combinaisons et enregistrez-le. Nous avons également une sécurité au niveau cellulaire qui contrôle l'accès
#
# Segment 72:
# **Original:** to individual cells based on the dimensions and member selections. We
# **Auto Translated:** aux cellules individuelles basées sur les dimensions et les sélections de membres. Nous
#
# Segment 73:
# **Original:** can create new or import. How to create and configure a data form from the
# **Auto Translated:** peut créer une nouvelle ou une importation. Comment créer et configurer un formulaire de données à partir du
#
# Segment 74:
# **Original:** home page click on the data plan. Under actions we can create an ad hoc or create a
# **Auto Translated:** Page d'accueil Cliquez sur le plan de données. Sous des actions, nous pouvons créer un ad hoc ou créer un
#
# Segment 75:
# **Original:** form. I will click on create a form. We need to enter the name. We will have to
# **Auto Translated:** formulaire. Je cliquerai sur Créer un formulaire. Nous devons entrer le nom. Nous devrons
#
# Segment 76:
# **Original:** select the queue. We will have all the dimensions here. We need to drag and
# **Auto Translated:** Sélectionnez la file d'attente. Nous aurons toutes les dimensions ici. Nous devons traîner et
#
# Segment 77:
# **Original:** draw the dimensions on the respective rows and columns. We can also have dimensions
# **Auto Translated:** Dessinez les dimensions sur les lignes et colonnes respectives. Nous pouvons aussi avoir des dimensions
#
# Segment 78:
# **Original:** on the pages. We will have to select the members accordingly. Clicking on the
# **Auto Translated:** sur les pages. Nous devrons sélectionner les membres en conséquence. Cliquer sur le
#
# Segment 79:
# **Original:** icon will give me the member selector and I can add the member required. I have the
# **Auto Translated:** L'icône me donnera le sélecteur de membres et je peux ajouter le membre requis. J'ai le
#
# Segment 80:
# **Original:** option to customize based on how I want to see the data if I need any menus.
# **Auto Translated:** Option pour personnaliser en fonction de la façon dont je souhaite voir les données si j'ai besoin de menus.
#
# Segment 81:
# **Original:** Meaning helps us in navigating from one form to another just by right clicking
# **Auto Translated:** Le sens nous aide à naviguer d'un formulaire à un autre juste en cliquant avec le bouton droit
#
# Segment 82:
# **Original:** on data form. This is where we can add business rule which we created for this
# **Auto Translated:** sur le formulaire de données. C'est là que nous pouvons ajouter une règle commerciale que nous avons créée pour ce
#
# Segment 83:
# **Original:** application. We can say how we want to run this business rule. In the layout we
# **Auto Translated:** application. Nous pouvons dire comment nous voulons gérer cette règle commerciale. Dans la disposition, nous
#
# Segment 84:
# **Original:** can see different options if we want to suppress the data, suppress the rows,
# **Auto Translated:** Peut voir différentes options si nous voulons supprimer les données, supprimer les lignes,
#
# Segment 85:
# **Original:** suppress columns. We can define properties for the dimensions if we want to see the
# **Auto Translated:** supprimer les colonnes. Nous pouvons définir des propriétés pour les dimensions si nous voulons voir le
#
# Segment 86:
# **Original:** adious name instead of the member height, description. We can also define the segment
# **Auto Translated:** Nom adieux au lieu de la hauteur du membre, description. Nous pouvons également définir le segment
#
# Segment 87:
# **Original:** properties which is a row property and the column property and what we want to
# **Auto Translated:** propriétés qui est une propriété de ligne et la propriété de colonne et ce que nous voulons
#
# Segment 88:
# **Original:** see. We also have different options in terms of how we want to see the data in
# **Auto Translated:** voir. Nous avons également des options différentes en termes de la façon dont nous voulons voir les données dans
#
# Segment 89:
# **Original:** this particular form. Also have rules to validate certain conditions. I have created
# **Auto Translated:** cette forme particulière. Ont également des règles pour valider certaines conditions. J'ai créé
#
# Segment 90:
# **Original:** the data form by keeping the versions product, market, currency, plant type in the
# **Auto Translated:** le formulaire de données en conservant le produit des versions, le marché, la devise, le type d'usine
#
# Segment 91:
# **Original:** point of view scenario in the page. In the columns we have the year, period and the
# **Auto Translated:** Scénario de point de vue dans la page. Dans les colonnes, nous avons l'année, la période et le
#
# Segment 92:
# **Original:** account. In the rows we have the entity. I have used substitution variable or
# **Auto Translated:** compte. Dans les lignes, nous avons l'entité. J'ai utilisé une variable de substitution ou
#
# Segment 93:
# **Original:** user variable here. So selecting on the member selector icon we see the members but
# **Auto Translated:** Variable utilisateur ici. Donc en sélectionnant l'icône du sélecteur de membres, nous voyons les membres mais
#
# Segment 94:
# **Original:** also we see variables. We can define the variables which will help us in
# **Auto Translated:** Nous voyons également des variables. Nous pouvons définir les variables qui nous aideront dans
#
# Segment 95:
# **Original:** prepopulating the form dynamically. I have set a condition here for row 3.
# **Auto Translated:** Prépopulation de la forme dynamiquement. J'ai réglé une condition ici pour la ligne 3.
#
# Segment 96:
# **Original:** So if the currency value is more than 6000 then the tel should be in red. We can
# **Auto Translated:** Donc, si la valeur de la devise est supérieure à 6000, le TEL doit être en rouge. Nous pouvons
#
# Segment 97:
# **Original:** validate the condition and we will get the dialog box. We'll click on okay. We'll click on okay again.
# **Auto Translated:** Valider la condition et nous obtiendrons la boîte de dialogue. Nous cliquerons sur OK. Nous cliquerons à nouveau sur OK.
#
# Segment 98:
# **Original:** I will save this form. I will close this form. This is the form we edited. I'm going to open it
# **Auto Translated:** Je vais enregistrer ce formulaire. Je ferai ce formulaire. Ceci est la forme que nous avons modifiée. Je vais l'ouvrir
#
# Segment 99:
# **Original:** and
# **Auto Translated:** et
#
# Segment 100:
# **Original:** expanding. I can see that when I had 6000 it was highlighted as per the condition
# **Auto Translated:** Expansion. Je peux voir que lorsque j'en avais 6000, il a été mis en évidence selon la condition
#
# Segment 101:
# **Original:** and I can expand more. I also have the options to adjust cells like I can say this is 10 percent.
# **Auto Translated:** Et je peux développer plus. J'ai également les options pour ajuster les cellules comme je peux dire que c'est 10%.
#
# Segment 102:
# **Original:** So I can have a positive a negative value or a percentage and click on okay.
# **Auto Translated:** Je peux donc avoir une valeur négative positive ou un pourcentage et cliquer sur OK.
#
# Segment 103:
# **Original:** The cell is updated and we can see how the value is changed for the total year.
# **Auto Translated:** La cellule est mise à jour et nous pouvons voir comment la valeur est modifiée pour l'année totale.
#
# Segment 104:
# **Original:** Whenever the cell is updated in yellow when we save it the data is saved right away
# **Auto Translated:** Chaque fois que la cellule est mise à jour en jaune lorsque nous les enregistrons, les données sont enregistrées tout de suite
#
# Segment 105:
# **Original:** and we can see how the data is reflected. Just like Excel we can drag data
# **Auto Translated:** Et nous pouvons voir comment les données sont reflétées. Tout comme Excel, nous pouvons faire glisser des données
#
# Segment 106:
# **Original:** and bring in data to all these rows so that all the data for the quarter one will be updated
# **Auto Translated:** et apporter des données à toutes ces lignes afin que toutes les données du trimestre soient mises à jour
#
# Segment 107:
# **Original:** along with the total and I'm going to save it.
# **Auto Translated:** Avec le total et je vais le sauver.
#
# Segment 108:
# **Original:** I want to have this data reflected for all other numbers as well
# **Auto Translated:** Je veux également que ces données soient reflétées pour tous les autres chiffres
#
# Segment 109:
# **Original:** and for these I want to increase the data by 20 percent.
# **Auto Translated:** Et pour ceux-ci, je veux augmenter les données de 20%.
#
# Segment 110:
# **Original:** And for these I'm going to increase the data by 50 percent.
# **Auto Translated:** Et pour cela, je vais augmenter les données de 50%.
#
# Segment 111:
# **Original:** I also have the option to distribute the to copy paste the data.
# **Auto Translated:** J'ai également la possibilité de distribuer pour copier coller les données.
#
# Segment 112:
# **Original:** I also have the option to adjust the data grid level in terms of how I want to adjust it.
# **Auto Translated:** J'ai également la possibilité d'ajuster le niveau de la grille de données en termes de façon dont je souhaite l'ajuster.
#
# Segment 113:
# **Original:** Is it proportional or is it uniform? So let's say for quarter one quarter three
# **Auto Translated:** Est-ce proportionnel ou est-il uniforme? Alors disons pour le quart d'un quart trois
#
# Segment 114:
# **Original:** as I have data for July of the September I'm going to adjust the data proportionally
# **Auto Translated:** Comme j'ai des données pour juillet de septembre, je vais ajuster les données proportionnellement
#
# Segment 115:
# **Original:** and it's adjusted by 1000.
# **Auto Translated:** Et il est ajusté par 1000.
#
# Segment 116:
# **Original:** You can see how the data is adjusted.
# **Auto Translated:** Vous pouvez voir comment les données sont ajustées.
#
# Segment 117:
# **Original:** We can also add attachments, add comments
# **Auto Translated:** Nous pouvons également ajouter des pièces jointes, ajouter des commentaires
#
# Segment 118:
# **Original:** and attach supporting details from our local files and publish it.
# **Auto Translated:** et joindre les détails à l'appui de nos fichiers locaux et la publier.
#
# Segment 119:
# **Original:** The user will be able to see the username, the date on when the comment was made,
# **Auto Translated:** L'utilisateur pourra voir le nom d'utilisateur, la date à laquelle le commentaire a été fait,
#
# Segment 120:
# **Original:** what time and what's the comment and this can go.
# **Auto Translated:** Quelle heure et quel est le commentaire et cela peut aller.
#
# Segment 121:
# **Original:** So when any user can make comments who have access to the form and the cell
# **Auto Translated:** Ainsi, quand un utilisateur peut faire des commentaires qui ont accès au formulaire et à la cellule
#
# Segment 122:
# **Original:** what's the comment is made? It is in blue
# **Auto Translated:** Qu'est-ce que le commentaire est fait? C'est en bleu
#
# Segment 123:
# **Original:** which means we either have an attachment or a comment.
# **Auto Translated:** Ce qui signifie que nous avons une pièce jointe ou un commentaire.
#
# Segment 124:
# **Original:** We can also set the preference
# **Auto Translated:** Nous pouvons également définir la préférence
#
# Segment 125:
# **Original:** from the tools. We can set the language and the areas. We can set how we want to see the data,
# **Auto Translated:** des outils. Nous pouvons définir la langue et les zones. Nous pouvons définir comment nous voulons voir les données,
#
# Segment 126:
# **Original:** the precision, suppressions. We will set the user variables from here
# **Auto Translated:** La précision, les suppressions. Nous allons définir les variables utilisateur d'ici
#
# Segment 127:
# **Original:** by selecting the member selector and selecting the respective member and clicking on OK
# **Auto Translated:** en sélectionnant le sélecteur de membre et en sélectionnant le membre respectif et en cliquant sur OK
#
# Segment 128:
# **Original:** and then saving it.
# **Auto Translated:** puis le sauver.
# Generating French audio (grouped by sentences)...
# Merging audio and video...
# Merging audio with video...
# Moviepy - Building video output\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video output\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready output\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: output\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: output\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
