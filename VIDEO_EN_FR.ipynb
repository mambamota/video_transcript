# %% [markdown]
# 4211   4.2.1_L’utilisation des différentes fonctionnalités - 1

# %%
import os
import re
import ffmpeg
import pysrt
import time
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video       = "to translate/4.2.1_L’utilisation des différentes fonctionnalités - 1.mp4"
base_name         = os.path.splitext(os.path.basename(input_video))[0]
timestamp         = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir        = f"{base_name}_run_{timestamp}"
model_size        = "small"
update_existing   = True
USE_EDGE_TTS      = True  # still using Edge TTS for re-synthesis/timing

os.makedirs(output_dir, exist_ok=True)
input_name        = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio   = os.path.join(output_dir, f"{input_name}-extracted-audio.wav")
subtitle_file_fr  = os.path.join(output_dir, f"{input_name}-french.srt")
translated_audio  = os.path.join(output_dir, f"{input_name}-french.wav")
output_video      = os.path.join(output_dir, f"{input_name}-french.mp4")
review_file       = os.path.join(output_dir, "translation_review.txt")
debug_log_file    = os.path.join(output_dir, "translation_debug_log.txt")

# ===== Helper: Extract audio =====
def extract_audio():
    (ffmpeg
       .input(input_video)
       .output(extracted_audio, ac=1, ar=16000)
       .overwrite_output()
       .run(capture_stdout=True, capture_stderr=True)
    )
    return extracted_audio

# ===== Helper: Transcribe (assumes French audio) =====
def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    print(f"Detected language: {info.language}")
    return info.language, [
        {"start": s.start, "end": s.end, "text": s.text.strip()}
        for s in segments
    ]

# ===== Helper: SubRip time conversion & file generation =====
def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    h = int(seconds // 3600)
    seconds %= 3600
    m = int(seconds // 60)
    seconds %= 60
    ms = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=h, minutes=m, seconds=int(seconds), milliseconds=ms)

def generate_subtitle_file(segments, out_path):
    subs = pysrt.SubRipFile()
    for i, seg in enumerate(segments, 1):
        subs.append(pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(seg["start"]),
            end=time_to_subrip(seg["end"]),
            text=seg["text"]
        ))
    subs.save(out_path, encoding="utf-8")
    return out_path

# ===== Review-override parsing (no translation fallback) =====
def parse_review_file(path):
    text   = open(path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    hdr = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = hdr.search(blk)
        if not m: continue
        start_s, end_s = float(m.group(1)), float(m.group(2))
        ft, vs, pre, post, soffs, eoffs = None, "+0%", 0.0, 0.0, 0, 0
        phrases, inter = [], []
        for line in blk.splitlines():
            line=line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                inter = [max(0,int(x)) for x in parts.split(",")] if parts else []
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
        segments.append({
            "start_s": start_s, "end_s": end_s,
            "final_translation": ft or "",   # no translation fallback
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })
    print(f"✅ Parsed {len(segments)} review segments.")
    return segments

# ===== TTS & sync =====
async def robust_synthesize_phrase(phrase, out_mp3, voice="fr-FR-DeniseNeural", rate="+0%", max_retries=5):
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as sess:
                await edge_tts.Communicate(text=phrase, voice=voice, rate=rate).save(out_mp3)
                return
        except Exception as e:
            await asyncio.sleep(2**attempt + random.random())
    raise RuntimeError(f"TTS failed for phrase: {phrase[:30]}…")

def adjust_audio_duration(audio: AudioSegment, target_s: float) -> AudioSegment:
    tgt_ms = int(target_s*1000)
    curr  = len(audio)
    if curr > tgt_ms:   return audio[:tgt_ms]
    if curr < tgt_ms:   return audio + AudioSegment.silent(duration=(tgt_ms-curr))
    return audio

async def async_generate_audio_with_reviewOLD(
    subs_path, out_wav, debug_path, review_path
):
    # 1) Auto-generate a review file (simply echo transcript as final)
    subs = pysrt.open(subs_path)
    with open(review_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Adjust only timing/speed. Keep phrases as-is.\n")
        f.write("----------------------------------------------------------------\n\n")
        for i, sub in enumerate(subs, 1):
            start_s = sub.start.ordinal/1000
            end_s   = sub.end.ordinal/1000
            text    = sub.text.replace("\n"," ")
            f.write(f"Segment {i} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {text}\n")
            f.write(f"**Auto Translated:** {text}\n")
            f.write(f"**Final Translation:** {text}\n")
            f.write("**Voice Speed:** +0%\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write("**Inter-Phrase-Silence:** \n")
            f.write(f"- {text}\n\n")
            f.write("----------------------------------------------------------------\n\n")
    # 2) Parse overrides, then synthesize each segment
    segments = parse_review_file(review_path)
    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s, end_s = seg["start_s"], seg["end_s"]
        duration_ms    = int((end_s - start_s)*1000)
        text           = seg["final_translation"]
        rate           = seg["voice_speed"]
        pre_ms, post_ms= seg["pre_silence"], seg["post_silence"]
        soffs, eoffs   = seg["start_offset_ms"], seg["end_offset_ms"]

        # synthesize one clip
        tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}.mp3")
        await robust_synthesize_phrase(text, tmp_mp3, rate=rate)
        aud = AudioSegment.from_mp3(tmp_mp3)
        os.remove(tmp_mp3)
        aud = adjust_audio_duration(aud, (duration_ms - pre_ms - post_ms)/1000.0)

        # assemble with silences
        seg_audio = AudioSegment.silent(duration=pre_ms) + aud + AudioSegment.silent(duration=post_ms)
        if eoffs>0: seg_audio += AudioSegment.silent(duration=eoffs)
        elif eoffs<0: seg_audio = seg_audio[:eoffs]

        # position on timeline
        start_ms = int(start_s*1000) + soffs
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined = combined[:start_ms] + seg_audio

        debug.append(f"Segment {idx+1}: start={start_ms}ms, dur={len(seg_audio)}ms\n")

    # write out
    with open(debug_path, "w", encoding="utf-8") as df:
        df.write("Debug Log\n\n"); df.writelines(debug)
    combined.export(out_wav, format="wav")
    return out_wav



async def async_generate_audio_with_review(
    subs_path: str,
    out_wav: str,
    debug_path: str,
    review_path: str
):
    """
    1) Generate a review file from the French subtitles.
    2) Pause to allow manual edits of timing, text/phrases, silences, etc.
    3) Parse the (potentially edited) review file.
    4) Synthesize each segment via Edge TTS with the reviewed settings.
    5) Export the combined audio and write a debug log.
    """
    import pysrt
    from pydub import AudioSegment
    import tempfile
    import os
    import random
    import aiohttp
    import edge_tts

    # --- 1) Write out the review file ---
    subs = pysrt.open(subs_path)
    with open(review_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Edit any **Final Translation**, **Voice Speed**, **Pre/Post-Silence**,\n")
        f.write("**Start-Offset**, **End-Offset**, **Inter-Phrase-Silence** as needed.\n")
        f.write("----------------------------------------------------------------\n\n")
        for i, sub in enumerate(subs, 1):
            start_s = sub.start.ordinal / 1000.0
            end_s   = sub.end.ordinal / 1000.0
            text    = sub.text.replace("\n", " ")
            f.write(f"Segment {i} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {text}\n")
            f.write(f"**Auto Translated:** {text}\n")
            f.write(f"**Final Translation:** {text}\n")
            f.write("**Voice Speed:** +0%\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write("**Inter-Phrase-Silence:** \n")
            f.write(f"- {text}\n\n")
            f.write("----------------------------------------------------------------\n\n")
    print(f"✅ Review file created at: {review_path}")

    # --- 2) Pause for manual edits ---
    input("🖊️  Please open and edit the review file as needed, then press Enter to continue…\n")

    # --- 3) Parse the (possibly edited) review file ---
    segments = parse_review_file(review_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    # Helper to synthesize a single phrase robustly
    async def synthesize(phrase: str, tmp_mp3: str, rate: str):
        max_retries = 5
        for attempt in range(1, max_retries + 1):
            try:
                async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as sess:
                    await edge_tts.Communicate(text=phrase, voice="fr-FR-DeniseNeural", rate=rate).save(tmp_mp3)
                    return
            except Exception:
                await asyncio.sleep(2 ** attempt + random.random())
        raise RuntimeError(f"TTS failed for phrase: {phrase[:30]}…")

    # --- 4) Synthesize each segment & assemble timeline ---
    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        duration_ms = int((end_s - start_s) * 1000)

        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soffs   = seg["start_offset_ms"]
        eoffs   = seg["end_offset_ms"]

        # Synthesize one clip for the entire segment text
        tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_seg{idx}.mp3")
        await synthesize(text, tmp_mp3, rate)
        aud = AudioSegment.from_mp3(tmp_mp3)
        os.remove(tmp_mp3)

        # Adjust to fit allocated content time (minus pre/post)
        content_s = (duration_ms - pre_ms - post_ms) / 1000.0
        if content_s > 0:
            aud = adjust_audio_duration(aud, content_s)

        # Build segment audio with pre/post-silence and end-offset
        seg_audio = AudioSegment.silent(duration=pre_ms) + aud + AudioSegment.silent(duration=post_ms)
        if eoffs > 0:
            seg_audio += AudioSegment.silent(duration=eoffs)
        elif eoffs < 0:
            seg_audio = seg_audio[:eoffs]

        # Position on timeline with start-offset
        start_ms = int(start_s * 1000) + soffs
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined = combined[:start_ms] + seg_audio

        debug.append(f"Segment {idx+1}: start_at={start_ms}ms, seg_duration={len(seg_audio)}ms\n")

    # --- 5) Export debug log and full WAV ---
    with open(debug_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)

    combined.export(out_wav, format="wav")
    print(f"✅ Generated audio file at: {out_wav}")
    return out_wav





# ===== Merge back into the video =====
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        pad = AudioSegment.silent(duration=(video.duration-audio.duration)*1000)
        tmp = os.path.join(output_dir, "tmp_full.wav")
        (AudioSegment.from_file(translated_audio) + pad).export(tmp, format="wav")
        audio = AudioFileClip(tmp)
    final = video.set_audio(audio)
    final.write_videofile(output_video, codec="libx264", audio_codec="aac",
                          temp_audiofile="tmp-audio.m4a", remove_temp=True, threads=4)
    video.close(); audio.close()

# ===== Main =====
async def async_main():
    print("1) Extracting audio…")
    extract_audio()
    print("2) Transcribing to generate French subtitles…")
    _, segments = transcribe(extracted_audio)
    generate_subtitle_file(segments, subtitle_file_fr)
    print("3) Synthesizing adjusted French audio…")
    await async_generate_audio_with_review(subtitle_file_fr, translated_audio, debug_log_file, review_file)
    print("4) Merging into output video…")
    merge_audio_video()
    print(f"🎉 Done! Output video at: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# 1) Extracting audio…
# 2) Transcribing to generate French subtitles…
# Detected language: fr
# 3) Synthesizing adjusted French audio…
# ✅ Parsed 118 review segments.
# 4) Merging into output video…
# Moviepy - Building video 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250523_122935\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4.
# MoviePy - Writing audio in tmp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250523_122935\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250523_122935\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4
# 🎉 Done! Output video at: 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250523_122935\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4

# %%
import os
import re
import ffmpeg
import pysrt
import time
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video       = "to translate/4.2.1_L’utilisation des différentes fonctionnalités - 1.mp4"
base_name         = os.path.splitext(os.path.basename(input_video))[0]
timestamp         = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir        = f"{base_name}_run_{timestamp}"
model_size        = "small"
update_existing   = True
USE_EDGE_TTS      = True  # still using Edge TTS for re-synthesis/timing

os.makedirs(output_dir, exist_ok=True)
input_name        = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio   = os.path.join(output_dir, f"{input_name}-extracted-audio.wav")
subtitle_file_fr  = os.path.join(output_dir, f"{input_name}-french.srt")
translated_audio  = os.path.join(output_dir, f"{input_name}-french.wav")
output_video      = os.path.join(output_dir, f"{input_name}-french.mp4")
review_file       = os.path.join(output_dir, "translation_review.txt")
debug_log_file    = os.path.join(output_dir, "translation_debug_log.txt")

# ===== Helper: Extract audio =====
def extract_audio():
    (ffmpeg
       .input(input_video)
       .output(extracted_audio, ac=1, ar=16000)
       .overwrite_output()
       .run(capture_stdout=True, capture_stderr=True)
    )
    return extracted_audio

# ===== Helper: Transcribe (assumes French audio) =====
def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    print(f"Detected language: {info.language}")
    return info.language, [
        {"start": s.start, "end": s.end, "text": s.text.strip()}
        for s in segments
    ]

# ===== Helper: SubRip time conversion & file generation =====
def time_to_subripOLD(seconds: float) -> pysrt.SubRipTime:
    h = int(seconds // 3600)
    seconds %= 3600
    m = int(seconds // 60)
    seconds %= 60
    ms = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=h, minutes=m, seconds=int(seconds), milliseconds=ms)

def generate_subtitle_file(segments, out_path):
    subs = pysrt.SubRipFile()
    for i, seg in enumerate(segments, 1):
        subs.append(pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(seg["start"]),
            end=time_to_subrip(seg["end"]),
            text=seg["text"]
        ))
    subs.save(out_path, encoding="utf-8")
    return out_path

# ===== Review-override parsing (no translation fallback) =====
def parse_review_file(path):
    text   = open(path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    hdr = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = hdr.search(blk)
        if not m: continue
        start_s, end_s = float(m.group(1)), float(m.group(2))
        ft, vs, pre, post, soffs, eoffs = None, "+0%", 0.0, 0.0, 0, 0
        phrases, inter = [], []
        for line in blk.splitlines():
            line=line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                inter = [max(0,int(x)) for x in parts.split(",")] if parts else []
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
        segments.append({
            "start_s": start_s, "end_s": end_s,
            "final_translation": ft or "",   # no translation fallback
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })
    print(f"✅ Parsed {len(segments)} review segments.")
    return segments

# ===== TTS & sync =====
async def robust_synthesize_phrase(phrase, out_mp3, voice="fr-FR-DeniseNeural", rate="+0%", max_retries=5):
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as sess:
                await edge_tts.Communicate(text=phrase, voice=voice, rate=rate).save(out_mp3)
                return
        except Exception as e:
            await asyncio.sleep(2**attempt + random.random())
    raise RuntimeError(f"TTS failed for phrase: {phrase[:30]}…")

def adjust_audio_duration(audio: AudioSegment, target_s: float) -> AudioSegment:
    tgt_ms = int(target_s*1000)
    curr  = len(audio)
    if curr > tgt_ms:   return audio[:tgt_ms]
    if curr < tgt_ms:   return audio + AudioSegment.silent(duration=(tgt_ms-curr))
    return audio

async def async_generate_audio_with_reviewOLD(
    subs_path, out_wav, debug_path, review_path
):
    # 1) Auto-generate a review file (simply echo transcript as final)
    subs = pysrt.open(subs_path)
    with open(review_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Adjust only timing/speed. Keep phrases as-is.\n")
        f.write("----------------------------------------------------------------\n\n")
        for i, sub in enumerate(subs, 1):
            start_s = sub.start.ordinal/1000
            end_s   = sub.end.ordinal/1000
            text    = sub.text.replace("\n"," ")
            f.write(f"Segment {i} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {text}\n")
            f.write(f"**Auto Translated:** {text}\n")
            f.write(f"**Final Translation:** {text}\n")
            f.write("**Voice Speed:** +0%\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write("**Inter-Phrase-Silence:** \n")
            f.write(f"- {text}\n\n")
            f.write("----------------------------------------------------------------\n\n")
    # 2) Parse overrides, then synthesize each segment
    segments = parse_review_file(review_path)
    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s, end_s = seg["start_s"], seg["end_s"]
        duration_ms    = int((end_s - start_s)*1000)
        text           = seg["final_translation"]
        rate           = seg["voice_speed"]
        pre_ms, post_ms= seg["pre_silence"], seg["post_silence"]
        soffs, eoffs   = seg["start_offset_ms"], seg["end_offset_ms"]

        # synthesize one clip
        tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}.mp3")
        await robust_synthesize_phrase(text, tmp_mp3, rate=rate)
        aud = AudioSegment.from_mp3(tmp_mp3)
        os.remove(tmp_mp3)
        aud = adjust_audio_duration(aud, (duration_ms - pre_ms - post_ms)/1000.0)

        # assemble with silences
        seg_audio = AudioSegment.silent(duration=pre_ms) + aud + AudioSegment.silent(duration=post_ms)
        if eoffs>0: seg_audio += AudioSegment.silent(duration=eoffs)
        elif eoffs<0: seg_audio = seg_audio[:eoffs]

        # position on timeline
        start_ms = int(start_s*1000) + soffs
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined = combined[:start_ms] + seg_audio

        debug.append(f"Segment {idx+1}: start={start_ms}ms, dur={len(seg_audio)}ms\n")

    # write out
    with open(debug_path, "w", encoding="utf-8") as df:
        df.write("Debug Log\n\n"); df.writelines(debug)
    combined.export(out_wav, format="wav")
    return out_wav


async def async_generate_audio_with_reviewEXISTING(
    subs_path: str,
    out_wav: str,
    debug_path: str,
    review_path: str
):
    """
    1) Generate a review file from the French subtitles.
    2) Pause to allow manual edits of timing, text/phrases, silences, etc.
    3) Parse the (potentially edited) review file.
    4) Synthesize each segment via Edge TTS with the reviewed settings.
    5) Export the combined audio and write a debug log.
    """
    import pysrt
    from pydub import AudioSegment
    import tempfile
    import os
    import random
    import aiohttp
    import edge_tts

    # --- 1) Write out the review file ---
    subs = pysrt.open(subs_path)
    with open(review_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Edit any **Final Translation**, **Voice Speed**, **Pre/Post-Silence**,\n")
        f.write("**Start-Offset**, **End-Offset**, **Inter-Phrase-Silence** as needed.\n")
        f.write("----------------------------------------------------------------\n\n")
        for i, sub in enumerate(subs, 1):
            start_s = sub.start.ordinal / 1000.0
            end_s   = sub.end.ordinal / 1000.0
            text    = sub.text.replace("\n", " ")
            f.write(f"Segment {i} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {text}\n")
            f.write(f"**Auto Translated:** {text}\n")
            f.write(f"**Final Translation:** {text}\n")
            f.write("**Voice Speed:** +0%\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write("**Inter-Phrase-Silence:** \n")
            f.write(f"- {text}\n\n")
            f.write("----------------------------------------------------------------\n\n")
    print(f"✅ Review file created at: {review_path}")

    # --- 2) Pause for manual edits ---
    input("🖊️  Please open and edit the review file as needed, then press Enter to continue…\n")

    # --- 3) Parse the (possibly edited) review file ---
    segments = parse_review_file(review_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    # Helper to synthesize a single phrase robustly
    async def synthesize(phrase: str, tmp_mp3: str, rate: str):
        max_retries = 5
        for attempt in range(1, max_retries + 1):
            try:
                async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as sess:
                    await edge_tts.Communicate(text=phrase, voice="fr-FR-DeniseNeural", rate=rate).save(tmp_mp3)
                    return
            except Exception:
                await asyncio.sleep(2 ** attempt + random.random())
        raise RuntimeError(f"TTS failed for phrase: {phrase[:30]}…")

    # --- 4) Synthesize each segment & assemble timeline ---
    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        duration_ms = int((end_s - start_s) * 1000)

        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soffs   = seg["start_offset_ms"]
        eoffs   = seg["end_offset_ms"]

        # Synthesize one clip for the entire segment text
        tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_seg{idx}.mp3")
        await synthesize(text, tmp_mp3, rate)
        aud = AudioSegment.from_mp3(tmp_mp3)
        os.remove(tmp_mp3)

        # Adjust to fit allocated content time (minus pre/post)
        content_s = (duration_ms - pre_ms - post_ms) / 1000.0
        if content_s > 0:
            aud = adjust_audio_duration(aud, content_s)

        # Build segment audio with pre/post-silence and end-offset
        seg_audio = AudioSegment.silent(duration=pre_ms) + aud + AudioSegment.silent(duration=post_ms)
        if eoffs > 0:
            seg_audio += AudioSegment.silent(duration=eoffs)
        elif eoffs < 0:
            seg_audio = seg_audio[:eoffs]

        # Position on timeline with start-offset
        start_ms = int(start_s * 1000) + soffs
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined = combined[:start_ms] + seg_audio

        debug.append(f"Segment {idx+1}: start_at={start_ms}ms, seg_duration={len(seg_audio)}ms\n")

    # --- 5) Export debug log and full WAV ---
    with open(debug_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)

    combined.export(out_wav, format="wav")
    print(f"✅ Generated audio file at: {out_wav}")
    return out_wav

async def async_generate_audio_with_reviewandramoavyeo(
    subs_path: str,
    out_wav: str,
    debug_path: str,
    review_path: str
):
    """
    1) Generate a review file from the French subtitles.
    2) Pause to allow manual edits of timing, text/phrases, silences, etc.
    3) Parse the (possibly edited) review file.
    4) Extract the natural pause durations from the original French audio.
    5) Synthesize each segment via Edge TTS, inserting the original pauses.
    6) Export the combined audio and write a debug log.
    """
    import pysrt
    from pydub import AudioSegment
    from pydub.silence import detect_silence, detect_nonsilent
    import tempfile
    import os
    import random
    import aiohttp
    import edge_tts

    # --- Load original French audio once ---
    # 'extracted_audio' should be the path to your original French WAV
    orig_audio = AudioSegment.from_file(extracted_audio, format="wav")

    # --- 1) Write out the review file ---
    subs = pysrt.open(subs_path)
    with open(review_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Edit any **Final Translation**, **Voice Speed**, **Pre/Post-Silence**,\n")
        f.write("**Start-Offset**, **End-Offset**, **Inter-Phrase-Silence** as needed.\n")
        f.write("----------------------------------------------------------------\n\n")
        for i, sub in enumerate(subs, 1):
            start_s = sub.start.ordinal / 1000.0
            end_s   = sub.end.ordinal / 1000.0
            text    = sub.text.replace("\n", " ")
            f.write(f"Segment {i} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {text}\n")
            f.write(f"**Auto Translated:** {text}\n")
            f.write(f"**Final Translation:** {text}\n")
            f.write("**Voice Speed:** +0%\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write("**Inter-Phrase-Silence:** \n")
            f.write(f"- {text}\n\n")
            f.write("----------------------------------------------------------------\n\n")
    print(f"✅ Review file created at: {review_path}")

    # --- 2) Pause for manual edits ---
    input("🖊️  Please open and edit the review file as needed, then press Enter to continue…\n")

    # --- 3) Parse the (possibly edited) review file ---
    segments = parse_review_file(review_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    # Helper to synthesize a single phrase robustly
    async def synthesize(phrase: str, tmp_mp3: str, rate: str):
        max_retries = 5
        for attempt in range(1, max_retries + 1):
            try:
                async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)):
                    await edge_tts.Communicate(
                        text=phrase,
                        voice="fr-FR-DeniseNeural",
                        rate=rate
                    ).save(tmp_mp3)
                    return
            except Exception:
                await asyncio.sleep(2 ** attempt + random.random())
        raise RuntimeError(f"TTS failed for phrase: {phrase[:30]}…")

    # --- 4) Extract natural pauses & synthesize each segment ---
    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        duration_ms = int((end_s - start_s) * 1000)

        # 4a) Extract the matching slice from the original
        slice_start = int(start_s * 1000)
        slice_end   = int(end_s   * 1000)
        orig_slice  = orig_audio[slice_start:slice_end]

        # 4b) Detect silent intervals (natural pauses)
        raw_silences = detect_silence(
            orig_slice,
            min_silence_len=50,
            silence_thresh=orig_slice.dBFS - 16
        )
        # Convert to durations
        seg["inter_phrase_silences"] = [
            end - start for start, end in raw_silences
        ]

        # 4c) Prepare TTS settings
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soffs   = seg["start_offset_ms"]
        eoffs   = seg["end_offset_ms"]

        # 4d) Synthesize the full-segment text
        tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_seg{idx}.mp3")
        await synthesize(text, tmp_mp3, rate)
        aud = AudioSegment.from_mp3(tmp_mp3)
        os.remove(tmp_mp3)

        # 4e) Trim any TTS trailing silence
        nons = detect_nonsilent(aud, min_silence_len=50, silence_thresh=aud.dBFS - 16)
        if nons:
            aud = aud[nons[0][0]:nons[-1][1]]

        # 4f) Adjust to fit allocated speech time
        speech_time_ms = duration_ms - pre_ms - post_ms
        if speech_time_ms > 0:
            aud = adjust_audio_duration(aud, speech_time_ms / 1000.0)

        # 4g) Assemble segment audio with original pauses
        seg_audio = AudioSegment.silent(duration=pre_ms)
        phrases = [text]  # using full text; if you split into sub-phrases, loop here
        # here we treat the whole text as one phrase; for multiple phrases, you'd split and loop:
        seg_audio += aud
        for pause in seg["inter_phrase_silences"]:
            seg_audio += AudioSegment.silent(duration=pause)
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Apply end-offset
        if eoffs > 0:
            seg_audio += AudioSegment.silent(duration=eoffs)
        elif eoffs < 0:
            seg_audio = seg_audio[:eoffs]

        # 4h) Position on the combined timeline
        start_ms = int(start_s * 1000) + soffs
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined = combined[:start_ms] + seg_audio

        debug.append(
            f"Segment {idx+1}: start_at={start_ms}ms, duration={len(seg_audio)}ms, "
            f"pauses={seg['inter_phrase_silences']}\n"
        )

    # --- 5) Export debug log and final WAV ---
    with open(debug_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)

    combined.export(out_wav, format="wav")
    print(f"✅ Generated audio file at: {out_wav}")
    return out_wav


# ====

import re
import pysrt
from pydub import AudioSegment
from pydub.silence import detect_silence, detect_nonsilent
import tempfile
import os
import random
import aiohttp
import edge_tts
import asyncio

# ——— Helper: convert seconds → SubRipTime —————————————————————————————
def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes,
                            seconds=int(seconds), milliseconds=milliseconds)

# ——— Helper: split Whisper segments into safe-duration groups ————————
def split_long_groups(groups, max_group_duration_secs):
    new = []
    for group in groups:
        start_s = group[0].start
        end_s   = group[-1].end
        total   = end_s - start_s
        if total <= max_group_duration_secs:
            new.append(group)
            continue

        temp = []
        temp_start = start_s
        last_safe = None
        for idx, item in enumerate(group):
            temp.append(item)
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe = idx
            current_end = item.end
            if (current_end - temp_start) >= max_group_duration_secs:
                if last_safe is not None:
                    new.append(temp[: last_safe+1])
                    temp = temp[last_safe+1 :]
                else:
                    new.append(temp)
                    temp = []
                temp_start = temp[0].start if temp else current_end
                last_safe = None

        if temp:
            new.append(temp)
    return new

# ——— Helper: ensure groups end in punctuation ——————————————————
def enforce_punctuation_boundaries(groups):
    i = 0
    safe_p = re.compile(r"[.!?,;:]$")
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not safe_p.search(last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1
    return groups

# ——— Updated async_generate_audio_with_review ———————————————————————
async def async_generate_audio_with_review(
    subtitle_path: str,
    out_wav: str,
    debug_path: str,
    review_path: str,
    max_group_duration: float = 25.0
):
    """
    1) Re-run Whisper on the already-extracted French audio.
    2) Group into sentence-based segments (max duration X s).
    3) Write & pause for manual review (review_path).
    4) Parse review file.
    5) Extract original pauses from global 'extracted_audio'.
    6) TTS synth per segment with DeniseNeural + original pauses.
    7) Export combined WAV to out_wav and debug log to debug_path.
    """
    import re
    import pysrt
    from faster_whisper import WhisperModel
    from pydub import AudioSegment
    from pydub.silence import detect_silence, detect_nonsilent
    import aiohttp, edge_tts, tempfile, os, random

    # 1) Transcribe original French audio again
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    raw_segments, _ = model.transcribe(extracted_audio, beam_size=5)

    # Wrap for grouping
    class Seg:
        def __init__(self, start, end, text):
            self.start = start
            self.end   = end
            self.text  = text.strip()

    pys = [Seg(s.start, s.end, s.text) for s in raw_segments]

    # 2) Group into sentence chunks
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for s in pys:
        cur.append(s)
        if sentence_end.search(s.text):
            groups.append(cur); cur = []
    if cur: groups.append(cur)

    # split & enforce
    groups = split_long_groups(groups, max_group_duration)
    groups = enforce_punctuation_boundaries(groups)

    # 3) Write review file for manual edits
    with open(review_path, "w", encoding="utf-8") as f:
        f.write("Review File — ajustez textes, silences, offsets…\n")
        f.write("------------------------------------------------\n\n")
        for i, group in enumerate(groups, 1):
            start_s = group[0].start
            end_s   = group[-1].end
            original = " ".join(g.text for g in group)
            f.write(f"Segment {i} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Final Translation:** {original}\n")
            f.write("**Voice Speed:** +0%\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write("**Inter-Phrase-Silence:** \n")
            # default phrase list
            phrases = re.split(r"(?<=[.!?])\s+", original)
            for ph in phrases:
                f.write(f"- {ph.strip()}\n")
            f.write("\n------------------------------------------------\n\n")
    print(f"✅ Review file at: {review_path}")
    input("🖊️ Éditez la review file puis appuyez sur Entrée pour continuer…")

    # 4) Parse edited review
    segments = parse_review_file(review_path)

    # 5) Load original for pause detection
    orig_audio = AudioSegment.from_file(extracted_audio, format="wav")
    combined   = AudioSegment.silent(duration=0)
    debug      = []

    # synth helper
    async def synth(phrase, tmp, rate):
        for _ in range(5):
            try:
                async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)):
                    await edge_tts.Communicate(text=phrase,
                                               voice="fr-FR-DeniseNeural",
                                               rate=rate).save(tmp)
                    return
            except:
                await asyncio.sleep(0.5 + random.random())
        raise RuntimeError("TTS failed")

    # 6) Build each segment
    for idx, seg in enumerate(segments):
        s_s, e_s = seg["start_s"], seg["end_s"]
        dur_ms    = int((e_s - s_s) * 1000)
        slice_ms  = (int(s_s*1000), int(e_s*1000))
        orig_slice = orig_audio[slice_ms[0]:slice_ms[1]]

        # natural pauses
        raw_sil = detect_silence(orig_slice,
                                 min_silence_len=50,
                                 silence_thresh=orig_slice.dBFS - 16)
        seg["inter_phrase_silences"] = [e - s for s, e in raw_sil]

        # synth
        tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp{idx}.mp3")
        await synth(seg["final_translation"], tmp_mp3, seg["voice_speed"])
        aud = AudioSegment.from_mp3(tmp_mp3); os.remove(tmp_mp3)

        # trim
        nons = detect_nonsilent(aud, min_silence_len=50, silence_thresh=aud.dBFS - 16)
        if nons:
            aud = aud[nons[0][0]:nons[-1][1]]

        # fit speech window
        speech_ms = max(0, dur_ms - seg["pre_silence"] - seg["post_silence"])
        aud = adjust_audio_duration(aud, speech_ms/1000.0)

        # assemble with pauses
        seg_a = AudioSegment.silent(duration=seg["pre_silence"]) + aud
        for p in seg["inter_phrase_silences"]:
            seg_a += AudioSegment.silent(duration=p)
        seg_a += AudioSegment.silent(duration=seg["post_silence"])

        # end-offset
        eo = seg["end_offset_ms"]
        seg_a = seg_a if eo>=0 else seg_a[:eo]
        if eo>0: seg_a += AudioSegment.silent(duration=eo)

        # place on timeline
        start_ms = int(s_s*1000) + seg["start_offset_ms"]
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        combined = combined[:start_ms] + seg_a

        debug.append(f"Seg {idx+1}: start={start_ms}ms, dur={len(seg_a)}ms, pauses={seg['inter_phrase_silences']}\n")

    # 7) Export
    with open(debug_path, "w", encoding="utf-8") as df:
        df.write("Debug Log\n\n"); df.writelines(debug)
    combined.export(out_wav, format="wav")
    print(f"✅ Generated audio at: {out_wav}")
    return out_wav

# ====


# ===== Merge back into the video =====
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        pad = AudioSegment.silent(duration=(video.duration-audio.duration)*1000)
        tmp = os.path.join(output_dir, "tmp_full.wav")
        (AudioSegment.from_file(translated_audio) + pad).export(tmp, format="wav")
        audio = AudioFileClip(tmp)
    final = video.set_audio(audio)
    final.write_videofile(output_video, codec="libx264", audio_codec="aac",
                          temp_audiofile="tmp-audio.m4a", remove_temp=True, threads=4)
    video.close(); audio.close()

# ===== Main =====
async def async_main():
    print("1) Extracting audio…")
    extract_audio()
    print("2) Transcribing to generate French subtitles…")
    _, segments = transcribe(extracted_audio)
    generate_subtitle_file(segments, subtitle_file_fr)
    print("3) Synthesizing adjusted French audio…")
    await async_generate_audio_with_review(subtitle_file_fr, translated_audio, debug_log_file, review_file)
    print("4) Merging into output video…")
    merge_audio_video()
    print(f"🎉 Done! Output video at: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# 1) Extracting audio…
# 2) Transcribing to generate French subtitles…
# Detected language: fr
# 3) Synthesizing adjusted French audio…
# ✅ Review file at: 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250524_014131\translation_review.txt
# ✅ Parsed 78 review segments.
# ✅ Generated audio at: 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250524_014131\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.wav
# 4) Merging into output video…
# Moviepy - Building video 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250524_014131\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4.
# MoviePy - Writing audio in tmp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250524_014131\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250524_014131\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4
# 🎉 Done! Output video at: 4.2.1_L’utilisation des différentes fonctionnalités - 1_run_20250524_014131\4.2.1_L’utilisation des différentes fonctionnalités - 1-french.mp4

# %% [markdown]
# LAST LAST VERSION 424

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent
from pydub.silence import detect_silence

# (Assurez-vous que robust_synthesize_phrase est importé et synchrone ici,
#  ou adaptez-le en appelant un TTS synchrone de votre choix.)

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up


def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")



def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) On regroupe et on split/merge les sous-titres exactement
       comme le fera l'audio.
    2) On écrit un review file où l'on affiche :
       - phrase par phrase (la liste exacte via "- ")
       - pre / post silence
       - voice speed
       - start/end offset
       - inter-phrase silences (N–1 valeurs pour N phrases)
       - measured-inter-phrase silences (durées réelles TTS)
    """
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regrouper par phrase (détection ponctuation en fin de sous-titre)
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text):
            groups.append(cur); cur = []
    if cur:
        groups.append(cur)

    # 2) Éclatement des groupes trop longs
    def split_long(gs, max_s):
        out = []
        for g in gs:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end - start <= max_s:
                out.append(g)
            else:
                mid = len(g)//2
                out.extend([g[:mid], g[mid:]])
        return out
    groups = split_long(groups, max_group_duration_secs)

    # 3) Forcer ponctuation de fin de groupe
    i = 0
    safe_punct = re.compile(r"[.!?,;:]$")
    while i < len(groups):
        if not safe_punct.search(groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4) Écriture du fichier de review
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, "
                "**Start-Offset:**, **End-Offset:**, **Inter-Phrase-Silence:**\n")
        f.write("Le champ **Measured-Inter-Phrase-Silence:** indique la pause réelle TTS détectée.\n")
        f.write("mais **ne touchez pas** la liste des phrases (lignes qui commencent par '- ').\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal / 1000
            end_s   = group[-1].end.ordinal   / 1000

            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # découpage phrases
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]

            # silences internes par défaut
            n = len(phrases)
            inter_silences = ",".join("0" for _ in range(max(0, n-1)))

            # valeurs par défaut
            pre_ms, post_ms = 0, 100
            start_offset, end_offset = 0, 0
            voice_speed = "+0%"

            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** {voice_speed}\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Start-Offset:** {start_offset}\n")
            f.write(f"**End-Offset:** {end_offset}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_silences}\n")
            for ph in phrases:
                f.write(f"- {ph}\n")

            # ——— Mesure des silences “naturels” entre phrases ———
            try:
                # 1) Synthèse rapide du segment complet
                tmp_all = os.path.join(tempfile.gettempdir(), f"tts_segment_{idx}.mp3")
                asyncio.run(robust_synthesize_phrase(auto_tr, tmp_all, rate=voice_speed))
                raw = AudioSegment.from_mp3(tmp_all)
                os.remove(tmp_all)

                # 2) Détection des silences ≥ 50 ms (on capte tous)
                raw_sil = detect_silence(
                    raw,
                    min_silence_len=200,
                    silence_thresh=raw.dBFS - 16
                )
                # 3) On ne garde que les N–1 plus longues, dans l’ordre chronologique
                #    pour correspondre aux N phrases
                n_breaks = max(0, len(phrases) - 1)
                # calculer (durée, position) pour chaque pause
                durs_pos = [(end - start, start) for start, end in raw_sil]
                # sélectionner les N–1 plus longues
                longest = sorted(durs_pos, key=lambda x: x[0], reverse=True)[:n_breaks]
                # remettre dans l’ordre temporel
                longest.sort(key=lambda x: x[1])
                measured = [dur for dur, _ in longest]

                f.write(f"**Measured-Inter-Phrase-Silence:** {','.join(str(x) for x in measured)}\n")
            except Exception:
                f.write(f"**Measured-Inter-Phrase-Silence:** \n")
            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Review file créé : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")



# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt


def parse_review_file(review_file_path):
    """
    Lit le review file et renvoie une liste de dicts avec :
      - start_s, end_s, original, final_translation, voice_speed
      - pre_silence, post_silence, start_offset_ms, end_offset_ms
      - phrases (list de phrases) et inter_phrase_silences (liste de silences internes)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): 
            continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft, vs = None, "+0%"
        pre, post = 0.0, 0.0
        soffs, eoffs = 0, 0
        phrases = []
        inter = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if parts:
                    inter = [max(0, int(x)) for x in parts.split(",")]
            elif line.startswith("- "):
                phrases.append(line[2:].strip())

        segments.append({
            "start_s": start_s,
            "end_s": end_s,
            "final_translation": ft or "",
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # 1) (Re)génération systématique du review file
    generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )
    print("✅ Review file régénéré, pensez à y reporter vos offsets personnalisés si besoin.")

    # 2) Lecture du review file enrichi
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        # Récupération des settings
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = int(seg["pre_silence"])
        post_ms = int(seg["post_silence"])
        soff    = seg["start_offset_ms"]
        eoff    = seg["end_offset_ms"]

        # Phrase splitting & TTS
        # phrases = split_french_phrases(text)
        # weights = calculate_phrase_weights(text, phrases)
        # phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)
        
        
        
                # Phrase splitting & TTS
        if idx == 9:
            # Segment 10 : split manuel pour bien isoler “Nous devons simplement…”
            phrases = [
                "Nous allons maintenant passer en revue la sécurité au niveau des données.",
                "Les intersections valides vous permettent de contrôler la saisie en définissant des combinaisons valides de membres.",
                "Nous devons simplement définir ces combinaisons et les enregistrer.",
                "Nous disposons aussi d’une sécurité au niveau cellulaire, qui gère l’accès à chaque cellule selon les dimensions et sélections de membres.",
                "Pour créer et configurer un formulaire de données depuis la page d’accueil, cliquez sur 'Données'.",
                "Sous Actions, choisissez Créer un formulaire ad hoc ou Créer un formulaire.",
                "Je clique sur Créer un formulaire, puis j’entre un nom et sélectionne le cube.",
                "Ensuite, je glisse les dimensions sur les lignes et colonnes, ou sur les pages selon le cas.",
                "J’ajoute les membres requis via l’icône du sélecteur.",
                "Enfin, je peux personnaliser l’affichage et ajouter des menus si nécessaire."
            ]
            # égaliser les poids si on veut un partage uniforme
            weights = [1/len(phrases)] * len(phrases)
            # et forcer toutes les pauses internes à zéro
            seg["inter_phrase_silences"] = [0] * (len(phrases) - 1)
        else:
            phrases = split_french_phrases(text)
            weights = calculate_phrase_weights(text, phrases)
            phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)

        # Budget pour la synthèse seule
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # Synthèse phrase par phrase
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s   = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, rate=rate)
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)
            aud = adjust_audio_duration(aud, dur_s)
            
            
            # # —————> Trim uniquement pour le segment 10 (idx==9)
            # if idx == 9:
            #     # détecter les portions non silencieuses (min_silence_len=50ms)
            #     nons = detect_nonsilent(aud, min_silence_len=50, silence_thresh=aud.dBFS - 16)
            #     if nons:
            #         start_trim, end_trim = nons[0][0], nons[-1][1]
            #         aud = aud[start_trim:end_trim]
            
            
            # === debug additionnel pour seg 10 ===
            if idx == 9:
                debug.append(
                    f"  Phrase {i+1}/{len(phrases)}: «{ph[:30]}…» "
                    f"cible={dur_s*1000:.0f}ms, réel={len(aud)}ms\n"
                )                       
            
            phrase_audios.append(aud)

        # Inter-phrase silences
        n_inter = max(0, len(phrases) - 1)
        if seg.get("inter_phrase_silences"):
            inter_applied = seg["inter_phrase_silences"][:n_inter]
            inter_applied += [0] * (n_inter - len(inter_applied))
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            sil_ms = (available // n_inter) if (n_inter and available>0) else 0
            inter_applied = [sil_ms] * n_inter

        # Reconstruction du segment
        seg_audio = AudioSegment.silent(duration=pre_ms)
        for i, aud in enumerate(phrase_audios):
            seg_audio += aud
            if i < len(inter_applied):
                seg_audio += AudioSegment.silent(duration=inter_applied[i])
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Offset de fin
        if eoff > 0:
            seg_audio += AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        # Mesure du décalage pour le debug
        nons2 = detect_nonsilent(seg_audio,
                                 min_silence_len=50,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (len(seg_audio)-post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000) + soff
        abs_e_v = int(end_s   * 1000) + eoff
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v


        if idx == 9:
            # log des silences insérés
            for j, sil in enumerate(inter_applied):
                debug.append(f"  Silence {j+1}/{len(inter_applied)}: {sil}ms\n")
            debug.append(f"  Segment10 total length: {len(seg_audio)}ms (should be {total_ms}ms)\n")


        # Placement sur la timeline
        start_ms = int(start_s * 1000) + soff
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=start_ms - len(combined))
        elif len(combined) > start_ms and soff < 0:
            combined = combined[:start_ms]
        combined += seg_audio

        # Enregistrement pour debug
        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"inter={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        )

    # Export debug & wav
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path


async def async_generate_translated_audio_with_sync_using_reviewLASTMAISPASOK(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # 1) Génération du review file si pas existant ou si on veut l'écraser
    if not os.path.exists(review_file_path) or update_existing:
        generate_translation_review_file(
            subtitle_source_path,
            review_file_path,
            max_group_duration_secs=25.0
        )
        print("✅ Review file créé ou mis à jour.")
    else:
        print("ℹ️ Review file existant conservé (update_existing=False).")

    # 2) Lecture du review file enrichi
    segments = parse_review_file(review_file_path)

    # 3) Override post-parse pour le segment 10 (idx 9)
    if len(segments) > 9:
        segments[9]["start_offset_ms"] = segments[9].get("start_offset_ms", -6500)
        print(f"⚙️ Segment 10 : start_offset_ms fixé à {segments[9]['start_offset_ms']}ms")

    combined = AudioSegment.silent(duration=0)
    debug    = []

    # 4) Boucle de génération audio
    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        # Réglages utilisateur
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = int(seg["pre_silence"])
        post_ms = int(seg["post_silence"])
        soff    = seg["start_offset_ms"]
        eoff    = seg["end_offset_ms"]

        # Phrase splitting & TTS
        if idx == 9:
            phrases = [
                "Nous allons maintenant regarder la sécurité au niveau des données.",
                "Les intersections valides peuvent vous aider à contrôler la saisie des données en définissant des combinaisons valides de membres de la dimension, pour éviter les entrées de données non valides.",
                "Nous devons simplement définir les combinaisons et l'enregistrer.",
                "Nous avons également une sécurité au niveau des cellules, qui contrôle l'accès aux cellules individuelles en fonction des dimensions et des sélections de membres.",
                "Nous pouvons créer une nouvelle sécurité ou faire une importation.",
                "Voyons comment créer et configurer un formulaire de données.",
                "À partir de la page d'accueil, cliquez sur la carte Données.",
                "Sous actions, nous pouvons créer un ad hoc ou créer un formulaire.",
                "Je vais cliquer sur Créer un formulaire.",
                "Nous devons entrer le nom.",
                "Nous devrons sélectionner le cube.",
                "Nous aurons toutes les dimensions ici.",
                "Nous devons faire glisser les dimensions sur les lignes et colonnes respectives.",
                "Nous pouvons également avoir des dimensions sur les pages.",
                "Nous devrons sélectionner les membres en conséquence.",
                "Cliquer sur l'icône me donnera le sélecteur de membres et je peux ajouter le membre requis.",
                "J'ai la possibilité de personnaliser en fonction de la façon dont je veux voir les données si j'ai besoin de menus."
            ]
            weights = [1/len(phrases)] * len(phrases)
            seg["inter_phrase_silences"] = seg.get(
                "inter_phrase_silences",
                [0] * (len(phrases) - 1)
            )
        else:
            phrases = split_french_phrases(text)
            weights = calculate_phrase_weights(text, phrases)
            phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)

        # Budget TTS
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # Synthèse phrase par phrase
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s   = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, rate=rate)
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)
            aud = adjust_audio_duration(aud, dur_s)

            if idx == 9:
                debug.append(
                    f"  Phrase {i+1}/{len(phrases)}: «{ph[:30]}…» "
                    f"cible={dur_s*1000:.0f}ms, réel={len(aud)}ms\n"
                )
            phrase_audios.append(aud)

        # Silences inter-phrase
        n_inter = max(0, len(phrases) - 1)
        if seg.get("inter_phrase_silences"):
            inter_applied = seg["inter_phrase_silences"][:n_inter]
            inter_applied += [0] * (n_inter - len(inter_applied))
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            sil_ms = (available // n_inter) if (n_inter and available > 0) else 0
            inter_applied = [sil_ms] * n_inter

        # Reconstruction du segment
        seg_audio = AudioSegment.silent(duration=pre_ms)
        for i, aud in enumerate(phrase_audios):
            seg_audio += aud
            if i < len(inter_applied):
                seg_audio += AudioSegment.silent(duration=inter_applied[i])
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Offset de fin
        if eoff > 0:
            seg_audio += AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        # Mesure du décalage pour le debug
        nons2 = detect_nonsilent(
            seg_audio,
            min_silence_len=50,
            silence_thresh=seg_audio.dBFS - 16
        )
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (len(seg_audio) - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000) + soff
        abs_e_v = int(end_s   * 1000) + eoff
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        if idx == 9:
            for j, sil in enumerate(inter_applied):
                debug.append(f"  Silence {j+1}/{len(inter_applied)}: {sil}ms\n")
            debug.append(f"  Segment10 total length: {len(seg_audio)}ms (should be {total_ms}ms)\n")

        # Placement sur la timeline (avec start_offset corrigé)
        start_ms = int(start_s * 1000) + soff
        gap = start_ms - len(combined)
        combined += AudioSegment.silent(duration=max(0, gap))
        combined += seg_audio
        

        # Enregistrement debug global
        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"inter={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        )

    # 5) Export debug & wav
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path

# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais jeter un œil aux confi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Actuellement, je vais ouvrir u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer ce l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également planifi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur le télépho…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais déplacer des détails s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Error] Attempt 1/10 failed for phrase: 'Pour cette dimension particuli…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305CE60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant examine…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections de valeur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Error] Attempt 1/10 failed for phrase: 'Nous avons également une sécur…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D490> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Error] Attempt 2/10 failed for phrase: 'Nous avons également une sécur…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D010> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.9s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Error] Attempt 3/10 failed for phrase: 'Nous avons également une sécur…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305C9E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.8s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sur la base des dimensions et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_16.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment créer et configurer un…'
# [Error] Attempt 1/10 failed for phrase: 'Comment créer et configurer un…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D640> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comment créer et configurer un…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_17.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous des actions, nous pouvons…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_18.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons entrer le nom. Nou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_19.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous aurons toutes les dimensi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_20.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_21.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Error] Attempt 1/10 failed for phrase: 'Nous devrons sélectionner les …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D370> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_22.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai la possibilité de personn…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_23.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Beaucoup nous aident à navigue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_24.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_25.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons dire comment nous…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305C9E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_26.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_27.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également définir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305C710> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_28.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé ce formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_29.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_30.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais enregistrer ce formula…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D5B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_31.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Error] Attempt 1/10 failed for phrase: 'La cellule est mise à jour et …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D2E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_32.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_33.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais également faire réfléc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_34.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour ceux-ci, je vais augme…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_35.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_36.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_37.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce proportionnel ou est-il…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_38.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_39.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_40.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_41.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, quand un utilisateur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_42.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_43.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_44.mp3
# ✅ Review file créé : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_222557\translation_review.txt (44 segments)
# ✅ Review file créé ou mis à jour.
# ✅ Parsed 27 segments depuis le review file.
# ⚙️ Segment 10 : start_offset_ms fixé à -6500ms
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir les configura…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité au niveau de EPM c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Error] Attempt 1/10 failed for phrase: 'Ceci ouvrira la fenêtre de Cal…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305FE30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Error] Attempt 2/10 failed for phrase: 'Ceci ouvrira la fenêtre de Cal…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305F9B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir l'application…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'expansion nous montrera EPBC…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux importer et je peux vo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai sélectionné le cube…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner Règles co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le système indiquera que la rè…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les administrateurs utilisent …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Error] Attempt 1/10 failed for phrase: 'Nous avons toutes les dimensio…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305E180> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La règle va copier les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais donc le valider et l'e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais ouvrir un …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour FY23, je n'ai pas de donn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Error] Attempt 1/10 failed for phrase: 'Vous voyez comment les données…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305E690> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Error] Attempt 2/10 failed for phrase: 'Vous voyez comment les données…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305E7B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.8s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Error] Attempt 1/10 failed for phrase: 'Je peux l'exécuter à partir du…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305FD10> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Error] Attempt 1/10 failed for phrase: 'Pour en savoir plus sur la séc…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D640> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a aussi des groupes défin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité attribue la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si j'ajoute le groupe Account …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant regarde…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections valides peuv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons simplement définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer une nouvell…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment créer et config…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous actions, nous pouvons cré…'
# [Error] Attempt 1/10 failed for phrase: 'Sous actions, nous pouvons cré…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305E2A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Sous actions, nous pouvons cré…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur Créer un f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons entrer le nom.…'
# [Error] Attempt 1/10 failed for phrase: 'Nous devons entrer le nom.…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305FB60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous devons entrer le nom.…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner le c…'
# [Error] Attempt 1/10 failed for phrase: 'Nous devrons sélectionner le c…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305DFD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous devrons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous aurons toutes les dimensi…'
# [Error] Attempt 1/10 failed for phrase: 'Nous aurons toutes les dimensi…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305FF50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous aurons toutes les dimensi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons faire glisser les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai la possibilité de personn…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305E060> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_16.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Error] Attempt 1/10 failed for phrase: 'C'est là que nous pouvons ajou…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305FAD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également différent…'
# [Error] Attempt 1/10 failed for phrase: 'Nous avons également différent…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305DA30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous avons également différent…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a également des règles po…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé le formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Error] Attempt 1/10 failed for phrase: 'Dans les colonnes, nous avons …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305CD40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, en sélectionnant l'icôn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai mis une condition ici pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et ceci est le formulaire que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En développant l'année, je peu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également l'option d'ajus…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme sur Excel, nous pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également refléter ces…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour celles-ci, je vais augmen…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Error] Attempt 1/10 failed for phrase: 'Et pour cela, je vais augmente…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305D2E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Error] Attempt 2/10 failed for phrase: 'Et pour cela, je vais augmente…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305E600> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.1s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305CA70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305FBF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 2/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305DEB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 5.0s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce un ajustement proportio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Disons donc pour le troisième …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, un utilisateur peut fai…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Lorsqu'un icône bleu est visib…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la langue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Error] Attempt 1/10 failed for phrase: 'la précision, les suppressions…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001A1B305DD00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_222557\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_222557\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_222557\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_222557\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent
import spacy


nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up



def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "  0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i  1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")





def generate_review_from_srt_grouped(
    source_srt, review_file_path,
    from_lang="en", to_lang="fr"
):
    import pysrt, re
    from deep_translator import GoogleTranslator
    import spacy

    subs = pysrt.open(source_srt, encoding='utf-8')
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    nlp = spacy.load("fr_core_news_sm")

    sentence_end = re.compile(r"[.!?]\s*$")

    buffer_text = []
    buffer_start = None
    buffer_end   = None
    segments = []

    for sub in subs:
        # init buffer start time
        if buffer_start is None:
            buffer_start = sub.start.ordinal / 1000
        # always extend buffer end time
        buffer_end = sub.end.ordinal / 1000
        buffer_text.append(sub.text.replace("\n", " ").strip())

        joined = " ".join(buffer_text)
        # si on termine sur un .,? ou !
        if sentence_end.search(joined):
            segments.append((buffer_start, buffer_end, joined))
            buffer_text = []
            buffer_start = None
            buffer_end   = None

    # s’il reste du texte sans ponctuation finale, on le traite aussi
    if buffer_text:
        joined = " ".join(buffer_text)
        segments.append((buffer_start, buffer_end, joined))

    # écriture du review-file
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File (groupé par phrases complètes)\n")
        f.write("Chaque segment s’arrête sur ., ? ou !\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, (start_s, end_s, original_en) in enumerate(segments, 1):
            try:
                auto_tr = translator.translate(text=original_en)
            except:
                auto_tr = "[ERREUR DE TRADUCTION]"

            doc = nlp(auto_tr)
            phrases = [sent.text.strip() for sent in doc.sents if sent.text.strip()]
            inter_ms = [0]*max(0, len(phrases)-1)
            budget   = int((end_s - start_s)*1000)

            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original (EN):** {original_en}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            # f.write("**Phrases (ne modifiez pas) :**\n")
            # for ph in phrases:
            #     f.write(f"- {ph}\n")
            f.write("**Pre-Silence:** 0\n")
            f.write("**Post-Silence:** 100\n")
            f.write(f"**Inter-Phrase-Silence:** {','.join(str(x) for x in inter_ms)}\n")
            f.write("**Start-Offset:** 0\n")
            f.write("**End-Offset:** 0\n")
            f.write(f"**Budget (ms):** {budget}\n")
            f.write("----------------------------------------------------------------\n\n")

    print(f"✅ Review file généré : {review_file_path} ({len(segments)} segments)")
    input("⚠️ Relisez et corrigez le fichier puis appuyez sur Entrée…")



def parse_review_file(review_file_path):
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        if blk.startswith("Translation Review File"): continue
        m = header.search(blk)
        if not m: continue
        start_s, end_s = float(m.group(1)), float(m.group(2))
        # defaults
        ft = vs = None
        pre = post = start_offset = end_offset = 0.0
        phrases = []
        silence_avant = []
        # 1) première passe : Original, Final, Phrases, Pre/Post, Offsets
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Phrases"):
                continue  # skip header
            elif line.startswith("- ") and not silence_avant:
                phrases.append(line[2:].strip())
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                start_offset = float(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = float(line.split("**End-Offset:**",1)[1])
        # init silence_avant à zéro pour chaque phrase
        silence_avant = [0.0] * len(phrases)
        # 2) lecture du bloc *après* avoir capturé les phrases
        state = None
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Silence-Avant:**"):
                state = "silence"
                continue
            if state == "silence" and line.startswith("- "):
                text_ph, ms = line[2:].rsplit(":",1)
                text_ph = text_ph.strip()
                ms      = float(ms.strip())
                if text_ph in phrases:
                    idx = phrases.index(text_ph)
                    silence_avant[idx] = ms
            if line == "":
                state = None

        segments.append({
            "start_s": start_s,
            "end_s":   end_s,
            "final_translation": ft,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "phrases":           phrases,
            "silence_avant_ms":  silence_avant
        })
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

async def async_generate_translated_audio_with_sync_using_review(
    subtitle_file_en,
    output_audio_path,
    debug_log_path,
    review_file_path
):
    # ─── 1) Génération / mise à jour du review-file à partir du .srt ───
    generate_review_from_srt_grouped(
        source_srt       = subtitle_file_en,
        review_file_path = review_file_path
    )

    # ─── 2) Lecture du review-file enrichi ───
    segments = parse_review_file(review_file_path)

    # ─── 2b) Injecter automatiquement les start_offset à partir du end_offset précédent ───
    for i in range(1, len(segments)):
        prev = segments[i-1]
        segments[i]['start_offset_ms'] = - prev.get('end_offset_ms', 0)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        # ─── 3) Récupérations de base ───
        start_s   = seg["start_s"]
        end_s     = seg["end_s"]
        total_ms  = int((end_s - start_s) * 1000)
        text      = seg["final_translation"]
        rate      = seg["voice_speed"]
        pre_ms    = seg["pre_silence"]
        post_ms   = seg["post_silence"]
        soff      = seg.get("start_offset_ms", 0)
        eoff      = seg.get("end_offset_ms",   0)

        # ─── 4) Découpage en phrases FR d’après le texte final ───
        phrases = split_french_phrases(text)
        weights = calculate_phrase_weights(text, phrases)
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40, max_chars=None)

        # ─── 5) Calcul du budget audio hors silences pré/post ───
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # ─── 6) Synthèse phrase par phrase ───
        phrase_audios = []
        for pi, ph in enumerate(phrases):
            dur_s  = (content_ms * weights[pi]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{pi}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, voice="fr-FR-DeniseNeural", rate=rate)

            aud = AudioSegment.from_mp3(tmp_mp3)
            try:
                os.remove(tmp_mp3)
            except PermissionError:
                pass  # Windows lock, on nettoiera plus tard
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # ─── 7) Anti-dépassement si TTS trop long ───
        sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)
        if sum_tts > content_ms and sum_tts > 0:
            factor = content_ms / sum_tts
            phrase_audios = [ change_playback_speed(a, factor) for a in phrase_audios ]
            sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)

        # ─── 8) Silences internes ───
        n_inter = max(0, len(phrases) - 1)
        manual_inters = seg.get("silences_internal", [])
        if manual_inters and len(manual_inters) == n_inter:
            inter_applied = manual_inters
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter

        # ─── 9) Assemblage du segment ───
        seq = []
        for i_aud, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i_aud < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i_aud]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq:
            seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        # ─── 10) Strip des silences initiaux indésirables ───
        nons = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS - 16)
        if nons:
            seg_audio = seg_audio[nons[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        # ─── 11) Ajuster à la durée totale_ms ───
        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # ─── 12) Debug timings ───
        nons2       = detect_nonsilent(seg_audio, min_silence_len=1, silence_thresh=seg_audio.dBFS - 16)
        start_a     = nons2[0][0] if nons2 else pre_ms
        end_a       = nons2[-1][1] if nons2 else (total_ms - post_ms)
        decal_start = int(start_s*1000 + start_a) - int(start_s*1000)
        decal_end   = int(start_s*1000 + end_a)   - int(end_s*1000)

        # ─── 13) Warp global si nécessaire ───
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s - start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s - start_s) / gen_dur)

        # ─── 14) Application des offsets puis mix sur timeline ───
        #  a) end-offset (allonger ou tronquer seg_audio)
        if eoff > 0:
            seg_audio = seg_audio + AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        #  b) calcul du point de collage
        start_ms = int(start_s * 1000) + soff
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms:
            combined = combined[:start_ms]

        combined += seg_audio

        # ─── 15) Log debug ───
        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"silences_internal={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        )

    # ─── 16) Export du debug et de l’onde ───
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path


# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file généré : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250502_104831\translation_review.txt (26 segments)
# ✅ Parsed 26 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir les configura…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité dans EPM comprendr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Error] Attempt 1/10 failed for phrase: 'À partir de la page d'accueil,…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Error] Attempt 1/10 failed for phrase: 'Maintenant, je vais sélectionn…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1010> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Error] Attempt 2/10 failed for phrase: 'Maintenant, je vais sélectionn…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D0DD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.7s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Error] Attempt 1/10 failed for phrase: 'Ici, le matériel OFS sera divi…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D12E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons enregistrer, réin…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1760> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour obtenir un rôle commercia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il ouvrira notre responsable d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir que l'applica…'
# [Error] Attempt 1/10 failed for phrase: 'Vous pouvez voir que l'applica…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1760> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Vous pouvez voir que l'applica…'
# [Error] Attempt 2/10 failed for phrase: 'Vous pouvez voir que l'applica…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1250> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.1s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Vous pouvez voir que l'applica…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Error] Attempt 1/10 failed for phrase: 'Dans cette démo, je vais créer…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai sélectionné la file…'
# [Error] Attempt 1/10 failed for phrase: 'Comme j'ai sélectionné la file…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1910> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comme j'ai sélectionné la file…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner le rouge …'
# [Error] Attempt 1/10 failed for phrase: 'Je vais sélectionner le rouge …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D3F50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais sélectionner le rouge …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il dira qu'il a créé, que nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais dire oui et une fois q…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il s'agit d'une règle commerci…'
# [Error] Attempt 1/10 failed for phrase: 'Il s'agit d'une règle commerci…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D2720> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Il s'agit d'une règle commerci…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Actuellement, je vais ouvrir u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je n'ai pas de données pour ce…'
# [Error] Attempt 1/10 failed for phrase: 'Je n'ai pas de données pour ce…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1BE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je n'ai pas de données pour ce…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Error] Attempt 1/10 failed for phrase: 'Vous voyez comment les données…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D15B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'exécuter à partir du gestion…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également planifi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Error] Attempt 1/10 failed for phrase: 'La sécurité peut être appliqué…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D3F50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur le formula…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais cliquer sur le formula…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1910> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais cliquer sur le formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais déplacer des détails s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité attribue la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant examine…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections de valeur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons simplement définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer une nouvell…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment créer et configurer un…'
# [Error] Attempt 1/10 failed for phrase: 'Comment créer et configurer un…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D0EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comment créer et configurer un…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous des actions, nous pouvons…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner la f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons faire glisser et d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Error] Attempt 1/10 failed for phrase: 'Cliquer sur l'icône me donnera…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D10A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Error] Attempt 2/10 failed for phrase: 'Cliquer sur l'icône me donnera…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D15B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.1s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le sens nous aide à passer d'u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également différent…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ont également des règles pour …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé le formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, en sélectionnant l'icôn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai réglé une condition ici p…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai réglé une condition ici p…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1A30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai réglé une condition ici p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la forme que nous avo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux voir que lorsque j'en …'
# [Error] Attempt 1/10 failed for phrase: 'Je peux voir que lorsque j'en …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1490> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux voir que lorsque j'en …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également les options pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Error] Attempt 1/10 failed for phrase: 'Chaque fois que la cellule est…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1AC0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Error] Attempt 2/10 failed for phrase: 'Chaque fois que la cellule est…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D2720> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme Excel, nous pouvons…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également faire réfléc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D19A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce proportionnel ou est-il…'
# [Error] Attempt 1/10 failed for phrase: 'Est-ce proportionnel ou est-il…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1490> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Est-ce proportionnel ou est-il…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Disons donc pour le trimestre …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, quand un utilisateur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il est en bleu, ce qui signifi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également définir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D0F80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la langue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir la façon …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1B50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons définir la façon …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000223587D1D90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.7s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous définirons les variables …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_3.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250502_104831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250502_104831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250502_104831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250502_104831\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %% [markdown]
# 424 - 07MAY - LAST VERSION

# %%
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais jeter un œil aux confi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour obtenir un rôle commercia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Actuellement, je vais ouvrir u…'
# [Error] Attempt 1/10 failed for phrase: 'Actuellement, je vais ouvrir u…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A4508200> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Actuellement, je vais ouvrir u…'
# [Error] Attempt 2/10 failed for phrase: 'Actuellement, je vais ouvrir u…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450B2F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.9s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Actuellement, je vais ouvrir u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur le formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais déplacer des détails s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant examine…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le sens nous aide à passer d'u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_16.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également faire réfléc…'
# [Error] Attempt 1/10 failed for phrase: 'Je veux également faire réfléc…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450B410> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je veux également faire réfléc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_17.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Error] Attempt 1/10 failed for phrase: 'Et pour cela, je vais augmente…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450BE30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_18.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_19.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_20.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce proportionnel ou est-il…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_21.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_22.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_23.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Error] Attempt 1/10 failed for phrase: 'L'utilisateur sera en mesure d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450A210> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_24.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, quand un utilisateur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_25.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_26.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tts_segment_27.mp3
# ✅ Review file créé : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_131959\translation_review.txt (27 segments)
# ✅ Review file régénéré, pensez à y reporter vos offsets personnalisés si besoin.
# ✅ Parsed 27 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir les configura…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Error] Attempt 1/10 failed for phrase: 'Nous verrons comment créer une…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CC104D40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité au niveau de EPM c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Error] Attempt 1/10 failed for phrase: 'La formule des membres est uti…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CC104D40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons enregistrer, réin…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CC1040E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Error] Attempt 1/10 failed for phrase: 'Pour voir une règle métier, cl…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CBFDBC80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir l'application…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'expansion nous montrera EPBC…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux importer et je peux vo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai sélectionné le cube…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner Règles co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le système indiquera que la rè…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les administrateurs utilisent …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La règle va copier les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais donc le valider et l'e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais ouvrir un …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai déjà un formulaire ici et…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450BE30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour FY23, je n'ai pas de donn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Error] Attempt 1/10 failed for phrase: 'Vous voyez comment les données…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450ACC0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Error] Attempt 1/10 failed for phrase: 'Je peux l'exécuter à partir du…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450B2F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Error] Attempt 1/10 failed for phrase: 'La sécurité peut être appliqué…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450ADE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Error] Attempt 1/10 failed for phrase: 'Pour en savoir plus sur la séc…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A4509D90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Error] Attempt 2/10 failed for phrase: 'Pour en savoir plus sur la séc…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CC104680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a aussi des groupes défin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons attribuer différe…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450B2F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité attribue la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si j'ajoute le groupe Account …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant examine…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections de valeur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons simplement définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons aussi une sécurité …'
# [Error] Attempt 1/10 failed for phrase: 'Nous avons aussi une sécurité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A4509E20> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous avons aussi une sécurité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer une nouvell…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour créer et configurer un fo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous Actions, sélectionnez Cré…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur Créer un f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il faut entrer un nom, sélecti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'On peut aussi placer des dimen…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur l’icône, j’ouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J’ai enfin la possibilité de p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Error] Attempt 1/10 failed for phrase: 'Dans la disposition, nous pouv…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CC104680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également différent…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a également des règles po…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé le formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, en sélectionnant l'icôn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir les varia…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4CC1044D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai mis une condition ici pou…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai mis une condition ici pou…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450BF50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai mis une condition ici pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et ceci est le formulaire que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En développant l'année, je peu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également l'option d'ajus…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme sur Excel, nous pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également refléter ces…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour celles-ci, je vais augmen…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce un ajustement proportio…'
# [Error] Attempt 1/10 failed for phrase: 'Est-ce un ajustement proportio…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000002A4A450B140> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Est-ce un ajustement proportio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Disons donc pour le troisième …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, un utilisateur peut fai…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Lorsqu'un icône bleu est visib…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la langue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_131959\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_131959\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_131959\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250512_131959\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %% [markdown]
# 423 - 07may2025 -LAST VERSION

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.3_La création de rapports.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up


def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")


def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) On regroupe et on split/merge les sous-titres exactement
       comme le fera l'audio.
    2) On écrit un review file où l'on affiche :
       - phrase par phrase (la liste exacte via "- ")
       - pre / post silence
       - voice speed
       - start/end offset
       - inter-phrase silences (N–1 valeurs pour N phrases)
    L'utilisateur peut ensuite :
      * ajuster Final Translation, Voice Speed, Pre/Post-Silence,
        Start-Offset, End-Offset
      * modifier le nombre de phrases (le parser adaptera N–1 silences).
    """

    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regrouper par phrase (détection ponctuation en fin de sous-titre)
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text):
            groups.append(cur); cur = []
    if cur:
        groups.append(cur)

    # 2) Éclatement des groupes trop longs
    def split_long(gs, max_s):
        out = []
        for g in gs:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end - start <= max_s:
                out.append(g)
            else:
                mid = len(g)//2
                out.extend([g[:mid], g[mid:]])
        return out
    groups = split_long(groups, max_group_duration_secs)

    # 3) Forcer ponctuation de fin de groupe
    i = 0
    safe_punct = re.compile(r"[.!?,;:]$")
    while i < len(groups):
        if not safe_punct.search(groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4) Écriture du fichier de review
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, "
                "**Start-Offset:**, **End-Offset:**, **Inter-Phrase-Silence:**\n")
        f.write("mais **ne touchez pas** la liste des phrases (lignes qui commencent par '- ').\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            # Calcul des temps
            start_s = group[0].start.ordinal / 1000
            end_s   = group[-1].end.ordinal   / 1000

            # Texte original + auto-traduit
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # Découpage initial en phrases (on ne réécrit pas ces lignes, mais on calcule N)
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]

            # Préparer la liste par défaut des silences internes = N–1 × 0 ms
            n = len(phrases)
            inter_silences = ",".join("0" for _ in range(max(0, n-1)))

            # Valeurs par défaut
            pre_ms, post_ms = 0, 0
            start_offset, end_offset = 0, 0
            voice_speed = "+0%"

            # Écriture du segment
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** {voice_speed}\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Start-Offset:** {start_offset}\n")
            f.write(f"**End-Offset:** {end_offset}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_silences}\n")

            # Liste des phrases pour que l'utilisateur puisse la modifier
            for ph in phrases:
                f.write(f"- {ph}\n")

            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Review file créé : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")



def parse_review_fileOLDA(review_file_path):
    """
    Lit le review file écrit ci-dessus et
    renvoie une liste de dicts avec :
      - start_s, end_s, final_translation, voice_speed
      - pre_silence, post_silence, phrases (list)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        ft, vs, pre, post = None, "+0%", 0.0, 0.0
        orig = None
        start_offset = 0 
        phrases = []
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                 # offset en millisecondes à ajouter au start
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])                
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
            elif line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()

        segments.append({
            "start_s":           start_s,
            "end_s":             end_s,
            "original":          orig,
            "final_translation": ft or orig,
            "voice_speed":       vs,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "phrases":           phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

def parse_review_file(review_file_path):
    """
    Lit le review file et renvoie une liste de dicts avec :
      - start_s, end_s, original, final_translation, voice_speed
      - pre_silence, post_silence, start_offset_ms, end_offset_ms
      - phrases (list de phrases) et inter_phrase_silences (liste de silences internes)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): 
            continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft, vs = None, "+0%"
        pre, post = 0.0, 0.0
        soffs, eoffs = 0, 0
        phrases = []
        inter = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if parts:
                    inter = [max(0, int(x)) for x in parts.split(",")]
            elif line.startswith("- "):
                phrases.append(line[2:].strip())

        segments.append({
            "start_s": start_s,
            "end_s": end_s,
            "final_translation": ft or "",
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # 1) Création du review file uniquement s'il n'existe pas encore
    if not os.path.exists(review_file_path):
        generate_translation_review_file(
            subtitle_source_path,
            review_file_path,
            max_group_duration_secs=25.0
        )
    else:
        print("✅ Review file déjà présent, on conserve vos offsets personnalisés.")


    # 2) Lecture du review file enrichi
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        # Récupération des settings
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soff    = seg.get("start_offset_ms", 0)
        eoff    = seg.get("end_offset_ms",   0)

        # Phrase splitting & TTS
        phrases = split_french_phrases(text)
        weights = calculate_phrase_weights(text, phrases)
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)

        # Budget pour TTS seule
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # Synthèse phrase par phrase
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s  = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, rate=rate)
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # Ajustement interne par override ou répartition égale
        n_inter = max(0, len(phrases) - 1)
        if seg.get("inter_phrase_silences"):
            inter_applied = seg["inter_phrase_silences"]
            # adapter la longueur
            if len(inter_applied) < n_inter:
                inter_applied += [0] * (n_inter - len(inter_applied))
            elif len(inter_applied) > n_inter:
                inter_applied = inter_applied[:n_inter]
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter

        # Reconstruction du segment audio
        seg_audio = AudioSegment.silent(duration=pre_ms)
        for i, aud in enumerate(phrase_audios):
            seg_audio += aud
            if i < len(inter_applied):
                seg_audio += AudioSegment.silent(duration=inter_applied[i])
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Application offset de fin
        if eoff > 0:
            seg_audio += AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        # Debug timing (prise en compte de soff)
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000) + soff
        #abs_e_v = int(end_s   * 1000)
        abs_e_v = int(end_s   * 1000) + eoff
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # Mise sur timeline avec offset de start
        start_ms = int(start_s * 1000) + soff
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms and soff < 0:
            combined = combined[:start_ms]
        combined += seg_audio

        # Enregistrement debug
        # debug.append(
        #     f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): pre={pre_ms}ms, post={post_ms}ms, "
        #     f"speed={rate}, inter={inter_applied}, "
        #     f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        # )

        debug.append(
                   f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
                   f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
                   f"inter={inter_applied}, "
                   f"phrases={phrases}, "
                   f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
                )



    # Export debug & wav
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path


# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file créé : 4.2.3_La création de rapports_run_20250508_115717\translation_review.txt (27 segments)
# ✅ Parsed 55 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, nous explorer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment créer un résumé des dé…'
# [Error] Attempt 1/10 failed for phrase: 'Comment créer un résumé des dé…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71C70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comment créer un résumé des dé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment créer un rapport avec …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment modifier un rapport et…'
# [Error] Attempt 1/10 failed for phrase: 'Comment modifier un rapport et…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71C70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comment modifier un rapport et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'De plus, nous explorerons les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Error] Attempt 1/10 failed for phrase: 'À partir de la page d'accueil,…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A70EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur le rapport, un…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur l'icône du cra…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et c'est la sélection de grill…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'De plus, nous pouvons aligner …'
# [Error] Attempt 1/10 failed for phrase: 'De plus, nous pouvons aligner …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A70D40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'De plus, nous pouvons aligner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur ceci nous permettr…'
# [Error] Attempt 1/10 failed for phrase: 'Cliquez sur ceci nous permettr…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71EB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cliquez sur ceci nous permettr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé plusieurs colonnes d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux voir différentes optio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir ces valeurs q…'
# [Error] Attempt 1/10 failed for phrase: 'Vous pouvez voir ces valeurs q…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A716D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Vous pouvez voir ces valeurs q…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Celui-ci est pour les colonnes…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si je sélectionne une cellule,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci sert à trier et je peux d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux ajouter des suppressio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également la possib…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Afin de créer un rapport résum…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur l'icône Créer …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ajouter une zone de texte vous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des pieds d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons des fonctions sur c…'
# [Error] Attempt 1/10 failed for phrase: 'Nous avons des fonctions sur c…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A72E70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous avons des fonctions sur c…'
# [Error] Attempt 2/10 failed for phrase: 'Nous avons des fonctions sur c…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71250> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.9s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous avons des fonctions sur c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous sélectionner description …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Actuellement, nous avons des d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Lorsque nous exécutons, nous o…'
# [Error] Attempt 1/10 failed for phrase: 'Lorsque nous exécutons, nous o…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A70EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Lorsque nous exécutons, nous o…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Toutes les récapitulations des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, nous explorerons u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller au formatage con…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, le format 1 , si la vale…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'De même, si la valeur est infé…'
# [Error] Attempt 1/10 failed for phrase: 'De même, si la valeur est infé…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A728D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'De même, si la valeur est infé…'
# [Error] Attempt 2/10 failed for phrase: 'De même, si la valeur est infé…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71EB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.9s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'De même, si la valeur est infé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_27_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrions être en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_28_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons une fonctionnalité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_29_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai réglé un formatage condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_30_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Mettez à jour cette condition …'
# [Error] Attempt 1/10 failed for phrase: 'Mettez à jour cette condition …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A70C20> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Mettez à jour cette condition …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_31_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, vous pouvez voir que de…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_32_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment créer un rapport avec …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_33_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Alors maintenant, au lieu de c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_34_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais créer une ligne de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_35_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai mes détails de revenus so…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_36_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux voir différentes fonct…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_37_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et si je clique sur l'exécutio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_38_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai ajouté une colonne supplé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_39_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela me montre le détail sur l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_40_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous verrez comment modifier u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_41_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner ce rappor…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais sélectionner ce rappor…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A72060> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais sélectionner ce rappor…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_42_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'quand je clique sur Graphic, c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_43_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner une grill…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais sélectionner une grill…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71010> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais sélectionner une grill…'
# [Error] Attempt 2/10 failed for phrase: 'Je vais sélectionner une grill…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A72180> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 5.0s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Je vais sélectionner une grill…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_44_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois le rapport est chargé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_45_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si on passe la souris sur la g…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_45_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Explorons les rapports narrati…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_46_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé cette carte en ajout…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai créé cette carte en ajout…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71E20> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai créé cette carte en ajout…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_47_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquez sur ceci ouvrira l'ins…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_47_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais ouvrir le rapport de l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_47_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous ouvrons le r…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_48_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons ajouter des auteu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_48_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois qu'ils les auront ajo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_48_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que ces derniers l'on…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_48_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons différentes section…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur l'aperçu e…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais cliquer sur l'aperçu e…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A728D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais cliquer sur l'aperçu e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir les rapports…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également voir l'…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'On peut voir les rapports de d…'
# [Error] Attempt 1/10 failed for phrase: 'On peut voir les rapports de d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A72D50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'On peut voir les rapports de d…'
# [Error] Attempt 2/10 failed for phrase: 'On peut voir les rapports de d…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A70CB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.1s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'On peut voir les rapports de d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'On peut y ajouter des explicat…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceux la ont été ajoutés par le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir plusieurs r…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux y voir exactement les …'
# [Error] Attempt 1/10 failed for phrase: 'Je peux y voir exactement les …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux y voir exactement les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En revenant sur la page d'ense…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ces rapports peuvent être util…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais maintenant ouvrir un r…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si nous voulons envoyer ce rap…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur Exécuter, un c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai reçu les courriels et j'a…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai reçu les courriels et j'a…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A70CB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai reçu les courriels et j'a…'
# [Error] Attempt 2/10 failed for phrase: 'J'ai reçu les courriels et j'a…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71E20> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'J'ai reçu les courriels et j'a…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'A chaque fois qu'un auteur est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ils peuvent également voir ces…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ils peuvent cliquer sur les me…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également voir la…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur la tâche me montre…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Alors en ouvrant ce rapport du…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également les optio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux voir les données de dé…'
# [Error] Attempt 1/10 failed for phrase: 'Je veux voir les données de dé…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A715B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je veux voir les données de dé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme vous pouvez voir il indi…'
# [Error] Attempt 1/10 failed for phrase: 'Comme vous pouvez voir il indi…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A71250> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comme vous pouvez voir il indi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si je clique sur rafraîchir, j…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois la phase de l'auteur …'
# [Error] Attempt 1/10 failed for phrase: 'Une fois la phase de l'auteur …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x000001D603A717F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Une fois la phase de l'auteur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une icône de revue est activée…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'On peut voir l'historique des …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'On peut aussi ajouter des fich…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que la phase du signa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ils peuvent approuver et cliqu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_53_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également voir le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_54_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.3_La création de rapports_run_20250508_115717\4.2.3_La création de rapports-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.3_La création de rapports_run_20250508_115717\4.2.3_La création de rapports-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.3_La création de rapports_run_20250508_115717\4.2.3_La création de rapports-french.mp4
# Process completed! Output video: 4.2.3_La création de rapports_run_20250508_115717\4.2.3_La création de rapports-french.mp4

# %% [markdown]
# 4214 - 05may2025 - LAST VERSION

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.1.4_Réalisation des suivis financiers.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up


def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")


def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) On regroupe et on split/merge les sous-titres exactement
       comme le fera l'audio.
    2) On écrit un review file où l'on affiche :
       - phrase par phrase (la liste exacte via "- ")
       - pre / post silence
       - voice speed
       - start/end offset
       - inter-phrase silences (N–1 valeurs pour N phrases)
    L'utilisateur peut ensuite :
      * ajuster Final Translation, Voice Speed, Pre/Post-Silence,
        Start-Offset, End-Offset
      * modifier le nombre de phrases (le parser adaptera N–1 silences).
    """

    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regrouper par phrase (détection ponctuation en fin de sous-titre)
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text):
            groups.append(cur); cur = []
    if cur:
        groups.append(cur)

    # 2) Éclatement des groupes trop longs
    def split_long(gs, max_s):
        out = []
        for g in gs:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end - start <= max_s:
                out.append(g)
            else:
                mid = len(g)//2
                out.extend([g[:mid], g[mid:]])
        return out
    groups = split_long(groups, max_group_duration_secs)

    # 3) Forcer ponctuation de fin de groupe
    i = 0
    safe_punct = re.compile(r"[.!?,;:]$")
    while i < len(groups):
        if not safe_punct.search(groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4) Écriture du fichier de review
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, "
                "**Start-Offset:**, **End-Offset:**, **Inter-Phrase-Silence:**\n")
        f.write("mais **ne touchez pas** la liste des phrases (lignes qui commencent par '- ').\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            # Calcul des temps
            start_s = group[0].start.ordinal / 1000
            end_s   = group[-1].end.ordinal   / 1000

            # Texte original + auto-traduit
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # Découpage initial en phrases (on ne réécrit pas ces lignes, mais on calcule N)
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]

            # Préparer la liste par défaut des silences internes = N–1 × 0 ms
            n = len(phrases)
            inter_silences = ",".join("0" for _ in range(max(0, n-1)))

            # Valeurs par défaut
            pre_ms, post_ms = 0, 0
            start_offset, end_offset = 0, 0
            voice_speed = "+0%"

            # Écriture du segment
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** {voice_speed}\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Start-Offset:** {start_offset}\n")
            f.write(f"**End-Offset:** {end_offset}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_silences}\n")

            # Liste des phrases pour que l'utilisateur puisse la modifier
            for ph in phrases:
                f.write(f"- {ph}\n")

            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Review file créé : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")



def parse_review_fileOLDA(review_file_path):
    """
    Lit le review file écrit ci-dessus et
    renvoie une liste de dicts avec :
      - start_s, end_s, final_translation, voice_speed
      - pre_silence, post_silence, phrases (list)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        ft, vs, pre, post = None, "+0%", 0.0, 0.0
        orig = None
        start_offset = 0 
        phrases = []
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                 # offset en millisecondes à ajouter au start
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])                
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
            elif line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()

        segments.append({
            "start_s":           start_s,
            "end_s":             end_s,
            "original":          orig,
            "final_translation": ft or orig,
            "voice_speed":       vs,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "phrases":           phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

def parse_review_file(review_file_path):
    """
    Lit le review file et renvoie une liste de dicts avec :
      - start_s, end_s, original, final_translation, voice_speed
      - pre_silence, post_silence, start_offset_ms, end_offset_ms
      - phrases (list de phrases) et inter_phrase_silences (liste de silences internes)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): 
            continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft, vs = None, "+0%"
        pre, post = 0.0, 0.0
        soffs, eoffs = 0, 0
        phrases = []
        inter = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if parts:
                    inter = [max(0, int(x)) for x in parts.split(",")]
            elif line.startswith("- "):
                phrases.append(line[2:].strip())

        segments.append({
            "start_s": start_s,
            "end_s": end_s,
            "final_translation": ft or "",
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # 1) Création du review file uniquement s'il n'existe pas encore
    if not os.path.exists(review_file_path):
        generate_translation_review_file(
            subtitle_source_path,
            review_file_path,
            max_group_duration_secs=25.0
        )
    else:
        print("✅ Review file déjà présent, on conserve vos offsets personnalisés.")


    # 2) Lecture du review file enrichi
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        # Récupération des settings
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soff    = seg.get("start_offset_ms", 0)
        eoff    = seg.get("end_offset_ms",   0)

        # Phrase splitting & TTS
        phrases = split_french_phrases(text)
        weights = calculate_phrase_weights(text, phrases)
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)

        # Budget pour TTS seule
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # Synthèse phrase par phrase
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s  = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, rate=rate)
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # Ajustement interne par override ou répartition égale
        n_inter = max(0, len(phrases) - 1)
        if seg.get("inter_phrase_silences"):
            inter_applied = seg["inter_phrase_silences"]
            # adapter la longueur
            if len(inter_applied) < n_inter:
                inter_applied += [0] * (n_inter - len(inter_applied))
            elif len(inter_applied) > n_inter:
                inter_applied = inter_applied[:n_inter]
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter

        # Reconstruction du segment audio
        seg_audio = AudioSegment.silent(duration=pre_ms)
        for i, aud in enumerate(phrase_audios):
            seg_audio += aud
            if i < len(inter_applied):
                seg_audio += AudioSegment.silent(duration=inter_applied[i])
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Application offset de fin
        if eoff > 0:
            seg_audio += AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        # Debug timing (prise en compte de soff)
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000) + soff
        #abs_e_v = int(end_s   * 1000)
        abs_e_v = int(end_s   * 1000) + eoff
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # Mise sur timeline avec offset de start
        start_ms = int(start_s * 1000) + soff
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms and soff < 0:
            combined = combined[:start_ms]
        combined += seg_audio

        # Enregistrement debug
        # debug.append(
        #     f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): pre={pre_ms}ms, post={post_ms}ms, "
        #     f"speed={rate}, inter={inter_applied}, "
        #     f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        # )

        debug.append(
                   f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
                   f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
                   f"inter={inter_applied}, "
                   f"phrases={phrases}, "
                   f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
                )



    # Export debug & wav
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path


# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file créé : 4.2.1.4_Réalisation des suivis financiers_run_20250507_102204\translation_review.txt (27 segments)
# ✅ Parsed 26 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, nous allons s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous expliquerons les écarts e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous consoliderons les prévisi…'
# [Error] Attempt 1/10 failed for phrase: 'Nous consoliderons les prévisi…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000027F8D885130> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous consoliderons les prévisi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous expliquerons les écarts e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous consoliderons les explica…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est un fichier de données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, nous allons ajuster les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous développons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais ajuster les données de…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ensuite, je vais comparer le b…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir que le budget…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, nous allons enregi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons créé un rapport pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir que les prév…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, nous avons aussi l'écart …'
# [Error] Attempt 1/10 failed for phrase: 'Ici, nous avons aussi l'écart …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000027F8D885400> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ici, nous avons aussi l'écart …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans le même fichier de dépens…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir comment ajust…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais développer les onglets…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, nous pouvons voir …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais mettre le montant réel…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois le commentaire ajouté…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai ouvert le rapport sur les…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai ouvert le rapport sur les…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000027F8D885640> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai ouvert le rapport sur les…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si j'ouvre les onglets pour l'…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé un ensemble de rappo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais prévisualiser l'ensemb…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons donc les données EF…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'aimerais surligner que tous …'
# [Error] Attempt 1/10 failed for phrase: 'J'aimerais surligner que tous …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000027F8D885B50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'aimerais surligner que tous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons ajouter des expli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.1.4_Réalisation des suivis financiers_run_20250507_102204\4.2.1.4_Réalisation des suivis financiers-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.1.4_Réalisation des suivis financiers_run_20250507_102204\4.2.1.4_Réalisation des suivis financiers-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.1.4_Réalisation des suivis financiers_run_20250507_102204\4.2.1.4_Réalisation des suivis financiers-french.mp4
# Process completed! Output video: 4.2.1.4_Réalisation des suivis financiers_run_20250507_102204\4.2.1.4_Réalisation des suivis financiers-french.mp4

# %% [markdown]
# 425 - 07may2025 - LAST VERSION

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.5_Intégration des données source.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up


def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")


def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) On regroupe et on split/merge les sous-titres exactement
       comme le fera l'audio.
    2) On écrit un review file où l'on affiche :
       - phrase par phrase (la liste exacte via "- ")
       - pre / post silence
       - voice speed
       - start/end offset
       - inter-phrase silences (N–1 valeurs pour N phrases)
    L'utilisateur peut ensuite :
      * ajuster Final Translation, Voice Speed, Pre/Post-Silence,
        Start-Offset, End-Offset
      * modifier le nombre de phrases (le parser adaptera N–1 silences).
    """

    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regrouper par phrase (détection ponctuation en fin de sous-titre)
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text):
            groups.append(cur); cur = []
    if cur:
        groups.append(cur)

    # 2) Éclatement des groupes trop longs
    def split_long(gs, max_s):
        out = []
        for g in gs:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end - start <= max_s:
                out.append(g)
            else:
                mid = len(g)//2
                out.extend([g[:mid], g[mid:]])
        return out
    groups = split_long(groups, max_group_duration_secs)

    # 3) Forcer ponctuation de fin de groupe
    i = 0
    safe_punct = re.compile(r"[.!?,;:]$")
    while i < len(groups):
        if not safe_punct.search(groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4) Écriture du fichier de review
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, "
                "**Start-Offset:**, **End-Offset:**, **Inter-Phrase-Silence:**\n")
        f.write("mais **ne touchez pas** la liste des phrases (lignes qui commencent par '- ').\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            # Calcul des temps
            start_s = group[0].start.ordinal / 1000
            end_s   = group[-1].end.ordinal   / 1000

            # Texte original + auto-traduit
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # Découpage initial en phrases (on ne réécrit pas ces lignes, mais on calcule N)
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]

            # Préparer la liste par défaut des silences internes = N–1 × 0 ms
            n = len(phrases)
            inter_silences = ",".join("0" for _ in range(max(0, n-1)))

            # Valeurs par défaut
            pre_ms, post_ms = 0, 100
            start_offset, end_offset = 0, 0
            voice_speed = "+0%"

            # Écriture du segment
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** {voice_speed}\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Start-Offset:** {start_offset}\n")
            f.write(f"**End-Offset:** {end_offset}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_silences}\n")

            # Liste des phrases pour que l'utilisateur puisse la modifier
            for ph in phrases:
                f.write(f"- {ph}\n")

            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Review file créé : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")



def parse_review_fileOLDA(review_file_path):
    """
    Lit le review file écrit ci-dessus et
    renvoie une liste de dicts avec :
      - start_s, end_s, final_translation, voice_speed
      - pre_silence, post_silence, phrases (list)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        ft, vs, pre, post = None, "+0%", 0.0, 0.0
        orig = None
        start_offset = 0 
        phrases = []
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                 # offset en millisecondes à ajouter au start
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])                
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
            elif line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()

        segments.append({
            "start_s":           start_s,
            "end_s":             end_s,
            "original":          orig,
            "final_translation": ft or orig,
            "voice_speed":       vs,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "phrases":           phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

def parse_review_file(review_file_path):
    """
    Lit le review file et renvoie une liste de dicts avec :
      - start_s, end_s, original, final_translation, voice_speed
      - pre_silence, post_silence, start_offset_ms, end_offset_ms
      - phrases (list de phrases) et inter_phrase_silences (liste de silences internes)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): 
            continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft, vs = None, "+0%"
        pre, post = 0.0, 0.0
        soffs, eoffs = 0, 0
        phrases = []
        inter = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if parts:
                    inter = [max(0, int(x)) for x in parts.split(",")]
            elif line.startswith("- "):
                phrases.append(line[2:].strip())

        segments.append({
            "start_s": start_s,
            "end_s": end_s,
            "final_translation": ft or "",
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # 1) Génération / mise à jour du review file
    generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )

    # 2) Lecture du review file enrichi
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        # Récupération des settings
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soff    = seg.get("start_offset_ms", 0)
        eoff    = seg.get("end_offset_ms",   0)

        # Phrase splitting & TTS
        phrases = split_french_phrases(text)
        weights = calculate_phrase_weights(text, phrases)
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)

        # Budget pour TTS seule
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # Synthèse phrase par phrase
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s  = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, rate=rate)
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # Ajustement interne par override ou répartition égale
        n_inter = max(0, len(phrases) - 1)
        if seg.get("inter_phrase_silences"):
            inter_applied = seg["inter_phrase_silences"]
            # adapter la longueur
            if len(inter_applied) < n_inter:
                inter_applied += [0] * (n_inter - len(inter_applied))
            elif len(inter_applied) > n_inter:
                inter_applied = inter_applied[:n_inter]
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter

        # Reconstruction du segment audio
        seg_audio = AudioSegment.silent(duration=pre_ms)
        for i, aud in enumerate(phrase_audios):
            seg_audio += aud
            if i < len(inter_applied):
                seg_audio += AudioSegment.silent(duration=inter_applied[i])
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Application offset de fin
        if eoff > 0:
            seg_audio += AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        # Debug timing (prise en compte de soff)
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000) + soff
        abs_e_v = int(end_s   * 1000)
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # Mise sur timeline avec offset de start
        start_ms = int(start_s * 1000) + soff
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms and soff < 0:
            combined = combined[:start_ms]
        combined += seg_audio

        # Enregistrement debug
        # debug.append(
        #     f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): pre={pre_ms}ms, post={post_ms}ms, "
        #     f"speed={rate}, inter={inter_applied}, "
        #     f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        # )

        debug.append(
                   f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
                   f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
                   f"inter={inter_applied}, "
                   f"phrases={phrases}, "
                   f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
                )



    # Export debug & wav
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path


# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    # on ferme le clip audio pour libérer le fichier avant la suppression
    temp_file = "temp-audio.m4a"
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile=temp_file,
        remove_temp=True,
        threads=4
    )
    audio.close()
    video.close()
    # …et on le supprime nous-mêmes une fois les fichiers fermés
    try:
        os.remove(temp_file)
    except OSError as e:
        print(f"Error deleting temporary file {temp_file}: {e}")
        
# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file créé : 4.2.5_Intégration des données source_run_20250508_122756\translation_review.txt (12 segments)
# ✅ Parsed 12 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Intégration des données source…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment configurer les mappage…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment configurer les validat…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et comment intégrer les donnée…'
# [Error] Attempt 1/10 failed for phrase: 'Et comment intégrer les donnée…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED45F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Et comment intégrer les donnée…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Oracle Enterprise Data Managem…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En alignant et en validant les…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il permet aux utilisateurs pro…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'image montre les données de …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les données ou les métadonnées…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les quatre piliers de l'EDMCS …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Requêtes. Des transactions de …'
# [Error] Attempt 1/10 failed for phrase: 'Requêtes. Des transactions de …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED43B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Requêtes. Des transactions de …'
# [Error] Attempt 2/10 failed for phrase: 'Requêtes. Des transactions de …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED5D00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.8s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Requêtes. Des transactions de …'
# [Error] Attempt 3/10 failed for phrase: 'Requêtes. Des transactions de …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED48C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.9s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'Requêtes. Des transactions de …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une connexion définie dans EDM…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La structure de base de l'EDMC…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'enregistrement des applicati…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il permet de réaliser des inté…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il peut y avoir une connexion …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans l'EDMCS, l'importation da…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ces données peuvent ensuite êt…'
# [Error] Attempt 1/10 failed for phrase: 'Ces données peuvent ensuite êt…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED4D40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ces données peuvent ensuite êt…'
# [Error] Attempt 2/10 failed for phrase: 'Ces données peuvent ensuite êt…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED49E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.7s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Ces données peuvent ensuite êt…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Après l'enregistrement d'une a…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous sélectionnerons enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En cliquant sur cette option, …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ce processus peut être automat…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il va récupérer le fichier à p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Après avoir importé le fichier…'
# [Error] Attempt 1/10 failed for phrase: 'Après avoir importé le fichier…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED44D0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Après avoir importé le fichier…'
# [Error] Attempt 2/10 failed for phrase: 'Après avoir importé le fichier…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED4EF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.6s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Après avoir importé le fichier…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous irons à l'icône de vue, s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, nous apporterons toutes l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons ajouter des enfan…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous attribuerons un nom pour …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La demande passera ensuite par…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois le processus d'approb…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour pousser les mises à jour …'
# [Error] Attempt 1/10 failed for phrase: 'Pour pousser les mises à jour …'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour pousser les mises à jour …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour ce faire, naviguer vers l…'
# [Error] Attempt 1/10 failed for phrase: 'Pour ce faire, naviguer vers l…'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Pour ce faire, naviguer vers l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons l'assistant d'exp…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Notez que s'il y a des abonnem…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant voir le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La Gestion centralisée des don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les avantages pour le client s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour les adaptateurs d'applica…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les avantages pour le client s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En ce qui concerne la gouverna…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les avantages pour les clients…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les éléments clés de la visual…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les avantages pour le client c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour les points de vue multipl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les avantages pour le client s…'
# [Error] Attempt 1/10 failed for phrase: 'Les avantages pour le client s…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000015BDFED4710> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Les avantages pour le client s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Enfin, pour la gestion des ver…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les avantages pour le client s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.5_Intégration des données source_run_20250508_122756\4.2.5_Intégration des données source-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.5_Intégration des données source_run_20250508_122756\4.2.5_Intégration des données source-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.5_Intégration des données source_run_20250508_122756\4.2.5_Intégration des données source-french.mp4
# Error deleting temporary file temp-audio.m4a: [WinError 2] Le fichier spécifié est introuvable: 'temp-audio.m4a'
# Process completed! Output video: 4.2.5_Intégration des données source_run_20250508_122756\4.2.5_Intégration des données source-french.mp4

# %% [markdown]
# VERSION 04MAY : DEBUG 2 FOIS LANCÉ

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent

nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up


def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides





def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")

import re

def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si déc​al_start > 0 → on ajoute d_start à Pre-Silence
      - Si déc​al_start < 0 → on ajoute d_start (négatif) à Start-Offset
      - Si déc​al_end   > 0 → on ajoute d_end   à Post-Silence
      - Si déc​al_end   < 0 → on écrit End-Offset = d_end (pour tronquer l'excès)
    On réécrit ensuite le review_file en préservant tout le reste.
    """

    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment\s+(\d+).*décal_start=(-?\d+)ms,\s*décal_end=(-?\d+)ms")
    with open(debug_log_path, encoding="utf-8") as df:
        for line in df:
            m = pattern.search(line)
            if m:
                idx   = int(m.group(1))
                d_start = int(m.group(2))
                d_end   = int(m.group(3))
                decalages[idx] = (d_start, d_end)

    # 2) Lit le review file existant
    text   = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)
    out    = []

    # 3) Pour chaque bloc non-titre, on ajuste silences et offsets
    seg_header = re.compile(r"Segment\s+(\d+)\s+\(start:")
    for blk in blocks:
        # Ne touche pas au header global
        if blk.strip().startswith("Translation Review File"):
            out.append(blk)
            continue

        m_hdr = seg_header.search(blk)
        if not m_hdr:
            out.append(blk)
            continue

        idx = int(m_hdr.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # Ajuste Pre-Silence ou Start-Offset
        def repl_pre(m):
            old = float(m.group(1))
            if d_start >= 0:
                new = old + d_start
                return f"**Pre-Silence:** {new:.0f}"
            else:
                # on conserve Pre-Silence à 0, on gère via Start-Offset
                return m.group(0)
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_start_offset(m):
            old = int(m.group(1))
            if d_start < 0:
                new = old + d_start
                return f"**Start-Offset:** {new}"
            else:
                return m.group(0)
        blk = re.sub(r"\*\*Start-Offset:\*\*\s*(-?\d+)", repl_start_offset, blk)

        # Ajuste Post-Silence ou End-Offset
        def repl_post(m):
            old = float(m.group(1))
            if d_end >= 0:
                new = old + d_end
                return f"**Post-Silence:** {new:.0f}"
            else:
                # on conserve Post-Silence à 0, on gère via End-Offset
                return m.group(0)
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        def repl_end_offset(m):
            old = int(m.group(1))
            if d_end < 0:
                # écrase ou ajoute une ligne End-Offset
                return f"**End-Offset:** {d_end}"
            else:
                return m.group(0)
        blk = re.sub(r"\*\*End-Offset:\*\*\s*(-?\d+)", repl_end_offset, blk)

        out.append(blk)

    # 4) Réécriture du fichier corrigé
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))

    print(f"✅ Review file ajusté selon {debug_log_path}")


def adjust_review_file_based_on_debug_logXX(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")


def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    1) On regroupe et on split/merge les sous-titres exactement
       comme le fera l'audio.
    2) On écrit un review file où l'on affiche :
       - phrase par phrase (la liste exacte via "- ")
       - pre / post silence
       - voice speed
       - start/end offset
       - inter-phrase silences (N–1 valeurs pour N phrases)
    L'utilisateur peut ensuite :
      * ajuster Final Translation, Voice Speed, Pre/Post-Silence,
        Start-Offset, End-Offset
      * modifier le nombre de phrases (le parser adaptera N–1 silences).
    """

    translator = GoogleTranslator(source=from_lang, target=to_lang)
    subs = pysrt.open(source_path)

    # 1) Regrouper par phrase (détection ponctuation en fin de sous-titre)
    sentence_end = re.compile(r"[.!?]\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text):
            groups.append(cur); cur = []
    if cur:
        groups.append(cur)

    # 2) Éclatement des groupes trop longs
    def split_long(gs, max_s):
        out = []
        for g in gs:
            start, end = g[0].start.ordinal/1000, g[-1].end.ordinal/1000
            if end - start <= max_s:
                out.append(g)
            else:
                mid = len(g)//2
                out.extend([g[:mid], g[mid:]])
        return out
    groups = split_long(groups, max_group_duration_secs)

    # 3) Forcer ponctuation de fin de groupe
    i = 0
    safe_punct = re.compile(r"[.!?,;:]$")
    while i < len(groups):
        if not safe_punct.search(groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4) Écriture du fichier de review
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage en phrases ci-dessous est **celui utilisé** en TTS.\n")
        f.write("Ajustez si besoin **Final Translation**, **Voice Speed**, **Pre/Post-Silence**, "
                "**Start-Offset:**, **End-Offset:**, **Inter-Phrase-Silence:**\n")
        f.write("mais **ne touchez pas** la liste des phrases (lignes qui commencent par '- ').\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            # Calcul des temps
            start_s = group[0].start.ordinal / 1000
            end_s   = group[-1].end.ordinal   / 1000

            # Texte original + auto-traduit
            original = " ".join(s.text for s in group)
            auto_tr  = translator.translate(text=original)

            # Découpage initial en phrases (on ne réécrit pas ces lignes, mais on calcule N)
            phrases = re.split(r"(?<=[.!?])\s+(?=[A-ZÀÂÉÈÊËÎÏÔŒÙÛÜ])", auto_tr)
            phrases = [p.strip() for p in phrases if p.strip()]

            # Préparer la liste par défaut des silences internes = N–1 × 0 ms
            n = len(phrases)
            inter_silences = ",".join("0" for _ in range(max(0, n-1)))

            # Valeurs par défaut
            pre_ms, post_ms = 0, 100
            start_offset, end_offset = 0, 0
            voice_speed = "+0%"

            # Écriture du segment
            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Voice Speed:** {voice_speed}\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Start-Offset:** {start_offset}\n")
            f.write(f"**End-Offset:** {end_offset}\n")
            f.write(f"**Inter-Phrase-Silence:** {inter_silences}\n")

            # Liste des phrases pour que l'utilisateur puisse la modifier
            for ph in phrases:
                f.write(f"- {ph}\n")

            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Review file créé : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")



def parse_review_fileOLDA(review_file_path):
    """
    Lit le review file écrit ci-dessus et
    renvoie une liste de dicts avec :
      - start_s, end_s, final_translation, voice_speed
      - pre_silence, post_silence, phrases (list)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")
    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        ft, vs, pre, post = None, "+0%", 0.0, 0.0
        orig = None
        start_offset = 0 
        phrases = []
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                 # offset en millisecondes à ajouter au start
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])                
            elif line.startswith("- "):
                phrases.append(line[2:].strip())
            elif line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()

        segments.append({
            "start_s":           start_s,
            "end_s":             end_s,
            "original":          orig,
            "final_translation": ft or orig,
            "voice_speed":       vs,
            "pre_silence":       pre,
            "post_silence":      post,
            "start_offset_ms":   start_offset,
            "end_offset_ms":     end_offset,
            "phrases":           phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

def parse_review_file(review_file_path):
    """
    Lit le review file et renvoie une liste de dicts avec :
      - start_s, end_s, original, final_translation, voice_speed
      - pre_silence, post_silence, start_offset_ms, end_offset_ms
      - phrases (list de phrases) et inter_phrase_silences (liste de silences internes)
    """
    text = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        m = header.search(blk)
        if not m or blk.startswith("Translation Review File"): 
            continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft, vs = None, "+0%"
        pre, post = 0.0, 0.0
        soffs, eoffs = 0, 0
        phrases = []
        inter = []

        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                soffs = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                eoffs = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("**Inter-Phrase-Silence:**"):
                parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                if parts:
                    inter = [max(0, int(x)) for x in parts.split(",")]
            elif line.startswith("- "):
                phrases.append(line[2:].strip())

        segments.append({
            "start_s": start_s,
            "end_s": end_s,
            "final_translation": ft or "",
            "voice_speed": vs,
            "pre_silence": pre,
            "post_silence": post,
            "start_offset_ms": soffs,
            "end_offset_ms": eoffs,
            "phrases": phrases,
            "inter_phrase_silences": inter
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments


async def async_generate_translated_audio_with_sync_using_review(
    subtitle_source_path, output_audio_path,
    debug_log_path, review_file_path
):
    # 1) Génération / mise à jour du review file
    generate_translation_review_file(
        subtitle_source_path,
        review_file_path,
        max_group_duration_secs=25.0
    )

    # 2) Lecture du review file enrichi
    segments = parse_review_file(review_file_path)

    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        start_s = seg["start_s"]
        end_s   = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        # Récupération des settings
        text    = seg["final_translation"]
        rate    = seg["voice_speed"]
        pre_ms  = seg["pre_silence"]
        post_ms = seg["post_silence"]
        soff    = seg.get("start_offset_ms", 0)
        eoff    = seg.get("end_offset_ms",   0)

        # Phrase splitting & TTS
        phrases = split_french_phrases(text)
        weights = calculate_phrase_weights(text, phrases)
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40)

        # Budget pour TTS seule
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # Synthèse phrase par phrase
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s  = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")
            await robust_synthesize_phrase(ph, tmp_mp3, rate=rate)
            aud = AudioSegment.from_mp3(tmp_mp3)
            os.remove(tmp_mp3)
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # Ajustement interne par override ou répartition égale
        n_inter = max(0, len(phrases) - 1)
        if seg.get("inter_phrase_silences"):
            inter_applied = seg["inter_phrase_silences"]
            # adapter la longueur
            if len(inter_applied) < n_inter:
                inter_applied += [0] * (n_inter - len(inter_applied))
            elif len(inter_applied) > n_inter:
                inter_applied = inter_applied[:n_inter]
        else:
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter

        # Reconstruction du segment audio
        seg_audio = AudioSegment.silent(duration=pre_ms)
        for i, aud in enumerate(phrase_audios):
            seg_audio += aud
            if i < len(inter_applied):
                seg_audio += AudioSegment.silent(duration=inter_applied[i])
        seg_audio += AudioSegment.silent(duration=post_ms)

        # Application offset de fin
        if eoff > 0:
            seg_audio += AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]

        # Debug timing (prise en compte de soff)
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000) + soff
        abs_e_v = int(end_s   * 1000)
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # Mise sur timeline avec offset de start
        start_ms = int(start_s * 1000) + soff
        if len(combined) < start_ms:
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms and soff < 0:
            combined = combined[:start_ms]
        combined += seg_audio

        # Enregistrement debug
        # debug.append(
        #     f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): pre={pre_ms}ms, post={post_ms}ms, "
        #     f"speed={rate}, inter={inter_applied}, "
        #     f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
        # )

        debug.append(
                   f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
                   f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
                   f"inter={inter_applied}, "
                   f"phrases={phrases}, "
                   f"décal_start={decal_start}ms, décal_end={decal_end}ms\n"
                )



    # Export debug & wav
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path


# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
        # ─── 1ʳᵉ passe : génère audio  debug ───
    print("Generating French audio (pass 1)  debug log...")
    await async_generate_translated_audio_with_sync_using_review(
        subtitle_file_en,
        translated_audio,
        debug_log_file,
        review_file
    )

    # ─── Ajustement automatique du review file sur la base du debug ───
    print("Adjusting review file based on debug log...")
    adjust_review_file_based_on_debug_log(debug_log_file, review_file)

    # ─── 2ᵉ passe : régénération audio avec le review file corrigé ───
    print("Generating French audio (pass 2) with adjusted settings...")
    await async_generate_translated_audio_with_sync_using_review(
        subtitle_file_en,
        translated_audio,
        debug_log_file,    # écrasera l'ancien debug_log avec de nouvelles mesures
        review_file
    )
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio (pass 1)  debug log...
# ✅ Review file créé : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\translation_review.txt (27 segments)
# ✅ Parsed 27 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir les configura…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité au niveau de EPM c…'
# [Error] Attempt 1/10 failed for phrase: 'La sécurité au niveau de EPM c…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713260> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La sécurité au niveau de EPM c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons enregistrer, réin…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713F50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir l'application…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'expansion nous montrera EPBC…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Error] Attempt 1/10 failed for phrase: 'Permettez-moi de sélectionner …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857139B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux importer et je peux vo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai sélectionné le cube…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner Règles co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le système indiquera que la rè…'
# [Error] Attempt 1/10 failed for phrase: 'Le système indiquera que la rè…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Le système indiquera que la rè…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les administrateurs utilisent …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La règle va copier les données…'
# [Error] Attempt 1/10 failed for phrase: 'La règle va copier les données…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La règle va copier les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons avoir des règles …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857136E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais donc le valider et l'e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Error] Attempt 1/10 failed for phrase: 'Une fois que je l'ai enregistr…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713410> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais ouvrir un …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour FY23, je n'ai pas de donn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons faire lancer cett…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712BA0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également céduler…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712BA0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons également céduler…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.2s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a aussi des groupes défin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons créer ou ajouter …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713020> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité attribue la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Error] Attempt 1/10 failed for phrase: 'Je vais aller dans le dossier …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713DA0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si j'ajoute le groupe Account …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant regarde…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections valides peuv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons simplement définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer une nouvell…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment créer et config…'
# [Error] Attempt 1/10 failed for phrase: 'Voyons comment créer et config…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0830> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Voyons comment créer et config…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous actions, nous pouvons cré…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur Créer un f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons faire glisser les …'
# [Error] Attempt 1/10 failed for phrase: 'Nous devons faire glisser les …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous devons faire glisser les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Error] Attempt 1/10 failed for phrase: 'Les menus nous aident à passer…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857132F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Error] Attempt 1/10 failed for phrase: 'C'est là que nous pouvons ajou…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857135C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir des propr…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0050> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons définir des propr…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713800> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.7s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également différent…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a également des règles po…'
# [Error] Attempt 1/10 failed for phrase: 'Il y a également des règles po…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0710> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Il y a également des règles po…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé le formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Error] Attempt 1/10 failed for phrase: 'Dans les colonnes, nous avons …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712F00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai utilisé une variable de s…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857139B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, en sélectionnant l'icôn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai mis une condition ici pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons valider la condit…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857135C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et ceci est le formulaire que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En développant l'année, je peu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également l'option d'ajus…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Error] Attempt 1/10 failed for phrase: 'Je peux donc avoir une valeur …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857130B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme sur Excel, nous pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également refléter ces…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour celles-ci, je vais augmen…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713020> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce un ajustement proportio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Disons donc pour le troisième …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, un utilisateur peut fai…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Lorsqu'un icône bleu est visib…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également définir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713020> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons également définir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713770> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la langue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# Adjusting review file based on debug log...
# ✅ Review file ajusté selon 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\translation_debug_log.txt
# Generating French audio (pass 2) with adjusted settings...
# ✅ Review file créé : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\translation_review.txt (27 segments)
# ✅ Parsed 27 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons voir les configura…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment créer une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous verrons comment la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité au niveau de EPM c…'
# [Error] Attempt 1/10 failed for phrase: 'La sécurité au niveau de EPM c…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857135C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La sécurité au niveau de EPM c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Error] Attempt 1/10 failed for phrase: 'À partir de la page d'accueil,…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713BF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais sélectionn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que le membre est mis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons sélectionner le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La formule des membres est uti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ici, le matériel OFS sera divi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons enregistrer, réin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour voir une règle métier, cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci ouvrira la fenêtre de Cal…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir l'application…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'expansion nous montrera EPBC…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Permettez-moi de sélectionner …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux importer et je peux vo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans cette démo, je vais créer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai sélectionné le cube…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner Règles co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le système indiquera que la rè…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Error] Attempt 1/10 failed for phrase: 'Ceci est la première page que …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0440> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ceci est la première page que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les administrateurs utilisent …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons toutes les dimensio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La règle va copier les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons avoir des règles …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_14.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais donc le valider et l'e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_15.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Maintenant, je vais ouvrir un …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour FY23, je n'ai pas de donn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller à ma règle et cl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons faire lancer cett…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous voyez comment les données…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux l'exécuter à partir du…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Error] Attempt 1/10 failed for phrase: 'Cela nous aide donc à exécuter…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0A70> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 3.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également céduler…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713530> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également céduler…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité peut être appliqué…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Error] Attempt 1/10 failed for phrase: 'Ceci peut être fait en utilisa…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713140> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Ceci peut être fait en utilisa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour en savoir plus sur la séc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a aussi des groupes défin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons attribuer différe…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713BF0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons attribuer différe…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712DE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.5s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons attribuer différe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons attribuer des rôl…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons exporter à partir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais montrer plus de détail…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712DE0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Error] Attempt 2/10 failed for phrase: 'Je vais montrer plus de détail…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857130B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 5.0s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Je vais montrer plus de détail…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour cette dimension particuli…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La sécurité attribue la sécuri…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment nous pouvons at…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Si j'ajoute le groupe Account …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant regarde…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les intersections valides peuv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons simplement définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également une sécur…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer une nouvell…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Voyons comment créer et config…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous actions, nous pouvons cré…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur Créer un f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devons faire glisser les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également avoir d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous devrons sélectionner les …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Error] Attempt 1/10 failed for phrase: 'Cliquer sur l'icône me donnera…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857130B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Error] Attempt 2/10 failed for phrase: 'Cliquer sur l'icône me donnera…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857135C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.3s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Cliquer sur l'icône me donnera…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai la possibilité de personn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Error] Attempt 1/10 failed for phrase: 'Les menus nous aident à passer…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712F00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Les menus nous aident à passer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'C'est là que nous pouvons ajou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons dire comment nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Error] Attempt 1/10 failed for phrase: 'Dans la disposition, nous pouv…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713AD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dans la disposition, nous pouv…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir des propr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_4.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_5.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous avons également différent…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_6.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Il y a également des règles po…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_7.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai créé le formulaire de don…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_8.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dans les colonnes, nous avons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_9.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_10.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, en sélectionnant l'icôn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_11.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir les varia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_12.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai mis une condition ici pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_13.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la condit…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais enregistrer ce formula…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857134A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et ceci est le formulaire que …'
# [Error] Attempt 1/10 failed for phrase: 'Et ceci est le formulaire que …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712600> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Et ceci est le formulaire que …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'En développant l'année, je peu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également l'option d'ajus…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_3.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Error] Attempt 1/10 failed for phrase: 'Je peux donc avoir une valeur …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713380> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Error] Attempt 1/10 failed for phrase: 'La cellule est mise à jour et …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857134A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Error] Attempt 2/10 failed for phrase: 'La cellule est mise à jour et …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.7s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Error] Attempt 3/10 failed for phrase: 'La cellule est mise à jour et …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0170> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.2s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Error] Attempt 1/10 failed for phrase: 'Chaque fois que la cellule est…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713260> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Error] Attempt 2/10 failed for phrase: 'Chaque fois que la cellule est…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713C80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.0s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme sur Excel, nous pou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également refléter ces…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour celles-ci, je vais augmen…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce un ajustement proportio…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Disons donc pour le troisième …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également ajouter…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x00000285857C0C20> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur sera en mesure d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, un utilisateur peut fai…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Lorsqu'un icône bleu est visib…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également définir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712D50> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la langue…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir la façon …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585713770> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Error] Attempt 2/10 failed for phrase: 'Nous pouvons définir la façon …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000028585712F00> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.0s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Nous pouvons définir la façon …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_2.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'la précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250504_095813\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4

# %% [markdown]
# code01MAY_424

# %%
import os
import re
import ffmpeg
import pysrt
import time
from deep_translator import GoogleTranslator
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from faster_whisper import WhisperModel
from shutil import which
import nest_asyncio
from datetime import datetime
import tempfile
import asyncio
import edge_tts
import aiohttp
import ssl
import random
from pydub.silence import detect_nonsilent
import spacy


nest_asyncio.apply()

# ----- Configuration -----
ffmpeg_path = which("ffmpeg")
if not ffmpeg_path:
    raise RuntimeError("ffmpeg not found. Please install ffmpeg first.")
print(f"✅ ffmpeg found at: {ffmpeg_path}")

input_video = "to translate/4.2.4_Configuration de la solution_Avr_10_Latest.mp4"
base_name = os.path.splitext(os.path.basename(input_video))[0]
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"{base_name}_run_{timestamp}"
model_size = "small"
update_existing = True

# For this version we rely on cloud-based Edge TTS.
USE_EDGE_TTS = True

# Files and paths
os.makedirs(output_dir, exist_ok=True)
input_video_name = os.path.splitext(os.path.basename(input_video))[0]
extracted_audio = os.path.join(output_dir, f"{input_video_name}-extracted-audio.wav")
subtitle_file_en = os.path.join(output_dir, f"{input_video_name}-english.srt")
translated_audio = os.path.join(output_dir, f"{input_video_name}-french.wav")
output_video = os.path.join(output_dir, f"{input_video_name}-french.mp4")
review_file = os.path.join(output_dir, "translation_review.txt")
debug_log_file = os.path.join(output_dir, "translation_debug_log.txt")

# ============== Helper Functions (extract_audio, transcribe, etc.) ==============
def extract_audio():
    try:
        (ffmpeg
         .input(input_video)
         .output(extracted_audio, ac=1, ar=16000)
         .overwrite_output()
         .run(capture_stdout=True, capture_stderr=True)
        )
        return extracted_audio
    except ffmpeg.Error as e:
        print("STDOUT:", e.stdout.decode("utf8"))
        print("STDERR:", e.stderr.decode("utf8"))
        raise

def transcribe(audio_path):
    model = WhisperModel(model_size, device="cpu", compute_type="int8")
    segments, info = model.transcribe(audio_path, beam_size=5)
    language = info.language
    print(f"Detected language: {language}")
    transcript_segments = []
    for segment in segments:
        transcript_segments.append({
            "start": segment.start,
            "end": segment.end,
            "text": segment.text.strip()
        })
    return language, transcript_segments

def time_to_subrip(seconds: float) -> pysrt.SubRipTime:
    hours = int(seconds // 3600)
    seconds %= 3600
    minutes = int(seconds // 60)
    seconds %= 60
    milliseconds = int((seconds - int(seconds)) * 1000)
    return pysrt.SubRipTime(hours=hours, minutes=minutes, seconds=int(seconds), milliseconds=milliseconds)

def generate_subtitle_file(segments, output_path):
    subs = pysrt.SubRipFile()
    for i, segment in enumerate(segments, 1):
        sub = pysrt.SubRipItem(
            index=i,
            start=time_to_subrip(segment["start"]),
            end=time_to_subrip(segment["end"]),
            text=segment["text"]
        )
        subs.append(sub)
    subs.save(output_path, encoding="utf-8")
    return output_path

# ============== Translation & Review Functions ==============

def split_long_groups(groups, max_group_duration_secs):
    """
    For each group (list of SubRipItems), if its duration > max_group_duration_secs,
    split it at the *last* subtitle in that group whose text ends in punctuation
    (.,!? or comma) before the duration threshold.
    Falls back to a simple split if no such “safe” break exists.
    """
    new_groups = []
    for group in groups:
        start_s = group[0].start.ordinal / 1000
        end_s   = group[-1].end.ordinal   / 1000
        total   = end_s - start_s

        # if already shorter than threshold, keep it
        if total <= max_group_duration_secs:
            new_groups.append(group)
            continue

        # otherwise walk through, tracking safe_breaks
        temp = []
        temp_start = start_s
        last_safe_idx = None
        for idx, item in enumerate(group):
            temp.append(item)
            # mark this idx if it ends in punctuation or comma
            if re.search(r"[.,!?]$", item.text.strip()):
                last_safe_idx = idx

            current_end = item.end.ordinal / 1000
            if (current_end - temp_start) >= max_group_duration_secs:
                # if we have a safe break before or at idx, split there
                if last_safe_idx is not None:
                    # emit group up through last_safe_idx
                    safe_group = temp[: last_safe_idx+1 ]
                    new_groups.append(safe_group)
                    # restart temp from the items after safe_idx
                    temp = temp[last_safe_idx+1 :]
                    temp_start = temp[0].start.ordinal / 1000 if temp else current_end
                else:
                    # no safe break—just split at current idx
                    new_groups.append(temp)
                    temp = []
                    temp_start = current_end

                # reset safe marker
                last_safe_idx = None

        # anything left over
        if temp:
            new_groups.append(temp)

    return new_groups


def validate_audio_duration(original_segment, translated_audio):
    """Compares original video duration with generated audio"""
    video_dur = original_segment['end'] - original_segment['start']
    audio_dur = translated_audio.duration_seconds
    
    if abs(video_dur - audio_dur) > 0.5:  # 500ms tolerance
        compensation = (video_dur - audio_dur) * 1000  # ms
        if compensation > 0:
            return AudioSegment.silent(duration=compensation)
        else:
            return translated_audio[:int(compensation*1000)]  # ms to samples
    return translated_audio

def generate_phrase_audio(text, voice_speed):
    raw_audio = edge_tts.Communicate(text).audio
    processed = apply_speed_adjustment(raw_audio, voice_speed)
    
    # Detect and preserve natural phrase endings
    non_silent = detect_nonsilent(processed, min_silence_len=50, silence_thresh=-40)
    if non_silent:
        end_pad = 150  # Minimum ending padding
        new_end = max(non_silent[-1][1] + end_pad, len(processed))
        return processed[:new_end]
    return processed


def apply_speed_adjustment(raw_audio, speed_setting):
    speed_factor = 1 + (int(speed_setting.strip('%')) / 100)
    sped_up = raw_audio.speedup(
        playback_speed=speed_factor,
        chunk_size=150,
        crossfade=25
    )
    
    # Calculate duration difference
    original_dur = len(raw_audio)
    new_dur = len(sped_up)
    compensation = original_dur - new_dur
    
    if compensation > 0:
        return sped_up + AudioSegment.silent(duration=compensation)
    return sped_up



def parse_review_overrides(review_file_path):
    text   = open(review_file_path, "r", encoding="utf-8").read()
    # split on any line of 3+ hyphens
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    overrides = []
    for idx, blk in enumerate(blocks, start=1):
        blk = blk.strip()
        if not blk or blk.startswith("Translation Review File"):
            continue

        # defaults
        ft       = None
        vs       = "+0%"
        pre_ms   = 0.0
        post_ms  = 100.0
        inter_ms = []

        for line in blk.splitlines():
            if line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                try: pre_ms = float(line.split("**Pre-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Pre-Silence")
            elif line.startswith("**Post-Silence:**"):
                try: post_ms = float(line.split("**Post-Silence:**",1)[1])
                except: print(f"[Warn] Seg {idx}: bad Post-Silence")
            elif line.startswith("**Inter-Phrase-Silence:**"):
                            parts = line.split("**Inter-Phrase-Silence:**",1)[1].strip()
                            if parts:
                                try:
                                    # Force negative values to 0 and limit to 5000ms max
                                    raw = [float(x) for x in parts.split(",")]
                                    inter_ms = [ max(0, min(x, 5000)) for x in raw ]
                                except ValueError:
                                    print(f"[Warning] Segment {idx}: invalid Inter-Phrase-Silence list")
                                    inter_ms = []

        if ft is None:
            print(f"[Warn] Seg {idx}: no Final Translation—will use source text.")

        overrides.append({
            "final_translation":      ft,
            "voice_speed":            vs,
            "pre_silence":            pre_ms,
            "post_silence":           post_ms,
            "inter_phrase_silences":  inter_ms
        })

    print("Parsed review overrides:")
    for i,o in enumerate(overrides,1):
        print(f"  Seg {i}: final={'OK' if o['final_translation'] else '<none>'}, "
              f"speed={o['voice_speed']}, pre={o['pre_silence']}ms, post={o['post_silence']}ms, "
              f"inter={o['inter_phrase_silences']}")
    return overrides


def enforce_punctuation_boundaries(groups):
    """Ensure groups end with proper punctuation"""
    i = 0
    safe_punctuation = r"[.!?,;:]$"
    while i < len(groups):
        last_text = groups[i][-1].text.strip()
        if not re.search(safe_punctuation, last_text):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
            else:  # Add artificial pause for final group
                groups[i][-1].text += "."
        else:
            i += 1
    return groups



# ============== Audio Synchronization Functions ==============


def adjust_audio_duration(audio: AudioSegment, target_secs: float) -> AudioSegment:
    """
     Ajuste TTS clip pour qu'il tienne **exactement** dans target_secs :
     - Si l'audio est trop long, on le **tronque**.  
     - S'il est trop court, on ajoute du silence.  
    """
    target_ms = int(target_secs * 1000)
    curr_ms   = len(audio)
    if curr_ms > target_ms:
        # on coupe précisément à la durée allouée
        return audio[:target_ms]
    elif curr_ms < target_ms:
            # on complète par du silence
        return audio + AudioSegment.silent(duration=(target_ms - curr_ms))
    return audio


# ============== French Phrase Alignment Functions ==============
def split_french_phrases(text):
    phrases = re.split(r"(?<=[.!?])\s+(?=[A-Z])", text)
    return [phrase.strip() for phrase in phrases if phrase.strip()]

def calculate_phrase_weights(original_text, translated_phrases):
    fr_phrase_word_counts = [len(phrase.split()) for phrase in translated_phrases]
    total_fr_words = sum(fr_phrase_word_counts)
    if total_fr_words == 0:
        return [1 / len(translated_phrases)] * len(translated_phrases)
    return [count / total_fr_words for count in fr_phrase_word_counts]

# ============== TTS Functions: Edge TTS Only with Debug Logging ==============


def change_playback_speed(sound, speed=1.0):
    new_frame_rate = int(sound.frame_rate * speed)
    altered_sound = sound._spawn(sound.raw_data, overrides={"frame_rate": new_frame_rate})
    return altered_sound.set_frame_rate(sound.frame_rate)

# ============== Updated Async Audio Generation Function ==============


def validate_audio_timing(original_duration, translated_segment):
    total_audio_time = (
        translated_segment["pre_silence"] 
        + sum(translated_segment["inter_phrase_silences"]) 
        + translated_segment["post_silence"] 
        + (translated_segment["audio"].duration_seconds * 1000)
    )
    
    if total_audio_time > original_duration * 1000:
        raise ValueError(f"Audio overflow: {total_audio_time}ms vs {original_duration*1000}ms")
    elif total_audio_time < original_duration * 1000 * 0.95:
        print(f"Warning: Audio underflow by {original_duration*1000 - total_audio_time}ms")



def adjust_review_file_based_on_debug_log(debug_log_path: str, review_file_path: str):
    """
    Pour chaque segment i :
      - Si décal_end est négatif de D ms, on ajoute D ms à post_silence
      - Si décal_start est positif de D ms, on ajoute D ms à pre_silence
    On réécrit ensuite le review_file avec ces nouvelles valeurs.
    """
    # 1) Parse le debug log
    decalages = {}  # idx -> (d_start, d_end)
    pattern = re.compile(r"Segment (\d+).*décal_start=(-?\d+)ms, décal_end=(-?\d+)ms")
    for line in open(debug_log_path, encoding="utf-8"):
        m = pattern.search(line)
        if m:
            idx = int(m.group(1))
            d_start, d_end = int(m.group(2)), int(m.group(3))
            decalages[idx] = (d_start, d_end)

    # 2) Lit tout le review file en mémoire
    text = open(review_file_path, encoding="utf-8").read()
    blocks = re.split(r"(?m)^-{3,}\s*$", text)

    out = []
    for blk in blocks:
        if not blk.strip() or blk.startswith("Translation Review File"):
            out.append(blk)
            continue

        # trouve le segment
        header = re.search(r"Segment\s+(\d+)\s+\(", blk)
        if not header:
            out.append(blk); continue
        idx = int(header.group(1))
        d_start, d_end = decalages.get(idx, (0, 0))

        # remplace les lignes Pre-Silence / Post-Silence
        def repl_pre(m):
            old = float(m.group(1))
            new = max(0.0, old + d_start)
            return f"**Pre-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Pre-Silence:\*\*\s*([0-9.]+)", repl_pre, blk)

        def repl_post(m):
            old = float(m.group(1))
            # si d_end<0, audio est trop long => il a fallu tronquer => on ne réduit pas post
            # si d_end>0, audio trop court => on ajoute
            new = max(0.0, old + d_end)
            return f"**Post-Silence:** {new:.0f}"
        blk = re.sub(r"\*\*Post-Silence:\*\*\s*([0-9.]+)", repl_post, blk)

        out.append(blk)

    # 3) Réécriture du fichier
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("\n---\n".join(out))
    print(f"✅ Review file ajusté selon {debug_log_path}")




def generate_translation_review_file(
    source_path, review_file_path,
    from_lang="en", to_lang="fr",
    max_group_duration_secs: float = 25.0
):
    """
    Génère un fichier de revue TTS avec :
     - votre Final Translation corrigé
     - une section Silence-Avant: pour chaque phrase (initialisée à 0)
    """
    print(f"🔍 Chargement des sous-titres depuis : {source_path}")
    try:
        subs = pysrt.open(source_path, encoding='utf-8')
    except UnicodeDecodeError:
        subs = pysrt.open(source_path, encoding='latin-1')

    translator = GoogleTranslator(source=from_lang, target=to_lang)
    nlp = spacy.load("fr_core_news_sm")

    # 1. Regroupement initial par ponctuation
     #sentence_end = re.compile(r"[.!?][\"')\]]?\s*$")
    sentence_end = re.compile(r"[.!?;,][\"')\]]?\s*$")
    groups, cur = [], []
    for sub in subs:
        cur.append(sub)
        if sentence_end.search(sub.text.strip()):
            groups.append(cur); cur = []
    if cur: groups.append(cur)

    # 2. Découpage des groupes trop longs (> max_group_duration_secs)
    def split_long(gs, max_s):
        def split_group(g):
            start = g[0].start.ordinal / 1000
            end   = g[-1].end.ordinal   / 1000
            dur   = end - start
            if dur <= max_s or len(g) == 1:
                return [g]
            # recherche de point de rupture sûr
            for i in range(len(g)-1, 0, -1):
                if re.search(r"[.?!,;:]$", g[i].text.strip()):
                    left, right = g[:i+1], g[i+1:]
                    if left and right:
                        return split_group(left) + split_group(right)
            mid = len(g)//2
            return split_group(g[:mid]) + split_group(g[mid:])
        out = []
        for g in gs:
            out.extend(split_group(g))
        return out

    groups = split_long(groups, max_group_duration_secs)

    # 3. Fusion si manque ponctuation finale
    i = 0
    while i < len(groups):
        if not re.search(r"[.!?,;:]$", groups[i][-1].text.strip()):
            if i+1 < len(groups):
                groups[i] += groups.pop(i+1)
                continue
            else:
                groups[i][-1].text += "."
        i += 1

    # 4. Écriture du fichier de revue
    print(f"✏️ Écriture du fichier de revue : {review_file_path}")
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File\n")
        f.write("Le découpage ci-dessous est celui utilisé en TTS.\n")
        f.write("Corrigez **Final Translation**, puis renseignez **Silence-Avant**.\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, group in enumerate(groups, 1):
            start_s = group[0].start.ordinal / 1000
            end_s   = group[-1].end.ordinal   / 1000
            original = " ".join(s.text.strip() for s in group)

            try:
                auto_tr = translator.translate(text=original)
            except Exception:
                auto_tr = "[ERREUR DE TRADUCTION]"

            # segmentation en phrases sur texte traduit
            doc = nlp(auto_tr)
            phrases = [sent.text.strip() for sent in doc.sents if sent.text.strip()]

            total_ms = int((end_s - start_s) * 1000)
            pre_ms, post_ms = 0, 0

            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original:** {original}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n\n")

            # Section Silence-Avant
            f.write("**Silence-Avant:**\n")
            for ph in phrases:
                f.write(f"- {ph} : 0\n")

            f.write(f"**Voice Speed:** +0%\n")
            f.write(f"**Pre-Silence:** {pre_ms}\n")
            f.write(f"**Post-Silence:** {post_ms}\n")
            f.write(f"**Start-Offset:** 0\n")
            f.write(f"**End-Offset:** 0\n")
            f.write(f"**Budget (ms):** {total_ms}\n")
            f.write("\n----------------------------------------------------------------\n\n")

    print(f"✅ Fichier de revue généré : {review_file_path} ({len(groups)} segments)")
    input("Tapez 'Y' pour continuer…")

import pysrt
import re
from deep_translator import GoogleTranslator
import spacy

def generate_translation_review_file_from_srt(
    source_srt, review_file_path,
    from_lang="en", to_lang="fr"
):
    """
    Génère un review file où chaque item du SRT anglais
    devient un segment TTS FR avec mêmes start/end.
    """
    # 1) Chargement
    subs = pysrt.open(source_srt, encoding='utf-8')
    translator = GoogleTranslator(source=from_lang, target=to_lang)
    nlp = spacy.load("fr_core_news_sm")

    # 2) Écriture du review file
    with open(review_file_path, "w", encoding="utf-8") as f:
        f.write("Translation Review File (basé sur le .srt anglais)\n")
        f.write("Chaque segment ci-dessous correspond à un item du SRT original.\n")
        f.write("Corrigez **Final Translation**, **Silence-Avant** ou **Silence-Après** si nécessaire.\n")
        f.write("----------------------------------------------------------------\n\n")

        for idx, sub in enumerate(subs, start=1):
            start_s = sub.start.ordinal / 1000
            end_s   = sub.end.ordinal   / 1000
            original_en = sub.text.replace("\n", " ")

            # traduction automatique
            try:
                auto_tr = translator.translate(text=original_en)
            except Exception:
                auto_tr = "[ERREUR DE TRADUCTION]"

            # segmentation FR pour info (ne décalera pas les times)
            doc = nlp(auto_tr)
            phrases = [sent.text.strip() for sent in doc.sents if sent.text.strip()]

            f.write(f"Segment {idx} (start: {start_s:.2f}s, end: {end_s:.2f}s)\n")
            f.write(f"**Original (EN):** {original_en}\n")
            f.write(f"**Auto Translated:** {auto_tr}\n")
            f.write(f"**Final Translation:** {auto_tr}\n")
            f.write(f"**Phrases (info) :**\n")
            for ph in phrases:
                f.write(f"- {ph}\n")
            f.write(f"**Pre-Silence:** 0\n")
            f.write(f"**Post-Silence:** 100\n")
            f.write(f"**Start-Offset:** 0\n")
            f.write(f"**End-Offset:** 0\n")
            f.write("----------------------------------------------------------------\n\n")

    print(f"✅ Review file généré ({len(subs)} segments) : {review_file_path}")
    input("⚠️  Veuillez maintenant éditer le fichier de revue si besoin, puis appuyez sur Entrée pour continuer…")

def parse_review_file(review_file_path):
    """
    Lit le review file généré ci-dessus et
    renvoie la liste des segments avec leurs silences manuels.
    """
    text   = open(review_file_path, encoding="utf-8").read()
    blocks = [b.strip() for b in re.split(r"(?m)^-{3,}\s*$", text) if b.strip()]
    segments = []
    header = re.compile(r"Segment\s+\d+\s+\(start:\s*([0-9.]+)s,\s*end:\s*([0-9.]+)s\)")

    for blk in blocks:
        if blk.startswith("Translation Review File"):
            continue
        m = header.search(blk)
        if not m:
            continue
        start_s, end_s = float(m.group(1)), float(m.group(2))

        # valeurs par défaut
        ft            = None
        vs            = "+0%"
        pre, post     = 0.0, 0.0
        start_offset  = 0
        end_offset    = 0
        phrases       = []
        orig          = None

        # 1) Lecture des champs fixes + collecte des phrases
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Original:**"):
                orig = line.split("**Original:**",1)[1].strip()
            elif line.startswith("**Final Translation:**"):
                ft = line.split("**Final Translation:**",1)[1].strip()
            elif line.startswith("**Voice Speed:**"):
                vs = line.split("**Voice Speed:**",1)[1].strip()
            elif line.startswith("**Pre-Silence:**"):
                pre = float(line.split("**Pre-Silence:**",1)[1])
            elif line.startswith("**Post-Silence:**"):
                post = float(line.split("**Post-Silence:**",1)[1])
            elif line.startswith("**Start-Offset:**"):
                start_offset = int(line.split("**Start-Offset:**",1)[1])
            elif line.startswith("**End-Offset:**"):
                end_offset = int(line.split("**End-Offset:**",1)[1])
            elif line.startswith("- "):
                phrases.append(line[2:].split(" : ")[0].strip())

        # 2) Prépare la liste des silences (initialisés à 0)
        n_inter = max(0, len(phrases) - 1)
        inter_silences = [0] * n_inter

        # 3) Lecture de la section Silence-Avant, si présente
        state = None
        for line in blk.splitlines():
            line = line.strip()
            if line.startswith("**Silence-Avant:**"):
                state = "silence"; continue
            if state == "silence":
                if not line:
                    state = None
                    continue
                if line.startswith("- ") and ":" in line:
                    ph_text, ms_str = line[2:].rsplit(":", 1)
                    ph_text, ms_str = ph_text.strip(), ms_str.strip()
                    try:
                        ms = int(ms_str)
                    except ValueError:
                        continue
                    if ph_text in phrases:
                        idx = phrases.index(ph_text)
                        if idx > 0:
                            inter_silences[idx-1] = ms
        # --- Nouveau bloc : calcul du budget et renommage des silences ---
        duration_ms = int((end_s - start_s) * 1000)
        # budget de base = durée segment, on y ajoutera silences internes
        budget_ms = duration_ms + sum(inter_silences)
        segments.append({
            "start_s":             start_s,
            "end_s":               end_s,
            "original":            orig,
            "final_translation":   ft or orig,
            "voice_speed":         vs,
            "pre_silence":         pre,
            "post_silence":        post,
            "start_offset_ms":     start_offset,
            "end_offset_ms":       end_offset,
            "silences_internal":   inter_silences,
            "budget_ms":           budget_ms,
            "phrases":             phrases
        })

    print(f"✅ Parsed {len(segments)} segments depuis le review file.")
    return segments


# ============== TTS Functions: Edge TTS Only with Debug Logging ==============
async def robust_synthesize_phrase(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%",
    max_retries: int = 10
):
    """
    Synthesize speech using Edge TTS with robust retry logic.
    Detailed debug messages are printed for each attempt.
    """
    for attempt in range(1, max_retries+1):
        try:
            async with aiohttp.ClientSession(timeout=aiohttp.ClientTimeout(total=30)) as session:
                communicate = edge_tts.Communicate(
                    text=phrase,
                    voice=voice,
                    rate=rate
                )
                print(f"[Debug] Attempt {attempt}/{max_retries}: Synthesizing phrase: '{phrase[:30]}…'")
                await communicate.save(output_path)
                print(f"[Debug] Phrase synthesized successfully to {output_path}")
                return
        except Exception as e:
            wait_time = 2 ** attempt + random.random()
            print(f"[Error] Attempt {attempt}/{max_retries} failed for phrase: '{phrase[:30]}…'. Exception: {e}")
            if attempt < max_retries:
                print(f"[Debug] Retrying in {wait_time:.1f}s…")
                await asyncio.sleep(wait_time)
    raise RuntimeError(f"Failed to synthesize phrase after {max_retries} attempts: {phrase[:30]}…")

async def synthesize_phrase_edge_hybrid(
    phrase: str,
    output_path: str,
    voice: str = "fr-FR-DeniseNeural",
    rate: str = "+0%"
):
    # Pour compatibilité, on redirige vers le robust_synthesize
    await robust_synthesize_phrase(phrase, output_path, voice, rate)


def merge_short_phrases(phrases, weights, min_chars=40, max_chars=None):
    new_ph, new_wt = [], []
    buf_ph, buf_wt = "", 0.0
    for ph, wt in zip(phrases, weights):
        if not buf_ph:
            buf_ph, buf_wt = ph, wt
        else:
            if len(buf_ph) < min_chars or len(ph) < min_chars:
                cand = buf_ph + " " + ph
                # si pas de max_chars défini, on fusionne sans condition
                cond = True if max_chars is None else (len(cand) <= max_chars)
                if cond:
                    buf_ph = cand
                    buf_wt += wt
                else:
                    new_ph.append(buf_ph)
                    new_wt.append(buf_wt)
                    buf_ph, buf_wt = ph, wt
            else:
                new_ph.append(buf_ph)
                new_wt.append(buf_wt)
                buf_ph, buf_wt = ph, wt
    if buf_ph:
        new_ph.append(buf_ph)
        new_wt.append(buf_wt)
    return new_ph, new_wt



def split_long_phrasesaaa(phrases, max_chars=80):
    new = []
    for p in phrases:
        if len(p) > max_chars:
            # on découpe au premier “,” ou “ et ” qu’on trouve
            parts = re.split(r",\s+| et ", p, maxsplit=1)
            new.extend([parts[0].strip(), parts[1].strip()] if len(parts)==2 else [p])
        else:
            new.append(p)
    return new

async def async_generate_translated_audio_with_sync_using_review(
    subtitle_file_en, output_audio_path,
    debug_log_path, review_file_path
):
    # ─── 1) Génération / mise à jour du review file ───
    # groups = generate_translation_review_file(
    #     subtitle_source_path,
    #     review_file_path,
    #     max_group_duration_secs=25.0
    # )


    generate_translation_review_file_from_srt(
        source_srt = subtitle_file_en,
        review_file_path=review_file
    )




    # ─── 2) Lecture du review file enrichi ───
    segments = parse_review_file(review_file_path)
    
        # ─── Injecter les start_offset basés sur le end_offset du segment précédent ───
    for i in range(1, len(segments)):
        prev = segments[i-1]
        segments[i]['start_offset_ms'] = - prev['end_offset_ms']


    combined = AudioSegment.silent(duration=0)
    debug    = []

    for idx, seg in enumerate(segments):
        # ─── 3) Récupérations de base ───
        start_s  = seg["start_s"]
        end_s    = seg["end_s"]
        total_ms = int((end_s - start_s) * 1000)

        text   = seg["final_translation"]
        rate   = seg["voice_speed"]
        pre_ms = seg["pre_silence"]
        post_ms= seg["post_silence"]

        # ─── 4) Utilisation des phrases définies dans le review file ───
        # si l'utilisateur a listé ses phrases, on les prend ; sinon fallback automatique
        # if seg.get("phrases"):
        #     phrases = seg["phrases"]
        # else:
        phrases = split_french_phrases(text)
        # calcul des poids sur texte final
        weights = calculate_phrase_weights(text, phrases)
        # fusion éventuelle de mini-phrases trop courtes
        phrases, weights = merge_short_phrases(phrases, weights, min_chars=40, max_chars=None)

        # ─── 6) Budget TTS versus silences pré/post ───
        content_ms = max(0, total_ms - pre_ms - post_ms)

        # ─── 7) Synthèse phrase par phrase avec retry ───
        phrase_audios = []
        for i, ph in enumerate(phrases):
            dur_s   = (content_ms * weights[i]) / 1000.0
            tmp_mp3 = os.path.join(tempfile.gettempdir(), f"tmp_{idx}_{i}.mp3")

            await robust_synthesize_phrase(
                ph, tmp_mp3,
                voice="fr-FR-DeniseNeural",
                rate=rate
            )
            # aud = AudioSegment.from_mp3(tmp_mp3)
            # os.remove(tmp_mp3)
            
            # 1) charger dans une variable
            aud = AudioSegment.from_mp3(tmp_mp3)
            # 2) fermer le handle et essayer de supprimer
            try:
                os.remove(tmp_mp3)
            except PermissionError:
                # si Windows bloque, on ignore : le tmp sera nettoyé par le système ou au prochain run
                pass
            # 3) continuer à travailler sur aud

            # On ajuste strictement à la durée allouée
            aud = adjust_audio_duration(aud, dur_s)
            phrase_audios.append(aud)

        # ─── 8) Anti-dépassement TTS seul ───
        sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)
        if sum_tts > content_ms and sum_tts > 0:
            factor = content_ms / sum_tts
            phrase_audios = [
                change_playback_speed(a, factor)
                for a in phrase_audios
            ]
            sum_tts = sum(a.duration_seconds * 1000 for a in phrase_audios)

        # ─── 9) Silences internes (manuels ou automatiques) ───
        n_inter   = max(0, len(phrases) - 1)
        # si l'utilisateur a rempli inter_phrase_silences dans le review file, on l'utilise
        #manual_inters = seg.get("inter_phrase_silences", [])
        manual_inters = seg.get("silences_internal", [])
        if manual_inters and len(manual_inters) == n_inter:
            inter_applied = manual_inters
        else:
            # budget restant en ms pour inter-phrases
            available = content_ms - sum(a.duration_seconds * 1000 for a in phrase_audios)
            if n_inter > 0 and available > 0:
                sil_ms = available // n_inter
                inter_applied = [sil_ms] * n_inter
            else:
                inter_applied = [0] * n_inter
                
                

        # ─── 10) Reconstruction du segment ───
        seq = []
        for i, aud in enumerate(phrase_audios):
            seq.append(aud)
            if i < len(inter_applied):
                seq.append(AudioSegment.silent(duration=inter_applied[i]))

        seg_audio = AudioSegment.silent(duration=pre_ms)
        for clip in seq:
            seg_audio += clip
        seg_audio += AudioSegment.silent(duration=post_ms)

        # ─── 11) Strip des silences internes TTS indésirables ───
        nons = detect_nonsilent(seg_audio, min_silence_len=1,
                                silence_thresh=seg_audio.dBFS - 16)
        if nons:
            seg_audio = seg_audio[nons[0][0]:]
        seg_audio = AudioSegment.silent(duration=pre_ms) + seg_audio

        # ─── 12) Pad ou trim strict au total_ms ───
        if len(seg_audio) < total_ms:
            seg_audio += AudioSegment.silent(duration=(total_ms - len(seg_audio)))
        seg_audio = seg_audio[:total_ms]

        # ─── 13) Debug timings ───
        nons2 = detect_nonsilent(seg_audio, min_silence_len=1,
                                 silence_thresh=seg_audio.dBFS - 16)
        start_a = nons2[0][0] if nons2 else pre_ms
        end_a   = nons2[-1][1] if nons2 else (total_ms - post_ms)
        abs_s_a = int(start_s * 1000) + start_a
        abs_e_a = int(start_s * 1000) + end_a
        abs_s_v = int(start_s * 1000)
        abs_e_v = int(end_s   * 1000)
        decal_start = abs_s_a - abs_s_v
        decal_end   = abs_e_a - abs_e_v

        # ─── 14) Warp global si nécessaire ───
        gen_dur = seg_audio.duration_seconds
        diff    = (end_s - start_s) - gen_dur
        if abs(diff) > 0.20:
            seg_audio = change_playback_speed(seg_audio, (end_s - start_s) / gen_dur)

        # ─── 15) Mix sur la timeline avec positionnement absolu ───
        base_ms   = int(start_s * 1000)
        soff      = seg.get("start_offset_ms", 0)
        eoff      = seg.get("end_offset_ms",   0)

        # 1) Appliquer l’offset de fin sur seg_audio
        if eoff > 0:
            seg_audio = seg_audio + AudioSegment.silent(duration=eoff)
        elif eoff < 0:
            seg_audio = seg_audio[:eoff]  # tronque les |eoff| derniers ms

        # 2) Calculer le point de départ absolu
        start_ms = base_ms + soff

        # 3) Forcer combined à exactement start_ms
        if len(combined) < start_ms:
            # la timeline est trop courte → on padde jusqu’à start_ms
            combined += AudioSegment.silent(duration=(start_ms - len(combined)))
        elif len(combined) > start_ms:
            # un précédent segment a débordé → on tronque pour revenir à start_ms
            combined = combined[:start_ms]

        # 4) Coller le segment audio
        combined += seg_audio


        # ─── 16) Log debug ───
        debug.append(
            f"Segment {idx+1} ({start_s:.2f}-{end_s:.2f}s): "
            f"pre={pre_ms}ms, post={post_ms}ms, speed={rate}, "
            f"silences_internal={inter_applied}, "
            f"décal_start={decal_start}ms, décal_end={decal_end}ms, "
            f"phrases={phrases}\n"
        )


    # ─── 17) Export debug & wav ───
    with open(debug_log_path, "w", encoding="utf-8") as df:
        df.write("Translation Debug Log\n\n")
        df.writelines(debug)
    combined.export(output_audio_path, format="wav")

    return output_audio_path



# ============== Merge Audio and Video Function ==============
def merge_audio_video():
    video = VideoFileClip(input_video)
    audio = AudioFileClip(translated_audio)
    if audio.duration < video.duration:
        extra_silence = AudioSegment.silent(duration=(video.duration - audio.duration) * 1000)
        audio_path_temp = os.path.join(output_dir, "temp_full_audio.wav")
        audio_seg = AudioSegment.from_file(translated_audio, format="wav")
        full_audio = audio_seg + extra_silence
        full_audio.export(audio_path_temp, format="wav")
        audio = AudioFileClip(audio_path_temp)
    video = video.set_audio(audio)
    video.write_videofile(
        output_video,
        codec="libx264",
        audio_codec="aac",
        temp_audiofile="temp-audio.m4a",
        remove_temp=True,
        threads=4
    )

# ============== Main Asynchronous Flow ==============
async def async_main():
    print("Extracting audio...")
    audio_path = extract_audio()
    print("Transcribing audio...")
    language, segments = transcribe(audio_path)
    print("Generating English subtitles...")
    generate_subtitle_file(segments, subtitle_file_en)
    print("Generating French audio with synchronization and manual overrides...")
    await async_generate_translated_audio_with_sync_using_review(subtitle_file_en, translated_audio, debug_log_file, review_file)
    print("Merging audio and video...")
    merge_audio_video()
    print(f"Process completed! Output video: {output_video}")

if __name__ == "__main__":
    asyncio.run(async_main())
# Out:
# ✅ ffmpeg found at: C:\ffmpeg\bin\ffmpeg.EXE
# Extracting audio...
# Transcribing audio...
# Detected language: en
# Generating English subtitles...
# Generating French audio with synchronization and manual overrides...
# ✅ Review file généré (128 segments) : 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250509_090058\translation_review.txt
# ✅ Parsed 128 segments depuis le review file.
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais jeter un œil aux confi…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_0_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'créer un rôle commercial ou un…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_1_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Fonctionne dans l'application …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_2_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'formulaires de données. La séc…'
# [Error] Attempt 1/10 failed for phrase: 'formulaires de données. La séc…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7B2F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'formulaires de données. La séc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_3_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sécurité par tâches ou flux de…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_4_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'À partir de la page d'accueil,…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_5_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner la file d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_6_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'membre pour lequel je souhaite…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_7_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'mis en évidence, nous pouvons …'
# [Error] Attempt 1/10 failed for phrase: 'mis en évidence, nous pouvons …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D79F40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'mis en évidence, nous pouvons …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_8_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'pour voir la formule des membr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_9_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le matériel OFS sera divisé pa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que nous avons la for…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_10_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons valider la formul…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_11_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'avec succès. Nous pouvons enre…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_12_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour obtenir un rôle commercia…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_13_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous cliquerons sur les règles…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_14_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Également appelé règles commer…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_15_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'expansion nous montrera l'EP…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_16_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Règle sous EPM FS. Permettez-m…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_17_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Règle, script, formule, je peu…'
# [Error] Attempt 1/10 failed for phrase: 'Règle, script, formule, je peu…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D91250> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Règle, script, formule, je peu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_18_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'va créer une règle. Comme j'ai…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_19_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Toutes ces informations sont p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais sélectionner le rouge …'
# [Error] Attempt 1/10 failed for phrase: 'Je vais sélectionner le rouge …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D79A30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais sélectionner le rouge …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_20_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Formule avec ce nom et je vais…'
# [Error] Attempt 1/10 failed for phrase: 'Formule avec ce nom et je vais…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D91370> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Formule avec ce nom et je vais…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_21_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'créé, nous voulons apporter de…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais dire oui et une fois q…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_22_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'créé c'est la première page qu…'
# [Error] Attempt 1/10 failed for phrase: 'créé c'est la première page qu…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7AF90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'créé c'est la première page qu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_23_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Les administrateurs utilisent …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_24_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sélectionnez la vue du script.…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_25_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais actuellement copier le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_26_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Offset d'allocation à l'exerci…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_27_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'règle commerciale de base. Nou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_28_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ces règles commerciales foncti…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_29_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Une fois que je l'ai enregistr…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_30_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Actuellement, je vais ouvrir u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_31_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Error] Attempt 1/10 failed for phrase: 'J'ai déjà un formulaire ici et…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7B6E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai déjà un formulaire ici et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_32_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'pour tous les quartiers et FY2…'
# [Error] Attempt 1/10 failed for phrase: 'pour tous les quartiers et FY2…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90CB0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'pour tous les quartiers et FY2…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_33_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour copier des données, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_34_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: '23 Une fois que j'ai exécuté l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_35_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'lance la règle commerciale. Je…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_36_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Règle lancée à partir d'ici ou…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_37_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme des formulaires de donné…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_38_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'est copié et il est peuplé dan…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_39_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'exécuter à partir du gestion…'
# [Error] Attempt 1/10 failed for phrase: 'L'exécuter à partir du gestion…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D919A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'L'exécuter à partir du gestion…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_39_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'peut attacher la règle commerc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_40_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sur Enregistrer, exécutez le c…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_41_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Cela nous aide donc à exécuter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_41_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Bouton Enregistrer. Nous pouvo…'
# [Error] Attempt 1/10 failed for phrase: 'Bouton Enregistrer. Nous pouvo…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90560> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Bouton Enregistrer. Nous pouvo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_42_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Exécutez dans le cadre des tra…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_43_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Règles commerciales qui permet…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_44_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'en utilisant la sécurité des r…'
# [Error] Attempt 1/10 failed for phrase: 'en utilisant la sécurité des r…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7B6E0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'en utilisant la sécurité des r…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_45_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais cliquer sur le formula…'
# [Error] Attempt 1/10 failed for phrase: 'Je vais cliquer sur le formula…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90290> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Je vais cliquer sur le formula…'
# [Error] Attempt 2/10 failed for phrase: 'Je vais cliquer sur le formula…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90440> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.6s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Je vais cliquer sur le formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_46_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'et accéder au contrôle d'accès…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_47_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'au sein de ces groupes et nous…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_48_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Administrateur, utilisateur de…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons voir la liste des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_49_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'peut attribuer différents rôle…'
# [Error] Attempt 1/10 failed for phrase: 'peut attribuer différents rôle…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90DD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'peut attribuer différents rôle…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_50_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'tâches que nécessaire. Nous po…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_51_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'ce qui les aidera à créer ou à…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_52_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Approuvant les gestionnaires d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_53_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Toute instance et importe un f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_54_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'toute instance différente dans…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_55_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais déplacer des détails s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_56_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sécurité dimensionnelle. Pour …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_57_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'attribué à chaque niveau de me…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_58_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'accès ou groupes affectés pour…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_59_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons créer ou ajouter …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_59_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Attribuez une lecture d'écritu…'
# [Error] Attempt 1/10 failed for phrase: 'Attribuez une lecture d'écritu…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7BB60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Attribuez une lecture d'écritu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_60_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Descendants du membre. La sécu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_61_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme les formulaires de donné…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_62_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'attribuer la sécurité pour un …'
# [Error] Attempt 1/10 failed for phrase: 'attribuer la sécurité pour un …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D79A30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'attribuer la sécurité pour un …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_63_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais aller dans le dossier …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_63_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et en cliquant dessus, je vais…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_64_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Conférence si je ajoute et leu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_65_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Pour accéder à ce formulaire d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_66_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous allons maintenant examine…'
# [Error] Attempt 1/10 failed for phrase: 'Nous allons maintenant examine…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7B4A0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous allons maintenant examine…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_67_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'vous aider à contrôler la sais…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_68_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'membres de la dimension pour é…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_69_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'combinaisons et enregistrez-le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_70_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'aux cellules individuelles bas…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_71_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'peut créer une nouvelle ou une…'
# [Error] Attempt 1/10 failed for phrase: 'peut créer une nouvelle ou une…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90E60> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.7s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'peut créer une nouvelle ou une…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_72_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comment créer et configurer un…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_72_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Page d'accueil Cliquez sur le …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_73_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sous des actions, nous pouvons…'
# [Error] Attempt 1/10 failed for phrase: 'Sous des actions, nous pouvons…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7BEC0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.5s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Sous des actions, nous pouvons…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_73_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'formulaire. Je cliquerai sur C…'
# [Error] Attempt 1/10 failed for phrase: 'formulaire. Je cliquerai sur C…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90680> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'formulaire. Je cliquerai sur C…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_74_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Sélectionnez la file d'attente…'
# [Error] Attempt 1/10 failed for phrase: 'Sélectionnez la file d'attente…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7BE30> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Sélectionnez la file d'attente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_75_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Dessinez les dimensions sur le…'
# [Error] Attempt 1/10 failed for phrase: 'Dessinez les dimensions sur le…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D79F40> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Dessinez les dimensions sur le…'
# [Error] Attempt 2/10 failed for phrase: 'Dessinez les dimensions sur le…'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 4.7s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Dessinez les dimensions sur le…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_76_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'sur les pages. Nous devrons sé…'
# [Error] Attempt 1/10 failed for phrase: 'sur les pages. Nous devrons sé…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D903B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'sur les pages. Nous devrons sé…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_77_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'icône me donnera le sélecteu…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_78_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Option pour personnaliser en f…'
# [Error] Attempt 1/10 failed for phrase: 'Option pour personnaliser en f…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D79D90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.9s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Option pour personnaliser en f…'
# [Error] Attempt 2/10 failed for phrase: 'Option pour personnaliser en f…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7B2F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.4s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'Option pour personnaliser en f…'
# [Error] Attempt 3/10 failed for phrase: 'Option pour personnaliser en f…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7BEC0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 8.6s…
# [Debug] Attempt 4/10: Synthesizing phrase: 'Option pour personnaliser en f…'
# [Error] Attempt 4/10 failed for phrase: 'Option pour personnaliser en f…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90290> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 16.5s…
# [Debug] Attempt 5/10: Synthesizing phrase: 'Option pour personnaliser en f…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_79_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Le sens nous aide à naviguer d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_80_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'sur le formulaire de données. …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_81_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'application. Nous pouvons dire…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_82_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Peut voir différentes options …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_83_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'supprimer les colonnes. Nous p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_84_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nom adieux au lieu de la haute…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_85_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également définir…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90440> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_85_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'propriétés qui est une proprié…'
# [Error] Attempt 1/10 failed for phrase: 'propriétés qui est une proprié…'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'propriétés qui est une proprié…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_86_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'voir. Nous avons également des…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_87_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'cette forme particulière. Ont …'
# [Error] Attempt 1/10 failed for phrase: 'cette forme particulière. Ont …'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D903B0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.4s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'cette forme particulière. Ont …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_88_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'le formulaire de données en co…'
# [Error] Attempt 1/10 failed for phrase: 'le formulaire de données en co…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90DD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'le formulaire de données en co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_89_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Scénario de point de vue dans …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_90_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'compte. Dans les lignes, nous …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_91_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai utilisé une variable de s…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_91_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Variable utilisateur ici. Donc…'
# [Error] Attempt 1/10 failed for phrase: 'Variable utilisateur ici. Donc…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D91250> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Variable utilisateur ici. Donc…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_92_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous voyons également des vari…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_93_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Prépopulation de la forme dyna…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_94_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai réglé une condition ici p…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_94_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Error] Attempt 1/10 failed for phrase: 'Donc, si la valeur de la devis…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7AA80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.8s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Donc, si la valeur de la devis…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_95_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Valider la condition et nous o…'
# [Error] Attempt 1/10 failed for phrase: 'Valider la condition et nous o…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D90DD0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Valider la condition et nous o…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_96_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je vais enregistrer ce formula…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_97_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ceci est la forme que nous avo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_97_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'et…'
# [Error] Attempt 1/10 failed for phrase: 'et…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D79D90> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.6s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'et…'
# [Error] Attempt 2/10 failed for phrase: 'et…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7AA80> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 4.6s…
# [Debug] Attempt 3/10: Synthesizing phrase: 'et…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_98_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Expansion. Je peux voir que lo…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_99_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et je peux développer plus. J'…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_100_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je peux donc avoir une valeur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_101_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La cellule est mise à jour et …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_102_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Chaque fois que la cellule est…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_103_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et nous pouvons voir comment l…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_104_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Tout comme Excel, nous pouvons…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_104_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'et apporter des données à tout…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_105_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Avec le total et je vais le sa…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_106_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Je veux également que ces donn…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_107_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour ceux-ci, je veux augme…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_108_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Error] Attempt 1/10 failed for phrase: 'Et pour cela, je vais augmente…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D911C0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.3s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Et pour cela, je vais augmente…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_109_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_110_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Error] Attempt 1/10 failed for phrase: 'J'ai également la possibilité …'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'J'ai également la possibilité …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_111_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Est-ce proportionnel ou est-il…'
# [Error] Attempt 1/10 failed for phrase: 'Est-ce proportionnel ou est-il…'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Est-ce proportionnel ou est-il…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_112_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Alors disons pour le quart d'u…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_112_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Comme j'ai des données pour ju…'
# [Error] Attempt 1/10 failed for phrase: 'Comme j'ai des données pour ju…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018524D7B410> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.0s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Comme j'ai des données pour ju…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_113_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Et il est ajusté par 1000.…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_114_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Vous pouvez voir comment les d…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_115_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons également ajouter…'. Exception: No audio was received. Please verify that your parameters are correct.
# [Debug] Retrying in 2.2s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons également ajouter…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_116_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'et joindre les détails à l'app…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_117_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'L'utilisateur pourra voir le n…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_118_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Quelle heure et quel est le co…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_119_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ainsi, quand un utilisateur pe…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_120_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Qu'est-ce que le commentaire e…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_121_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Ce qui signifie que nous avons…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_122_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons également définir…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_123_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'des outils. Nous pouvons défin…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_124_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'Nous pouvons définir comment n…'
# [Error] Attempt 1/10 failed for phrase: 'Nous pouvons définir comment n…'. Exception: Cannot connect to host speech.platform.bing.com:443 ssl:<ssl.SSLContext object at 0x0000018593D905F0> [Une connexion existante a dû être fermée par l’hôte distant]
# [Debug] Retrying in 2.1s…
# [Debug] Attempt 2/10: Synthesizing phrase: 'Nous pouvons définir comment n…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_124_1.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'La précision, les suppressions…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_125_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'en sélectionnant le sélecteur …'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_126_0.mp3
# [Debug] Attempt 1/10: Synthesizing phrase: 'puis le sauver.…'
# [Debug] Phrase synthesized successfully to C:\Users\061181~1\AppData\Local\Temp\tmp_127_0.mp3
# Merging audio and video...
# Moviepy - Building video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250509_090058\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250509_090058\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Moviepy - Done !
# Moviepy - video ready 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250509_090058\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
# Process completed! Output video: 4.2.4_Configuration de la solution_Avr_10_Latest_run_20250509_090058\4.2.4_Configuration de la solution_Avr_10_Latest-french.mp4
